# %%
# BIBLIOTECAS / MÓDULOS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import shutil
import csv

# %%
# Conglomerados Prudenciais e Instituições Independentes - Resumo (sem "Número de Agências" e "Número de Postos de Atendimento") - a partir de 03/2014 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Resumo (sem "Número de Agências" e "Número de Postos de Atendimento") - até 12/2013 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CPres122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122023 = CPres122023.iloc[:, :-1]
CPres122023.dropna(subset=['Data'], inplace=True)
CPres122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPres.csv', sep=',')
CPres092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092023 = CPres092023.iloc[:, :-1]
CPres092023.dropna(subset=['Data'], inplace=True)
CPres092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPres.csv', sep=',')
CPres062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062023 = CPres062023.iloc[:, :-1]
CPres062023.dropna(subset=['Data'], inplace=True)
CPres062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPres.csv', sep=',')
CPres032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032023 = CPres032023.iloc[:, :-1]
CPres032023.dropna(subset=['Data'], inplace=True)
CPres032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPres.csv', sep=',')
CPres122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122022 = CPres122022.iloc[:, :-1]
CPres122022.dropna(subset=['Data'], inplace=True)
CPres122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPres.csv', sep=',')
CPres092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092022 = CPres092022.iloc[:, :-1]
CPres092022.dropna(subset=['Data'], inplace=True)
CPres092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPres.csv', sep=',')
CPres062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062022 = CPres062022.iloc[:, :-1]
CPres062022.dropna(subset=['Data'], inplace=True)
CPres062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPres.csv', sep=',')
CPres032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032022 = CPres032022.iloc[:, :-1]
CPres032022.dropna(subset=['Data'], inplace=True)
CPres032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPres.csv', sep=',')
CPres122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122021 = CPres122021.iloc[:, :-1]
CPres122021.dropna(subset=['Data'], inplace=True)
CPres122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPres.csv', sep=',')
CPres092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092021 = CPres092021.iloc[:, :-1]
CPres092021.dropna(subset=['Data'], inplace=True)
CPres092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPres.csv', sep=',')
CPres062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062021 = CPres062021.iloc[:, :-1]
CPres062021.dropna(subset=['Data'], inplace=True)
CPres062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPres.csv', sep=',')
CPres032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032021 = CPres032021.iloc[:, :-1]
CPres032021.dropna(subset=['Data'], inplace=True)
CPres032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPres.csv', sep=',')
CPres122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122020 = CPres122020.iloc[:, :-1]
CPres122020.dropna(subset=['Data'], inplace=True)
CPres122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPres.csv', sep=',')
CPres092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092020 = CPres092020.iloc[:, :-1]
CPres092020.dropna(subset=['Data'], inplace=True)
CPres092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPres.csv', sep=',')
CPres062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062020 = CPres062020.iloc[:, :-1]
CPres062020.dropna(subset=['Data'], inplace=True)
CPres062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPres.csv', sep=',')
CPres032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032020 = CPres032020.iloc[:, :-1]
CPres032020.dropna(subset=['Data'], inplace=True)
CPres032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPres.csv', sep=',')
CPres122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122019 = CPres122019.iloc[:, :-1]
CPres122019.dropna(subset=['Data'], inplace=True)
CPres122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPres.csv', sep=',')
CPres092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092019 = CPres092019.iloc[:, :-1]
CPres092019.dropna(subset=['Data'], inplace=True)
CPres092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPres.csv', sep=',')
CPres062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062019 = CPres062019.iloc[:, :-1]
CPres062019.dropna(subset=['Data'], inplace=True)
CPres062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPres.csv', sep=',')
CPres032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032019 = CPres032019.iloc[:, :-1]
CPres032019.dropna(subset=['Data'], inplace=True)
CPres032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPres.csv', sep=',')
CPres122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122018 = CPres122018.iloc[:, :-1]
CPres122018.dropna(subset=['Data'], inplace=True)
CPres122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPres.csv', sep=',')
CPres092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092018 = CPres092018.iloc[:, :-1]
CPres092018.dropna(subset=['Data'], inplace=True)
CPres092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPres.csv', sep=',')
CPres062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062018 = CPres062018.iloc[:, :-1]
CPres062018.dropna(subset=['Data'], inplace=True)
CPres062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPres.csv', sep=',')
CPres032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032018 = CPres032018.iloc[:, :-1]
CPres032018.dropna(subset=['Data'], inplace=True)
CPres032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPres.csv', sep=',')
CPres122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122017 = CPres122017.iloc[:, :-1]
CPres122017.dropna(subset=['Data'], inplace=True)
CPres122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPres.csv', sep=',')
CPres092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092017 = CPres092017.iloc[:, :-1]
CPres092017.dropna(subset=['Data'], inplace=True)
CPres092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPres.csv', sep=',')
CPres062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062017 = CPres062017.iloc[:, :-1]
CPres062017.dropna(subset=['Data'], inplace=True)
CPres062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPres.csv', sep=',')
CPres032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032017 = CPres032017.iloc[:, :-1]
CPres032017.dropna(subset=['Data'], inplace=True)
CPres032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPres.csv', sep=',')
CPres122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122016 = CPres122016.iloc[:, :-1]
CPres122016.dropna(subset=['Data'], inplace=True)
CPres122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPres.csv', sep=',')
CPres092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092016 = CPres092016.iloc[:, :-1]
CPres092016.dropna(subset=['Data'], inplace=True)
CPres092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPres.csv', sep=',')
CPres062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062016 = CPres062016.iloc[:, :-1]
CPres062016.dropna(subset=['Data'], inplace=True)
CPres062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPres.csv', sep=',')
CPres032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032016 = CPres032016.iloc[:, :-1]
CPres032016.dropna(subset=['Data'], inplace=True)
CPres032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPres.csv', sep=',')
CPres122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122015 = CPres122015.iloc[:, :-1]
CPres122015.dropna(subset=['Data'], inplace=True)
CPres122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPres.csv', sep=',')
CPres092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092015 = CPres092015.iloc[:, :-1]
CPres092015.dropna(subset=['Data'], inplace=True)
CPres092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPres.csv', sep=',')
CPres062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062015 = CPres062015.iloc[:, :-1]
CPres062015.dropna(subset=['Data'], inplace=True)
CPres062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPres.csv', sep=',')
CPres032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032015 = CPres032015.iloc[:, :-1]
CPres032015.dropna(subset=['Data'], inplace=True)
CPres032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPres.csv', sep=',')
# Reinclusão a partir de 03/2015 das colunas finais 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia' e 'Índice de Imobilização'
CPres122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPres.csv', sep=';', usecols=[i for i in range(16)])
CPres122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'N/A']
CPres122014 = CPres122014.iloc[:, :-1]
CPres122014.dropna(subset=['Data'], inplace=True)
CPres122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPres.csv', sep=',')
CPres092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPres.csv', sep=';', usecols=[i for i in range(16)])
CPres092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'N/A']
CPres092014 = CPres092014.iloc[:, :-1]
CPres092014.dropna(subset=['Data'], inplace=True)
CPres092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPres.csv', sep=',')
CPres062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPres.csv', sep=';', usecols=[i for i in range(16)])
CPres062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'N/A']
CPres062014 = CPres062014.iloc[:, :-1]
CPres062014.dropna(subset=['Data'], inplace=True)
CPres062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPres.csv', sep=',')
CPres032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPres.csv', sep=';', usecols=[i for i in range(16)])
CPres032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'N/A']
CPres032014 = CPres032014.iloc[:, :-1]
CPres032014.dropna(subset=['Data'], inplace=True)
CPres032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPres.csv', sep=',')
# Exclusão a partir de 03/2014 das colunas finais 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia' e 'Índice de Imobilização'
CPres122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122013 = CPres122013.iloc[:, :-1]
CPres122013.dropna(subset=['Data'], inplace=True)
CPres122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPres.csv', sep=',')
CPres092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres092013 = CPres092013.iloc[:, :-1]
CPres092013.dropna(subset=['Data'], inplace=True)
CPres092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPres.csv', sep=',')
CPres062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres062013 = CPres062013.iloc[:, :-1]
CPres062013.dropna(subset=['Data'], inplace=True)
CPres062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPres.csv', sep=',')
CPres032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres032013 = CPres032013.iloc[:, :-1]
CPres032013.dropna(subset=['Data'], inplace=True)
CPres032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPres.csv', sep=',')
CPres122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPres.csv', sep=';', usecols=[i for i in range(19)])
CPres122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Ativo Total', 'Carteira de Crédito Classificada', 'Passivo Circulante e Exigível a Longo Prazo e Resultados de Exercícios Futuros', 'Captações', 'Patrimônio Líquido', 'Lucro Líquido', 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia', 'Índice de Imobilização', 'N/A']
CPres122012 = CPres122012.iloc[:, :-1]
CPres122012.dropna(subset=['Data'], inplace=True)
CPres122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPres.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPres_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPres_csv.to_csv('CPres.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPres.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPres.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPres = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPres.csv', sep=';')
CPres1 = CPres[CPres['Patrimônio Líquido'].str.contains('NI')==False]
CPres1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPres.csv', index=False, encoding='utf-8-sig', sep=';')
display(CPres1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1                                               ITAU
# 2               2                                           BRADESCO
# 3               3                            CAIXA ECONOMICA FEDERAL
# 4               4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# ...           ...                                                ...
# 64141        1338  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
# 64142        1339                                    AVIPAM CC LTDA.
# 64143        1340                                    HR SCMEPP LTDA.
# 64144        1341                                      MEGA CC LTDA.
# 64145        1342  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
#
#                     Código  TCB   SR TD       TC          Cidade  UF     Data  \
# ...

# %%
# Conglomerados Prudenciais e Instituições Independentes - Resumo (somente "Número de Agências" e "Número de Postos de Atendimento") - a partir de 03/2014 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Resumo (somente "Número de Agências" e "Número de Postos de Atendimento") - até 12/2013 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CPage122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122023 = CPage122023.iloc[:, :-1]
CPage122023.dropna(subset=['Data'], inplace=True)
CPage122023['Número de Agências'] = CPage122023['Número de Agências'].astype(str)
CPage122023['Número de Agências'] = CPage122023['Número de Agências'].str.replace('.', '')
CPage122023['Número de Postos de Atendimento'] = CPage122023['Número de Postos de Atendimento'].astype(str)
CPage122023['Número de Postos de Atendimento'] = CPage122023['Número de Postos de Atendimento'].str.replace('.', '')
CPage122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPage.csv', sep=',')
CPage092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092023 = CPage092023.iloc[:, :-1]
CPage092023.dropna(subset=['Data'], inplace=True)
CPage092023['Número de Agências'] = CPage092023['Número de Agências'].astype(str)
CPage092023['Número de Agências'] = CPage092023['Número de Agências'].str.replace('.', '')
CPage092023['Número de Postos de Atendimento'] = CPage092023['Número de Postos de Atendimento'].astype(str)
CPage092023['Número de Postos de Atendimento'] = CPage092023['Número de Postos de Atendimento'].str.replace('.', '')
CPage092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPage.csv', sep=',')
CPage062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062023 = CPage062023.iloc[:, :-1]
CPage062023.dropna(subset=['Data'], inplace=True)
CPage062023['Número de Agências'] = CPage062023['Número de Agências'].astype(str)
CPage062023['Número de Agências'] = CPage062023['Número de Agências'].str.replace('.', '')
CPage062023['Número de Postos de Atendimento'] = CPage062023['Número de Postos de Atendimento'].astype(str)
CPage062023['Número de Postos de Atendimento'] = CPage062023['Número de Postos de Atendimento'].str.replace('.', '')
CPage062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPage.csv', sep=',')
CPage032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032023 = CPage032023.iloc[:, :-1]
CPage032023.dropna(subset=['Data'], inplace=True)
CPage032023['Número de Agências'] = CPage032023['Número de Agências'].astype(str)
CPage032023['Número de Agências'] = CPage032023['Número de Agências'].str.replace('.', '')
CPage032023['Número de Postos de Atendimento'] = CPage032023['Número de Postos de Atendimento'].astype(str)
CPage032023['Número de Postos de Atendimento'] = CPage032023['Número de Postos de Atendimento'].str.replace('.', '')
CPage032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPage.csv', sep=',')
CPage122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122022 = CPage122022.iloc[:, :-1]
CPage122022.dropna(subset=['Data'], inplace=True)
CPage122022['Número de Agências'] = CPage122022['Número de Agências'].astype(str)
CPage122022['Número de Agências'] = CPage122022['Número de Agências'].str.replace('.', '')
CPage122022['Número de Postos de Atendimento'] = CPage122022['Número de Postos de Atendimento'].astype(str)
CPage122022['Número de Postos de Atendimento'] = CPage122022['Número de Postos de Atendimento'].str.replace('.', '')
CPage122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPage.csv', sep=',')
CPage092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092022 = CPage092022.iloc[:, :-1]
CPage092022.dropna(subset=['Data'], inplace=True)
CPage092022['Número de Agências'] = CPage092022['Número de Agências'].astype(str)
CPage092022['Número de Agências'] = CPage092022['Número de Agências'].str.replace('.', '')
CPage092022['Número de Postos de Atendimento'] = CPage092022['Número de Postos de Atendimento'].astype(str)
CPage092022['Número de Postos de Atendimento'] = CPage092022['Número de Postos de Atendimento'].str.replace('.', '')
CPage092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPage.csv', sep=',')
CPage062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062022 = CPage062022.iloc[:, :-1]
CPage062022.dropna(subset=['Data'], inplace=True)
CPage062022['Número de Agências'] = CPage062022['Número de Agências'].astype(str)
CPage062022['Número de Agências'] = CPage062022['Número de Agências'].str.replace('.', '')
CPage062022['Número de Postos de Atendimento'] = CPage062022['Número de Postos de Atendimento'].astype(str)
CPage062022['Número de Postos de Atendimento'] = CPage062022['Número de Postos de Atendimento'].str.replace('.', '')
CPage062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPage.csv', sep=',')
CPage032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032022 = CPage032022.iloc[:, :-1]
CPage032022.dropna(subset=['Data'], inplace=True)
CPage032022['Número de Agências'] = CPage032022['Número de Agências'].astype(str)
CPage032022['Número de Agências'] = CPage032022['Número de Agências'].str.replace('.', '')
CPage032022['Número de Postos de Atendimento'] = CPage032022['Número de Postos de Atendimento'].astype(str)
CPage032022['Número de Postos de Atendimento'] = CPage032022['Número de Postos de Atendimento'].str.replace('.', '')
CPage032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPage.csv', sep=',')
CPage122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122021 = CPage122021.iloc[:, :-1]
CPage122021.dropna(subset=['Data'], inplace=True)
CPage122021['Número de Agências'] = CPage122021['Número de Agências'].astype(str)
CPage122021['Número de Agências'] = CPage122021['Número de Agências'].str.replace('.', '')
CPage122021['Número de Postos de Atendimento'] = CPage122021['Número de Postos de Atendimento'].astype(str)
CPage122021['Número de Postos de Atendimento'] = CPage122021['Número de Postos de Atendimento'].str.replace('.', '')
CPage122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPage.csv', sep=',')
CPage092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092021 = CPage092021.iloc[:, :-1]
CPage092021.dropna(subset=['Data'], inplace=True)
CPage092021['Número de Agências'] = CPage092021['Número de Agências'].astype(str)
CPage092021['Número de Agências'] = CPage092021['Número de Agências'].str.replace('.', '')
CPage092021['Número de Postos de Atendimento'] = CPage092021['Número de Postos de Atendimento'].astype(str)
CPage092021['Número de Postos de Atendimento'] = CPage092021['Número de Postos de Atendimento'].str.replace('.', '')
CPage092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPage.csv', sep=',')
CPage062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062021 = CPage062021.iloc[:, :-1]
CPage062021.dropna(subset=['Data'], inplace=True)
CPage062021['Número de Agências'] = CPage062021['Número de Agências'].astype(str)
CPage062021['Número de Agências'] = CPage062021['Número de Agências'].str.replace('.', '')
CPage062021['Número de Postos de Atendimento'] = CPage062021['Número de Postos de Atendimento'].astype(str)
CPage062021['Número de Postos de Atendimento'] = CPage062021['Número de Postos de Atendimento'].str.replace('.', '')
CPage062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPage.csv', sep=',')
CPage032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032021 = CPage032021.iloc[:, :-1]
CPage032021.dropna(subset=['Data'], inplace=True)
CPage032021['Número de Agências'] = CPage032021['Número de Agências'].astype(str)
CPage032021['Número de Agências'] = CPage032021['Número de Agências'].str.replace('.', '')
CPage032021['Número de Postos de Atendimento'] = CPage032021['Número de Postos de Atendimento'].astype(str)
CPage032021['Número de Postos de Atendimento'] = CPage032021['Número de Postos de Atendimento'].str.replace('.', '')
CPage032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPage.csv', sep=',')
CPage122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122020 = CPage122020.iloc[:, :-1]
CPage122020.dropna(subset=['Data'], inplace=True)
CPage122020['Número de Agências'] = CPage122020['Número de Agências'].astype(str)
CPage122020['Número de Agências'] = CPage122020['Número de Agências'].str.replace('.', '')
CPage122020['Número de Postos de Atendimento'] = CPage122020['Número de Postos de Atendimento'].astype(str)
CPage122020['Número de Postos de Atendimento'] = CPage122020['Número de Postos de Atendimento'].str.replace('.', '')
CPage122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPage.csv', sep=',')
CPage092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092020 = CPage092020.iloc[:, :-1]
CPage092020.dropna(subset=['Data'], inplace=True)
CPage092020['Número de Agências'] = CPage092020['Número de Agências'].astype(str)
CPage092020['Número de Agências'] = CPage092020['Número de Agências'].str.replace('.', '')
CPage092020['Número de Postos de Atendimento'] = CPage092020['Número de Postos de Atendimento'].astype(str)
CPage092020['Número de Postos de Atendimento'] = CPage092020['Número de Postos de Atendimento'].str.replace('.', '')
CPage092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPage.csv', sep=',')
CPage062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062020 = CPage062020.iloc[:, :-1]
CPage062020.dropna(subset=['Data'], inplace=True)
CPage062020['Número de Agências'] = CPage062020['Número de Agências'].astype(str)
CPage062020['Número de Agências'] = CPage062020['Número de Agências'].str.replace('.', '')
CPage062020['Número de Postos de Atendimento'] = CPage062020['Número de Postos de Atendimento'].astype(str)
CPage062020['Número de Postos de Atendimento'] = CPage062020['Número de Postos de Atendimento'].str.replace('.', '')
CPage062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPage.csv', sep=',')
CPage032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032020 = CPage032020.iloc[:, :-1]
CPage032020.dropna(subset=['Data'], inplace=True)
CPage032020['Número de Agências'] = CPage032020['Número de Agências'].astype(str)
CPage032020['Número de Agências'] = CPage032020['Número de Agências'].str.replace('.', '')
CPage032020['Número de Postos de Atendimento'] = CPage032020['Número de Postos de Atendimento'].astype(str)
CPage032020['Número de Postos de Atendimento'] = CPage032020['Número de Postos de Atendimento'].str.replace('.', '')
CPage032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPage.csv', sep=',')
CPage122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122019 = CPage122019.iloc[:, :-1]
CPage122019.dropna(subset=['Data'], inplace=True)
CPage122019['Número de Agências'] = CPage122019['Número de Agências'].astype(str)
CPage122019['Número de Agências'] = CPage122019['Número de Agências'].str.replace('.', '')
CPage122019['Número de Postos de Atendimento'] = CPage122019['Número de Postos de Atendimento'].astype(str)
CPage122019['Número de Postos de Atendimento'] = CPage122019['Número de Postos de Atendimento'].str.replace('.', '')
CPage122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPage.csv', sep=',')
CPage092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092019 = CPage092019.iloc[:, :-1]
CPage092019.dropna(subset=['Data'], inplace=True)
CPage092019['Número de Agências'] = CPage092019['Número de Agências'].astype(str)
CPage092019['Número de Agências'] = CPage092019['Número de Agências'].str.replace('.', '')
CPage092019['Número de Postos de Atendimento'] = CPage092019['Número de Postos de Atendimento'].astype(str)
CPage092019['Número de Postos de Atendimento'] = CPage092019['Número de Postos de Atendimento'].str.replace('.', '')
CPage092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPage.csv', sep=',')
CPage062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062019 = CPage062019.iloc[:, :-1]
CPage062019.dropna(subset=['Data'], inplace=True)
CPage062019['Número de Agências'] = CPage062019['Número de Agências'].astype(str)
CPage062019['Número de Agências'] = CPage062019['Número de Agências'].str.replace('.', '')
CPage062019['Número de Postos de Atendimento'] = CPage062019['Número de Postos de Atendimento'].astype(str)
CPage062019['Número de Postos de Atendimento'] = CPage062019['Número de Postos de Atendimento'].str.replace('.', '')
CPage062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPage.csv', sep=',')
CPage032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032019 = CPage032019.iloc[:, :-1]
CPage032019.dropna(subset=['Data'], inplace=True)
CPage032019['Número de Agências'] = CPage032019['Número de Agências'].astype(str)
CPage032019['Número de Agências'] = CPage032019['Número de Agências'].str.replace('.', '')
CPage032019['Número de Postos de Atendimento'] = CPage032019['Número de Postos de Atendimento'].astype(str)
CPage032019['Número de Postos de Atendimento'] = CPage032019['Número de Postos de Atendimento'].str.replace('.', '')
CPage032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPage.csv', sep=',')
CPage122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122018 = CPage122018.iloc[:, :-1]
CPage122018.dropna(subset=['Data'], inplace=True)
CPage122018['Número de Agências'] = CPage122018['Número de Agências'].astype(str)
CPage122018['Número de Agências'] = CPage122018['Número de Agências'].str.replace('.', '')
CPage122018['Número de Postos de Atendimento'] = CPage122018['Número de Postos de Atendimento'].astype(str)
CPage122018['Número de Postos de Atendimento'] = CPage122018['Número de Postos de Atendimento'].str.replace('.', '')
CPage122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPage.csv', sep=',')
CPage092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092018 = CPage092018.iloc[:, :-1]
CPage092018.dropna(subset=['Data'], inplace=True)
CPage092018['Número de Agências'] = CPage092018['Número de Agências'].astype(str)
CPage092018['Número de Agências'] = CPage092018['Número de Agências'].str.replace('.', '')
CPage092018['Número de Postos de Atendimento'] = CPage092018['Número de Postos de Atendimento'].astype(str)
CPage092018['Número de Postos de Atendimento'] = CPage092018['Número de Postos de Atendimento'].str.replace('.', '')
CPage092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPage.csv', sep=',')
CPage062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062018 = CPage062018.iloc[:, :-1]
CPage062018.dropna(subset=['Data'], inplace=True)
CPage062018['Número de Agências'] = CPage062018['Número de Agências'].astype(str)
CPage062018['Número de Agências'] = CPage062018['Número de Agências'].str.replace('.', '')
CPage062018['Número de Postos de Atendimento'] = CPage062018['Número de Postos de Atendimento'].astype(str)
CPage062018['Número de Postos de Atendimento'] = CPage062018['Número de Postos de Atendimento'].str.replace('.', '')
CPage062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPage.csv', sep=',')
CPage032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032018 = CPage032018.iloc[:, :-1]
CPage032018.dropna(subset=['Data'], inplace=True)
CPage032018['Número de Agências'] = CPage032018['Número de Agências'].astype(str)
CPage032018['Número de Agências'] = CPage032018['Número de Agências'].str.replace('.', '')
CPage032018['Número de Postos de Atendimento'] = CPage032018['Número de Postos de Atendimento'].astype(str)
CPage032018['Número de Postos de Atendimento'] = CPage032018['Número de Postos de Atendimento'].str.replace('.', '')
CPage032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPage.csv', sep=',')
CPage122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122017 = CPage122017.iloc[:, :-1]
CPage122017.dropna(subset=['Data'], inplace=True)
CPage122017['Número de Agências'] = CPage122017['Número de Agências'].astype(str)
CPage122017['Número de Agências'] = CPage122017['Número de Agências'].str.replace('.', '')
CPage122017['Número de Postos de Atendimento'] = CPage122017['Número de Postos de Atendimento'].astype(str)
CPage122017['Número de Postos de Atendimento'] = CPage122017['Número de Postos de Atendimento'].str.replace('.', '')
CPage122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPage.csv', sep=',')
CPage092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092017 = CPage092017.iloc[:, :-1]
CPage092017.dropna(subset=['Data'], inplace=True)
CPage092017['Número de Agências'] = CPage092017['Número de Agências'].astype(str)
CPage092017['Número de Agências'] = CPage092017['Número de Agências'].str.replace('.', '')
CPage092017['Número de Postos de Atendimento'] = CPage092017['Número de Postos de Atendimento'].astype(str)
CPage092017['Número de Postos de Atendimento'] = CPage092017['Número de Postos de Atendimento'].str.replace('.', '')
CPage092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPage.csv', sep=',')
CPage062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062017 = CPage062017.iloc[:, :-1]
CPage062017.dropna(subset=['Data'], inplace=True)
CPage062017['Número de Agências'] = CPage062017['Número de Agências'].astype(str)
CPage062017['Número de Agências'] = CPage062017['Número de Agências'].str.replace('.', '')
CPage062017['Número de Postos de Atendimento'] = CPage062017['Número de Postos de Atendimento'].astype(str)
CPage062017['Número de Postos de Atendimento'] = CPage062017['Número de Postos de Atendimento'].str.replace('.', '')
CPage062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPage.csv', sep=',')
CPage032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032017 = CPage032017.iloc[:, :-1]
CPage032017.dropna(subset=['Data'], inplace=True)
CPage032017['Número de Agências'] = CPage032017['Número de Agências'].astype(str)
CPage032017['Número de Agências'] = CPage032017['Número de Agências'].str.replace('.', '')
CPage032017['Número de Postos de Atendimento'] = CPage032017['Número de Postos de Atendimento'].astype(str)
CPage032017['Número de Postos de Atendimento'] = CPage032017['Número de Postos de Atendimento'].str.replace('.', '')
CPage032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPage.csv', sep=',')
CPage122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122016 = CPage122016.iloc[:, :-1]
CPage122016.dropna(subset=['Data'], inplace=True)
CPage122016['Número de Agências'] = CPage122016['Número de Agências'].astype(str)
CPage122016['Número de Agências'] = CPage122016['Número de Agências'].str.replace('.', '')
CPage122016['Número de Postos de Atendimento'] = CPage122016['Número de Postos de Atendimento'].astype(str)
CPage122016['Número de Postos de Atendimento'] = CPage122016['Número de Postos de Atendimento'].str.replace('.', '')
CPage122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPage.csv', sep=',')
CPage092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092016 = CPage092016.iloc[:, :-1]
CPage092016.dropna(subset=['Data'], inplace=True)
CPage092016['Número de Agências'] = CPage092016['Número de Agências'].astype(str)
CPage092016['Número de Agências'] = CPage092016['Número de Agências'].str.replace('.', '')
CPage092016['Número de Postos de Atendimento'] = CPage092016['Número de Postos de Atendimento'].astype(str)
CPage092016['Número de Postos de Atendimento'] = CPage092016['Número de Postos de Atendimento'].str.replace('.', '')
CPage092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPage.csv', sep=',')
CPage062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062016 = CPage062016.iloc[:, :-1]
CPage062016.dropna(subset=['Data'], inplace=True)
CPage062016['Número de Agências'] = CPage062016['Número de Agências'].astype(str)
CPage062016['Número de Agências'] = CPage062016['Número de Agências'].str.replace('.', '')
CPage062016['Número de Postos de Atendimento'] = CPage062016['Número de Postos de Atendimento'].astype(str)
CPage062016['Número de Postos de Atendimento'] = CPage062016['Número de Postos de Atendimento'].str.replace('.', '')
CPage062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPage.csv', sep=',')
CPage032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032016 = CPage032016.iloc[:, :-1]
CPage032016.dropna(subset=['Data'], inplace=True)
CPage032016['Número de Agências'] = CPage032016['Número de Agências'].astype(str)
CPage032016['Número de Agências'] = CPage032016['Número de Agências'].str.replace('.', '')
CPage032016['Número de Postos de Atendimento'] = CPage032016['Número de Postos de Atendimento'].astype(str)
CPage032016['Número de Postos de Atendimento'] = CPage032016['Número de Postos de Atendimento'].str.replace('.', '')
CPage032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPage.csv', sep=',')
CPage122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122015 = CPage122015.iloc[:, :-1]
CPage122015.dropna(subset=['Data'], inplace=True)
CPage122015['Número de Agências'] = CPage122015['Número de Agências'].astype(str)
CPage122015['Número de Agências'] = CPage122015['Número de Agências'].str.replace('.', '')
CPage122015['Número de Postos de Atendimento'] = CPage122015['Número de Postos de Atendimento'].astype(str)
CPage122015['Número de Postos de Atendimento'] = CPage122015['Número de Postos de Atendimento'].str.replace('.', '')
CPage122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPage.csv', sep=',')
CPage092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092015 = CPage092015.iloc[:, :-1]
CPage092015.dropna(subset=['Data'], inplace=True)
CPage092015['Número de Agências'] = CPage092015['Número de Agências'].astype(str)
CPage092015['Número de Agências'] = CPage092015['Número de Agências'].str.replace('.', '')
CPage092015['Número de Postos de Atendimento'] = CPage092015['Número de Postos de Atendimento'].astype(str)
CPage092015['Número de Postos de Atendimento'] = CPage092015['Número de Postos de Atendimento'].str.replace('.', '')
CPage092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPage.csv', sep=',')
CPage062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062015 = CPage062015.iloc[:, :-1]
CPage062015.dropna(subset=['Data'], inplace=True)
CPage062015['Número de Agências'] = CPage062015['Número de Agências'].astype(str)
CPage062015['Número de Agências'] = CPage062015['Número de Agências'].str.replace('.', '')
CPage062015['Número de Postos de Atendimento'] = CPage062015['Número de Postos de Atendimento'].astype(str)
CPage062015['Número de Postos de Atendimento'] = CPage062015['Número de Postos de Atendimento'].str.replace('.', '')
CPage062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPage.csv', sep=',')
CPage032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032015 = CPage032015.iloc[:, :-1]
CPage032015.dropna(subset=['Data'], inplace=True)
CPage032015['Número de Agências'] = CPage032015['Número de Agências'].astype(str)
CPage032015['Número de Agências'] = CPage032015['Número de Agências'].str.replace('.', '')
CPage032015['Número de Postos de Atendimento'] = CPage032015['Número de Postos de Atendimento'].astype(str)
CPage032015['Número de Postos de Atendimento'] = CPage032015['Número de Postos de Atendimento'].str.replace('.', '')
CPage032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPage.csv', sep=',')
# Reinclusão a partir de 03/2015 das colunas finais 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia' e 'Índice de Imobilização'
CPage122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 16, 17], thousands='.')
CPage122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122014 = CPage122014.iloc[:, :-1]
CPage122014.dropna(subset=['Data'], inplace=True)
CPage122014['Número de Agências'] = CPage122014['Número de Agências'].astype(str)
CPage122014['Número de Agências'] = CPage122014['Número de Agências'].str.replace('.', '')
CPage122014['Número de Postos de Atendimento'] = CPage122014['Número de Postos de Atendimento'].astype(str)
CPage122014['Número de Postos de Atendimento'] = CPage122014['Número de Postos de Atendimento'].str.replace('.', '')
CPage122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPage.csv', sep=',')
CPage092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 16, 17], thousands='.')
CPage092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092014 = CPage092014.iloc[:, :-1]
CPage092014.dropna(subset=['Data'], inplace=True)
CPage092014['Número de Agências'] = CPage092014['Número de Agências'].astype(str)
CPage092014['Número de Agências'] = CPage092014['Número de Agências'].str.replace('.', '')
CPage092014['Número de Postos de Atendimento'] = CPage092014['Número de Postos de Atendimento'].astype(str)
CPage092014['Número de Postos de Atendimento'] = CPage092014['Número de Postos de Atendimento'].str.replace('.', '')
CPage092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPage.csv', sep=',')
CPage062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 16, 17], thousands='.')
CPage062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062014 = CPage062014.iloc[:, :-1]
CPage062014.dropna(subset=['Data'], inplace=True)
CPage062014['Número de Agências'] = CPage062014['Número de Agências'].astype(str)
CPage062014['Número de Agências'] = CPage062014['Número de Agências'].str.replace('.', '')
CPage062014['Número de Postos de Atendimento'] = CPage062014['Número de Postos de Atendimento'].astype(str)
CPage062014['Número de Postos de Atendimento'] = CPage062014['Número de Postos de Atendimento'].str.replace('.', '')
CPage062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPage.csv', sep=',')
CPage032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 16, 17], thousands='.')
CPage032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032014 = CPage032014.iloc[:, :-1]
CPage032014.dropna(subset=['Data'], inplace=True)
CPage032014['Número de Agências'] = CPage032014['Número de Agências'].astype(str)
CPage032014['Número de Agências'] = CPage032014['Número de Agências'].str.replace('.', '')
CPage032014['Número de Postos de Atendimento'] = CPage032014['Número de Postos de Atendimento'].astype(str)
CPage032014['Número de Postos de Atendimento'] = CPage032014['Número de Postos de Atendimento'].str.replace('.', '')
CPage032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPage.csv', sep=',')
# Exclusão a partir de 03/2014 das colunas finais 'Patrimônio de Referência para Comparação com o RWA', 'Índice de Basileia' e 'Índice de Imobilização'
CPage122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122013 = CPage122013.iloc[:, :-1]
CPage122013.dropna(subset=['Data'], inplace=True)
CPage122013['Número de Agências'] = CPage122013['Número de Agências'].astype(str)
CPage122013['Número de Agências'] = CPage122013['Número de Agências'].str.replace('.', '')
CPage122013['Número de Postos de Atendimento'] = CPage122013['Número de Postos de Atendimento'].astype(str)
CPage122013['Número de Postos de Atendimento'] = CPage122013['Número de Postos de Atendimento'].str.replace('.', '')
CPage122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPage.csv', sep=',')
CPage092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage092013 = CPage092013.iloc[:, :-1]
CPage092013.dropna(subset=['Data'], inplace=True)
CPage092013['Número de Agências'] = CPage092013['Número de Agências'].astype(str)
CPage092013['Número de Agências'] = CPage092013['Número de Agências'].str.replace('.', '')
CPage092013['Número de Postos de Atendimento'] = CPage092013['Número de Postos de Atendimento'].astype(str)
CPage092013['Número de Postos de Atendimento'] = CPage092013['Número de Postos de Atendimento'].str.replace('.', '')
CPage092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPage.csv', sep=',')
CPage062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage062013 = CPage062013.iloc[:, :-1]
CPage062013.dropna(subset=['Data'], inplace=True)
CPage062013['Número de Agências'] = CPage062013['Número de Agências'].astype(str)
CPage062013['Número de Agências'] = CPage062013['Número de Agências'].str.replace('.', '')
CPage062013['Número de Postos de Atendimento'] = CPage062013['Número de Postos de Atendimento'].astype(str)
CPage062013['Número de Postos de Atendimento'] = CPage062013['Número de Postos de Atendimento'].str.replace('.', '')
CPage062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPage.csv', sep=',')
CPage032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage032013 = CPage032013.iloc[:, :-1]
CPage032013.dropna(subset=['Data'], inplace=True)
CPage032013['Número de Agências'] = CPage032013['Número de Agências'].astype(str)
CPage032013['Número de Agências'] = CPage032013['Número de Agências'].str.replace('.', '')
CPage032013['Número de Postos de Atendimento'] = CPage032013['Número de Postos de Atendimento'].astype(str)
CPage032013['Número de Postos de Atendimento'] = CPage032013['Número de Postos de Atendimento'].str.replace('.', '')
CPage032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPage.csv', sep=',')
CPage122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPres.csv', encoding='utf-8-sig', sep=';', usecols=[0, 1, 2, 3, 4, 5, 6, 7, 8, 18, 19, 20], thousands='.')
CPage122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Número de Agências', 'Número de Postos de Atendimento', 'N/A']
CPage122012 = CPage122012.iloc[:, :-1]
CPage122012.dropna(subset=['Data'], inplace=True)
CPage122012['Número de Agências'] = CPage122012['Número de Agências'].astype(str)
CPage122012['Número de Agências'] = CPage122012['Número de Agências'].str.replace('.', '')
CPage122012['Número de Postos de Atendimento'] = CPage122012['Número de Postos de Atendimento'].astype(str)
CPage122012['Número de Postos de Atendimento'] = CPage122012['Número de Postos de Atendimento'].str.replace('.', '')
CPage122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPage.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPage_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPage_csv.to_csv('CPage.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPage.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPage.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPage = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPage.csv', sep=';')
display (CPage)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
# C:\Users\mvrgu\AppData\Local\Temp/ipykernel_6080/1598057347.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   CPage122023['Número de Agências'] = CPage122023['Número de Agências'].str.replace('.', '')
# C:\Users\mvrgu\AppData\Local\Temp/ipykernel_6080/1598057347.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   CPage122023['Número de Postos de Atendimento'] = CPage122023['Número de Postos de Atendimento'].str.replace('.', '')
# ...

# %%
# Conglomerados Prudenciais e Instituições Independentes - Ativos - a partir de 03/2014 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Ativos - até 12/2013 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir primeiras linhas / excluir totalizadores / criar arquivos .csv temporários
CPati122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPati.csv', sep=';', skiprows=1)
CPati122023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122023 = CPati122023.iloc[:, :-1]
CPati122023.dropna(subset=['Data'], inplace=True)
CPati122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPati.csv', sep=',')
CPati092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPati.csv', sep=';', skiprows=1)
CPati092023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092023 = CPati092023.iloc[:, :-1]
CPati092023.dropna(subset=['Data'], inplace=True)
CPati092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPati.csv', sep=',')
CPati062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPati.csv', sep=';', skiprows=1)
CPati062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062023 = CPati062023.iloc[:, :-1]
CPati062023.dropna(subset=['Data'], inplace=True)
CPati062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPati.csv', sep=',')
CPati032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPati.csv', sep=';', skiprows=1)
CPati032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032023 = CPati032023.iloc[:, :-1]
CPati032023.dropna(subset=['Data'], inplace=True)
CPati032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPati.csv', sep=',')
CPati122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPati.csv', sep=';', skiprows=1)
CPati122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122022 = CPati122022.iloc[:, :-1]
CPati122022.dropna(subset=['Data'], inplace=True)
CPati122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPati.csv', sep=',')
CPati092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPati.csv', sep=';', skiprows=1)
CPati092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092022 = CPati092022.iloc[:, :-1]
CPati092022.dropna(subset=['Data'], inplace=True)
CPati092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPati.csv', sep=',')
CPati062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPati.csv', sep=';', skiprows=1)
CPati062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062022 = CPati062022.iloc[:, :-1]
CPati062022.dropna(subset=['Data'], inplace=True)
CPati062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPati.csv', sep=',')
CPati032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPati.csv', sep=';', skiprows=1)
CPati032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032022 = CPati032022.iloc[:, :-1]
CPati032022.dropna(subset=['Data'], inplace=True)
CPati032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPati.csv', sep=',')
CPati122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPati.csv', sep=';', skiprows=1)
CPati122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122021 = CPati122021.iloc[:, :-1]
CPati122021.dropna(subset=['Data'], inplace=True)
CPati122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPati.csv', sep=',')
CPati092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPati.csv', sep=';', skiprows=1)
CPati092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092021 = CPati092021.iloc[:, :-1]
CPati092021.dropna(subset=['Data'], inplace=True)
CPati092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPati.csv', sep=',')
CPati062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPati.csv', sep=';', skiprows=1)
CPati062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062021 = CPati062021.iloc[:, :-1]
CPati062021.dropna(subset=['Data'], inplace=True)
CPati062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPati.csv', sep=',')
CPati032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPati.csv', sep=';', skiprows=1)
CPati032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032021 = CPati032021.iloc[:, :-1]
CPati032021.dropna(subset=['Data'], inplace=True)
CPati032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPati.csv', sep=',')
CPati122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPati.csv', sep=';', skiprows=1)
CPati122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122020 = CPati122020.iloc[:, :-1]
CPati122020.dropna(subset=['Data'], inplace=True)
CPati122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPati.csv', sep=',')
CPati092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPati.csv', sep=';', skiprows=1)
CPati092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092020 = CPati092020.iloc[:, :-1]
CPati092020.dropna(subset=['Data'], inplace=True)
CPati092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPati.csv', sep=',')
CPati062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPati.csv', sep=';', skiprows=1)
CPati062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062020 = CPati062020.iloc[:, :-1]
CPati062020.dropna(subset=['Data'], inplace=True)
CPati062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPati.csv', sep=',')
CPati032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPati.csv', sep=';', skiprows=1)
CPati032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032020 = CPati032020.iloc[:, :-1]
CPati032020.dropna(subset=['Data'], inplace=True)
CPati032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPati.csv', sep=',')
CPati122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPati.csv', sep=';', skiprows=1)
CPati122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122019 = CPati122019.iloc[:, :-1]
CPati122019.dropna(subset=['Data'], inplace=True)
CPati122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPati.csv', sep=',')
CPati092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPati.csv', sep=';', skiprows=1)
CPati092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092019 = CPati092019.iloc[:, :-1]
CPati092019.dropna(subset=['Data'], inplace=True)
CPati092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPati.csv', sep=',')
CPati062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPati.csv', sep=';', skiprows=1)
CPati062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062019 = CPati062019.iloc[:, :-1]
CPati062019.dropna(subset=['Data'], inplace=True)
CPati062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPati.csv', sep=',')
CPati032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPati.csv', sep=';', skiprows=1)
CPati032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032019 = CPati032019.iloc[:, :-1]
CPati032019.dropna(subset=['Data'], inplace=True)
CPati032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPati.csv', sep=',')
CPati122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPati.csv', sep=';', skiprows=1)
CPati122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122018 = CPati122018.iloc[:, :-1]
CPati122018.dropna(subset=['Data'], inplace=True)
CPati122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPati.csv', sep=',')
CPati092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPati.csv', sep=';', skiprows=1)
CPati092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092018 = CPati092018.iloc[:, :-1]
CPati092018.dropna(subset=['Data'], inplace=True)
CPati092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPati.csv', sep=',')
CPati062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPati.csv', sep=';', skiprows=1)
CPati062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062018 = CPati062018.iloc[:, :-1]
CPati062018.dropna(subset=['Data'], inplace=True)
CPati062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPati.csv', sep=',')
CPati032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPati.csv', sep=';', skiprows=1)
CPati032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032018 = CPati032018.iloc[:, :-1]
CPati032018.dropna(subset=['Data'], inplace=True)
CPati032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPati.csv', sep=',')
CPati122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPati.csv', sep=';', skiprows=1)
CPati122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122017 = CPati122017.iloc[:, :-1]
CPati122017.dropna(subset=['Data'], inplace=True)
CPati122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPati.csv', sep=',')
CPati092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPati.csv', sep=';', skiprows=1)
CPati092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092017 = CPati092017.iloc[:, :-1]
CPati092017.dropna(subset=['Data'], inplace=True)
CPati092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPati.csv', sep=',')
CPati062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPati.csv', sep=';', skiprows=1)
CPati062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062017 = CPati062017.iloc[:, :-1]
CPati062017.dropna(subset=['Data'], inplace=True)
CPati062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPati.csv', sep=',')
CPati032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPati.csv', sep=';', skiprows=1)
CPati032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032017 = CPati032017.iloc[:, :-1]
CPati032017.dropna(subset=['Data'], inplace=True)
CPati032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPati.csv', sep=',')
CPati122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPati.csv', sep=';', skiprows=1)
CPati122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122016 = CPati122016.iloc[:, :-1]
CPati122016.dropna(subset=['Data'], inplace=True)
CPati122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPati.csv', sep=',')
CPati092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPati.csv', sep=';', skiprows=1)
CPati092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092016 = CPati092016.iloc[:, :-1]
CPati092016.dropna(subset=['Data'], inplace=True)
CPati092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPati.csv', sep=',')
CPati062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPati.csv', sep=';', skiprows=1)
CPati062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062016 = CPati062016.iloc[:, :-1]
CPati062016.dropna(subset=['Data'], inplace=True)
CPati062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPati.csv', sep=',')
CPati032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPati.csv', sep=';', skiprows=1)
CPati032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032016 = CPati032016.iloc[:, :-1]
CPati032016.dropna(subset=['Data'], inplace=True)
CPati032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPati.csv', sep=',')
CPati122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPati.csv', sep=';', skiprows=1)
CPati122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122015 = CPati122015.iloc[:, :-1]
CPati122015.dropna(subset=['Data'], inplace=True)
CPati122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPati.csv', sep=',')
CPati092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPati.csv', sep=';', skiprows=1)
CPati092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092015 = CPati092015.iloc[:, :-1]
CPati092015.dropna(subset=['Data'], inplace=True)
CPati092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPati.csv', sep=',')
CPati062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPati.csv', sep=';', skiprows=1)
CPati062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062015 = CPati062015.iloc[:, :-1]
CPati062015.dropna(subset=['Data'], inplace=True)
CPati062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPati.csv', sep=',')
CPati032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPati.csv', sep=';', skiprows=1)
CPati032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032015 = CPati032015.iloc[:, :-1]
CPati032015.dropna(subset=['Data'], inplace=True)
CPati032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPati.csv', sep=',')
CPati122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPati.csv', sep=';', skiprows=1)
CPati122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122014 = CPati122014.iloc[:, :-1]
CPati122014.dropna(subset=['Data'], inplace=True)
CPati122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPati.csv', sep=',')
CPati092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPati.csv', sep=';', skiprows=1)
CPati092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092014 = CPati092014.iloc[:, :-1]
CPati092014.dropna(subset=['Data'], inplace=True)
CPati092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPati.csv', sep=',')
CPati062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPati.csv', sep=';', skiprows=1)
CPati062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062014 = CPati062014.iloc[:, :-1]
CPati062014.dropna(subset=['Data'], inplace=True)
CPati062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPati.csv', sep=',')
CPati032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPati.csv', sep=';', skiprows=1)
CPati032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032014 = CPati032014.iloc[:, :-1]
CPati032014.dropna(subset=['Data'], inplace=True)
CPati032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPati.csv', sep=',')
CPati122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPati.csv', sep=';', skiprows=1)
CPati122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122013 = CPati122013.iloc[:, :-1]
CPati122013.dropna(subset=['Data'], inplace=True)
CPati122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPati.csv', sep=',')
CPati092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPati.csv', sep=';', skiprows=1)
CPati092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati092013 = CPati092013.iloc[:, :-1]
CPati092013.dropna(subset=['Data'], inplace=True)
CPati092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPati.csv', sep=',')
CPati062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPati.csv', sep=';', skiprows=1)
CPati062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati062013 = CPati062013.iloc[:, :-1]
CPati062013.dropna(subset=['Data'], inplace=True)
CPati062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPati.csv', sep=',')
CPati032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPati.csv', sep=';', skiprows=1)
CPati032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati032013 = CPati032013.iloc[:, :-1]
CPati032013.dropna(subset=['Data'], inplace=True)
CPati032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPati.csv', sep=',')
CPati122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPati.csv', sep=';', skiprows=1)
CPati122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Disponibilidades (a)', 'Aplicações Interfinanceiras de Liquidez (b)', 'TVM e Instrumentos Financeiros Derivativos(c)', 'Operações de Crédito (d1)', 'Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito Líquidas de Provisão (d)', 'Arrendamento Mercantil a Receber (e1)', 'Imobilizado de Arrendamento (e2)', 'Credores por Antecipação de Valor Residual (e3)', 'Provisão sobre Arrendamento Mercantil (e4)', 'Arrendamento Mercantil Líquido de Provisão (e)', 'Outros Créditos - Líquido de Provisão (f)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Total Ajustado (i) = (a) + (b) + (c) + (d) + (e) + (f) + (g) + (h)', 'Credores por Antecipação de Valor Residual (j)', 'Ativo Total (k) = (i) - (j)', 'N/A']
CPati122012 = CPati122012.iloc[:, :-1]
CPati122012.dropna(subset=['Data'], inplace=True)
CPati122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPati.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPati_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPati_csv.to_csv('CPati.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPati.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPati.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPati = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPati.csv', sep=';')
CPati1 = CPati[CPati['Ativo Total (k) = (i) - (j)'].str.contains('NI')==False]
CPati1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPati.csv', index=False, encoding='utf-8-sig', sep=';')
display(CPati1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1                                               ITAU
# 2               2                                           BRADESCO
# 3               3                            CAIXA ECONOMICA FEDERAL
# 4               4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# ...           ...                                                ...
# 64141        1338  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
# 64142        1339                                    AVIPAM CC LTDA.
# 64143        1340                                    HR SCMEPP LTDA.
# 64144        1341                                      MEGA CC LTDA.
# 64145        1342  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
#
#              Código  TCB   SR TD   TC          Cidade  UF     Data  ...  \
# ...

# %%
# Conglomerados Financeiros e Instituições Independentes - Carteira de Crédito Classificada por Região Geográfica
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CFreg122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CFreg.csv', sep=';')
CFreg122023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122023 = CFreg122023.iloc[:, :-1]
CFreg122023.dropna(subset=['Data'], inplace=True)
CFreg122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CFreg.csv', sep=',')
CFreg092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CFreg.csv', sep=';')
CFreg092023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092023 = CFreg092023.iloc[:, :-1]
CFreg092023.dropna(subset=['Data'], inplace=True)
CFreg092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CFreg.csv', sep=',')
CFreg062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CFreg.csv', sep=';')
CFreg062023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062023 = CFreg062023.iloc[:, :-1]
CFreg062023.dropna(subset=['Data'], inplace=True)
CFreg062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CFreg.csv', sep=',')
CFreg032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CFreg.csv', sep=';')
CFreg032023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032023 = CFreg032023.iloc[:, :-1]
CFreg032023.dropna(subset=['Data'], inplace=True)
CFreg032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CFreg.csv', sep=',')
CFreg122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CFreg.csv', sep=';')
CFreg122022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122022 = CFreg122022.iloc[:, :-1]
CFreg122022.dropna(subset=['Data'], inplace=True)
CFreg122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CFreg.csv', sep=',')
CFreg092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CFreg.csv', sep=';')
CFreg092022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092022 = CFreg092022.iloc[:, :-1]
CFreg092022.dropna(subset=['Data'], inplace=True)
CFreg092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CFreg.csv', sep=',')
CFreg062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CFreg.csv', sep=';')
CFreg062022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062022 = CFreg062022.iloc[:, :-1]
CFreg062022.dropna(subset=['Data'], inplace=True)
CFreg062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CFreg.csv', sep=',')
CFreg032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CFreg.csv', sep=';')
CFreg032022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032022 = CFreg032022.iloc[:, :-1]
CFreg032022.dropna(subset=['Data'], inplace=True)
CFreg032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CFreg.csv', sep=',')
CFreg122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CFreg.csv', sep=';')
CFreg122021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122021 = CFreg122021.iloc[:, :-1]
CFreg122021.dropna(subset=['Data'], inplace=True)
CFreg122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CFreg.csv', sep=',')
CFreg092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CFreg.csv', sep=';')
CFreg092021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092021 = CFreg092021.iloc[:, :-1]
CFreg092021.dropna(subset=['Data'], inplace=True)
CFreg092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CFreg.csv', sep=',')
CFreg062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CFreg.csv', sep=';')
CFreg062021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062021 = CFreg062021.iloc[:, :-1]
CFreg062021.dropna(subset=['Data'], inplace=True)
CFreg062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CFreg.csv', sep=',')
CFreg032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CFreg.csv', sep=';')
CFreg032021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032021 = CFreg032021.iloc[:, :-1]
CFreg032021.dropna(subset=['Data'], inplace=True)
CFreg032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CFreg.csv', sep=',')
CFreg122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CFreg.csv', sep=';')
CFreg122020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122020 = CFreg122020.iloc[:, :-1]
CFreg122020.dropna(subset=['Data'], inplace=True)
CFreg122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CFreg.csv', sep=',')
CFreg092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CFreg.csv', sep=';')
CFreg092020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092020 = CFreg092020.iloc[:, :-1]
CFreg092020.dropna(subset=['Data'], inplace=True)
CFreg092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CFreg.csv', sep=',')
CFreg062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CFreg.csv', sep=';')
CFreg062020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062020 = CFreg062020.iloc[:, :-1]
CFreg062020.dropna(subset=['Data'], inplace=True)
CFreg062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CFreg.csv', sep=',')
CFreg032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CFreg.csv', sep=';')
CFreg032020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032020 = CFreg032020.iloc[:, :-1]
CFreg032020.dropna(subset=['Data'], inplace=True)
CFreg032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CFreg.csv', sep=',')
CFreg122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CFreg.csv', sep=';')
CFreg122019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122019 = CFreg122019.iloc[:, :-1]
CFreg122019.dropna(subset=['Data'], inplace=True)
CFreg122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CFreg.csv', sep=',')
CFreg092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CFreg.csv', sep=';')
CFreg092019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092019 = CFreg092019.iloc[:, :-1]
CFreg092019.dropna(subset=['Data'], inplace=True)
CFreg092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CFreg.csv', sep=',')
CFreg062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CFreg.csv', sep=';')
CFreg062019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062019 = CFreg062019.iloc[:, :-1]
CFreg062019.dropna(subset=['Data'], inplace=True)
CFreg062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CFreg.csv', sep=',')
CFreg032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CFreg.csv', sep=';')
CFreg032019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032019 = CFreg032019.iloc[:, :-1]
CFreg032019.dropna(subset=['Data'], inplace=True)
CFreg032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CFreg.csv', sep=',')
CFreg122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CFreg.csv', sep=';')
CFreg122018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122018 = CFreg122018.iloc[:, :-1]
CFreg122018.dropna(subset=['Data'], inplace=True)
CFreg122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CFreg.csv', sep=',')
CFreg092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CFreg.csv', sep=';')
CFreg092018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092018 = CFreg092018.iloc[:, :-1]
CFreg092018.dropna(subset=['Data'], inplace=True)
CFreg092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CFreg.csv', sep=',')
CFreg062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CFreg.csv', sep=';')
CFreg062018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062018 = CFreg062018.iloc[:, :-1]
CFreg062018.dropna(subset=['Data'], inplace=True)
CFreg062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CFreg.csv', sep=',')
CFreg032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CFreg.csv', sep=';')
CFreg032018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032018 = CFreg032018.iloc[:, :-1]
CFreg032018.dropna(subset=['Data'], inplace=True)
CFreg032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CFreg.csv', sep=',')
CFreg122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CFreg.csv', sep=';')
CFreg122017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122017 = CFreg122017.iloc[:, :-1]
CFreg122017.dropna(subset=['Data'], inplace=True)
CFreg122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CFreg.csv', sep=',')
CFreg092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CFreg.csv', sep=';')
CFreg092017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092017 = CFreg092017.iloc[:, :-1]
CFreg092017.dropna(subset=['Data'], inplace=True)
CFreg092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CFreg.csv', sep=',')
CFreg062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CFreg.csv', sep=';')
CFreg062017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062017 = CFreg062017.iloc[:, :-1]
CFreg062017.dropna(subset=['Data'], inplace=True)
CFreg062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CFreg.csv', sep=',')
CFreg032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CFreg.csv', sep=';')
CFreg032017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032017 = CFreg032017.iloc[:, :-1]
CFreg032017.dropna(subset=['Data'], inplace=True)
CFreg032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CFreg.csv', sep=',')
CFreg122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CFreg.csv', sep=';')
CFreg122016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122016 = CFreg122016.iloc[:, :-1]
CFreg122016.dropna(subset=['Data'], inplace=True)
CFreg122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CFreg.csv', sep=',')
CFreg092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CFreg.csv', sep=';')
CFreg092016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092016 = CFreg092016.iloc[:, :-1]
CFreg092016.dropna(subset=['Data'], inplace=True)
CFreg092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CFreg.csv', sep=',')
CFreg062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CFreg.csv', sep=';')
CFreg062016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062016 = CFreg062016.iloc[:, :-1]
CFreg062016.dropna(subset=['Data'], inplace=True)
CFreg062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CFreg.csv', sep=',')
CFreg032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CFreg.csv', sep=';')
CFreg032016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032016 = CFreg032016.iloc[:, :-1]
CFreg032016.dropna(subset=['Data'], inplace=True)
CFreg032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CFreg.csv', sep=',')
CFreg122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CFreg.csv', sep=';')
CFreg122015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122015 = CFreg122015.iloc[:, :-1]
CFreg122015.dropna(subset=['Data'], inplace=True)
CFreg122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CFreg.csv', sep=',')
CFreg092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CFreg.csv', sep=';')
CFreg092015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092015 = CFreg092015.iloc[:, :-1]
CFreg092015.dropna(subset=['Data'], inplace=True)
CFreg092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CFreg.csv', sep=',')
CFreg062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CFreg.csv', sep=';')
CFreg062015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062015 = CFreg062015.iloc[:, :-1]
CFreg062015.dropna(subset=['Data'], inplace=True)
CFreg062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CFreg.csv', sep=',')
CFreg032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CFreg.csv', sep=';')
CFreg032015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032015 = CFreg032015.iloc[:, :-1]
CFreg032015.dropna(subset=['Data'], inplace=True)
CFreg032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CFreg.csv', sep=',')
CFreg122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CFreg.csv', sep=';')
CFreg122014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122014 = CFreg122014.iloc[:, :-1]
CFreg122014.dropna(subset=['Data'], inplace=True)
CFreg122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CFreg.csv', sep=',')
CFreg092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CFreg.csv', sep=';')
CFreg092014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092014 = CFreg092014.iloc[:, :-1]
CFreg092014.dropna(subset=['Data'], inplace=True)
CFreg092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CFreg.csv', sep=',')
# Arquivo de 06/2014 não disponível no Banco Central do Brasil
CFreg062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CFreg.csv', sep=';')
CFreg062014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior']
CFreg062014 = CFreg062014.iloc[:, :-1]
CFreg062014.dropna(subset=['Data'], inplace=True)
CFreg062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CFreg.csv', sep=',')
CFreg032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CFreg.csv', sep=';')
CFreg032014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032014 = CFreg032014.iloc[:, :-1]
CFreg032014.dropna(subset=['Data'], inplace=True)
CFreg032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CFreg.csv', sep=',')
CFreg122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CFreg.csv', sep=';')
CFreg122013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122013 = CFreg122013.iloc[:, :-1]
CFreg122013.dropna(subset=['Data'], inplace=True)
CFreg122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CFreg.csv', sep=',')
CFreg092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CFreg.csv', sep=';')
CFreg092013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg092013 = CFreg092013.iloc[:, :-1]
CFreg092013.dropna(subset=['Data'], inplace=True)
CFreg092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CFreg.csv', sep=',')
CFreg062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CFreg.csv', sep=';')
CFreg062013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg062013 = CFreg062013.iloc[:, :-1]
CFreg062013.dropna(subset=['Data'], inplace=True)
CFreg062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CFreg.csv', sep=',')
CFreg032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CFreg.csv', sep=';')
CFreg032013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg032013 = CFreg032013.iloc[:, :-1]
CFreg032013.dropna(subset=['Data'], inplace=True)
CFreg032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CFreg.csv', sep=',')
CFreg122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CFreg.csv', sep=';')
CFreg122012.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Região Sudeste', 'Região Centro-Oeste', 'Região Nordeste', 'Região Norte', 'Região Sul', 'Região Não Informada', 'Exterior', 'N/A']
CFreg122012 = CFreg122012.iloc[:, :-1]
CFreg122012.dropna(subset=['Data'], inplace=True)
CFreg122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CFreg.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CFreg_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CFreg_csv.to_csv('CFreg.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CFreg.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CFreg = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv', sep=';')
CFreg1 = CFreg[CFreg['Carteira de Crédito Classificada'].str.contains('NI')==False]
CFreg1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv', index=False, encoding='utf-8-sig', sep=';')
CFreg = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv', sep=';')
CFreg2 = CFreg[CFreg['Região Sul'].str.contains('NI')==False]
CFreg2.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv', index=False, encoding='utf-8-sig', sep=';')
display(CFreg2)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1                                               ITAU
# 2               2                            CAIXA ECONOMICA FEDERAL
# 3               3                                           BRADESCO
# 4               4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# ...           ...                                                ...
# 58008        1239  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 58009        1240  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 58032        1263            NUMBRS SOCIEDADE DE CRÉDITO DIRETO S.A.
# 58131        1362  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 58141        1372  SOLIDEZ - CORRETORA DE CÂMBIO, TÍTULOS E VALOR...
#
#            Código  TCB TD       TC   SR   Segmento          Cidade  UF  \
# ...

# %%
# Conglomerados Financeiros e Instituições Independentes - Carteira de Crédito Classificada (de Pessoa Física) por modalidade e prazo de vencimento
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CFcpf122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CFcpf.csv', sep=';', skiprows=1)
CFcpf122023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122023 = CFcpf122023.iloc[:, :-1]
CFcpf122023.dropna(subset=['Data'], inplace=True)
CFcpf122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CFcpf.csv', sep=',')
CFcpf092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CFcpf.csv', sep=';', skiprows=1)
CFcpf092023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092023 = CFcpf092023.iloc[:, :-1]
CFcpf092023.dropna(subset=['Data'], inplace=True)
CFcpf092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CFcpf.csv', sep=',')
CFcpf062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CFcpf.csv', sep=';', skiprows=1)
CFcpf062023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062023 = CFcpf062023.iloc[:, :-1]
CFcpf062023.dropna(subset=['Data'], inplace=True)
CFcpf062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CFcpf.csv', sep=',')
CFcpf032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CFcpf.csv', sep=';', skiprows=1)
CFcpf032023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032023 = CFcpf032023.iloc[:, :-1]
CFcpf032023.dropna(subset=['Data'], inplace=True)
CFcpf032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CFcpf.csv', sep=',')
CFcpf122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CFcpf.csv', sep=';', skiprows=1)
CFcpf122022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122022 = CFcpf122022.iloc[:, :-1]
CFcpf122022.dropna(subset=['Data'], inplace=True)
CFcpf122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CFcpf.csv', sep=',')
CFcpf092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CFcpf.csv', sep=';', skiprows=1)
CFcpf092022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092022 = CFcpf092022.iloc[:, :-1]
CFcpf092022.dropna(subset=['Data'], inplace=True)
CFcpf092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CFcpf.csv', sep=',')
CFcpf062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CFcpf.csv', sep=';', skiprows=1)
CFcpf062022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062022 = CFcpf062022.iloc[:, :-1]
CFcpf062022.dropna(subset=['Data'], inplace=True)
CFcpf062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CFcpf.csv', sep=',')
CFcpf032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CFcpf.csv', sep=';', skiprows=1)
CFcpf032022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032022 = CFcpf032022.iloc[:, :-1]
CFcpf032022.dropna(subset=['Data'], inplace=True)
CFcpf032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CFcpf.csv', sep=',')
CFcpf122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CFcpf.csv', sep=';', skiprows=1)
CFcpf122021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122021 = CFcpf122021.iloc[:, :-1]
CFcpf122021.dropna(subset=['Data'], inplace=True)
CFcpf122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CFcpf.csv', sep=',')
CFcpf092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CFcpf.csv', sep=';', skiprows=1)
CFcpf092021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092021 = CFcpf092021.iloc[:, :-1]
CFcpf092021.dropna(subset=['Data'], inplace=True)
CFcpf092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CFcpf.csv', sep=',')
CFcpf062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CFcpf.csv', sep=';', skiprows=1)
CFcpf062021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062021 = CFcpf062021.iloc[:, :-1]
CFcpf062021.dropna(subset=['Data'], inplace=True)
CFcpf062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CFcpf.csv', sep=',')
CFcpf032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CFcpf.csv', sep=';', skiprows=1)
CFcpf032021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032021 = CFcpf032021.iloc[:, :-1]
CFcpf032021.dropna(subset=['Data'], inplace=True)
CFcpf032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CFcpf.csv', sep=',')
CFcpf122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CFcpf.csv', sep=';', skiprows=1)
CFcpf122020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122020 = CFcpf122020.iloc[:, :-1]
CFcpf122020.dropna(subset=['Data'], inplace=True)
CFcpf122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CFcpf.csv', sep=',')
CFcpf092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CFcpf.csv', sep=';', skiprows=1)
CFcpf092020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092020 = CFcpf092020.iloc[:, :-1]
CFcpf092020.dropna(subset=['Data'], inplace=True)
CFcpf092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CFcpf.csv', sep=',')
CFcpf062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CFcpf.csv', sep=';', skiprows=1)
CFcpf062020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062020 = CFcpf062020.iloc[:, :-1]
CFcpf062020.dropna(subset=['Data'], inplace=True)
CFcpf062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CFcpf.csv', sep=',')
CFcpf032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CFcpf.csv', sep=';', skiprows=1)
CFcpf032020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032020 = CFcpf032020.iloc[:, :-1]
CFcpf032020.dropna(subset=['Data'], inplace=True)
CFcpf032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CFcpf.csv', sep=',')
CFcpf122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CFcpf.csv', sep=';', skiprows=1)
CFcpf122019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122019 = CFcpf122019.iloc[:, :-1]
CFcpf122019.dropna(subset=['Data'], inplace=True)
CFcpf122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CFcpf.csv', sep=',')
CFcpf092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CFcpf.csv', sep=';', skiprows=1)
CFcpf092019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092019 = CFcpf092019.iloc[:, :-1]
CFcpf092019.dropna(subset=['Data'], inplace=True)
CFcpf092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CFcpf.csv', sep=',')
CFcpf062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CFcpf.csv', sep=';', skiprows=1)
CFcpf062019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062019 = CFcpf062019.iloc[:, :-1]
CFcpf062019.dropna(subset=['Data'], inplace=True)
CFcpf062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CFcpf.csv', sep=',')
CFcpf032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CFcpf.csv', sep=';', skiprows=1)
CFcpf032019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032019 = CFcpf032019.iloc[:, :-1]
CFcpf032019.dropna(subset=['Data'], inplace=True)
CFcpf032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CFcpf.csv', sep=',')
CFcpf122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CFcpf.csv', sep=';', skiprows=1)
CFcpf122018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122018 = CFcpf122018.iloc[:, :-1]
CFcpf122018.dropna(subset=['Data'], inplace=True)
CFcpf122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CFcpf.csv', sep=',')
CFcpf092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CFcpf.csv', sep=';', skiprows=1)
CFcpf092018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092018 = CFcpf092018.iloc[:, :-1]
CFcpf092018.dropna(subset=['Data'], inplace=True)
CFcpf092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CFcpf.csv', sep=',')
CFcpf062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CFcpf.csv', sep=';', skiprows=1)
CFcpf062018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062018 = CFcpf062018.iloc[:, :-1]
CFcpf062018.dropna(subset=['Data'], inplace=True)
CFcpf062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CFcpf.csv', sep=',')
CFcpf032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CFcpf.csv', sep=';', skiprows=1)
CFcpf032018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032018 = CFcpf032018.iloc[:, :-1]
CFcpf032018.dropna(subset=['Data'], inplace=True)
CFcpf032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CFcpf.csv', sep=',')
CFcpf122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CFcpf.csv', sep=';', skiprows=1)
CFcpf122017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122017 = CFcpf122017.iloc[:, :-1]
CFcpf122017.dropna(subset=['Data'], inplace=True)
CFcpf122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CFcpf.csv', sep=',')
CFcpf092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CFcpf.csv', sep=';', skiprows=1)
CFcpf092017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092017 = CFcpf092017.iloc[:, :-1]
CFcpf092017.dropna(subset=['Data'], inplace=True)
CFcpf092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CFcpf.csv', sep=',')
CFcpf062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CFcpf.csv', sep=';', skiprows=1)
CFcpf062017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062017 = CFcpf062017.iloc[:, :-1]
CFcpf062017.dropna(subset=['Data'], inplace=True)
CFcpf062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CFcpf.csv', sep=',')
CFcpf032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CFcpf.csv', sep=';', skiprows=1)
CFcpf032017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032017 = CFcpf032017.iloc[:, :-1]
CFcpf032017.dropna(subset=['Data'], inplace=True)
CFcpf032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CFcpf.csv', sep=',')
CFcpf122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CFcpf.csv', sep=';', skiprows=1)
CFcpf122016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122016 = CFcpf122016.iloc[:, :-1]
CFcpf122016.dropna(subset=['Data'], inplace=True)
CFcpf122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CFcpf.csv', sep=',')
CFcpf092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CFcpf.csv', sep=';', skiprows=1)
CFcpf092016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092016 = CFcpf092016.iloc[:, :-1]
CFcpf092016.dropna(subset=['Data'], inplace=True)
CFcpf092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CFcpf.csv', sep=',')
CFcpf062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CFcpf.csv', sep=';', skiprows=1)
CFcpf062016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062016 = CFcpf062016.iloc[:, :-1]
CFcpf062016.dropna(subset=['Data'], inplace=True)
CFcpf062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CFcpf.csv', sep=',')
CFcpf032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CFcpf.csv', sep=';', skiprows=1)
CFcpf032016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032016 = CFcpf032016.iloc[:, :-1]
CFcpf032016.dropna(subset=['Data'], inplace=True)
CFcpf032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CFcpf.csv', sep=',')
CFcpf122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CFcpf.csv', sep=';', skiprows=1)
CFcpf122015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122015 = CFcpf122015.iloc[:, :-1]
CFcpf122015.dropna(subset=['Data'], inplace=True)
CFcpf122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CFcpf.csv', sep=',')
CFcpf092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CFcpf.csv', sep=';', skiprows=1)
CFcpf092015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092015 = CFcpf092015.iloc[:, :-1]
CFcpf092015.dropna(subset=['Data'], inplace=True)
CFcpf092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CFcpf.csv', sep=',')
CFcpf062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CFcpf.csv', sep=';', skiprows=1)
CFcpf062015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062015 = CFcpf062015.iloc[:, :-1]
CFcpf062015.dropna(subset=['Data'], inplace=True)
CFcpf062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CFcpf.csv', sep=',')
CFcpf032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CFcpf.csv', sep=';', skiprows=1)
CFcpf032015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032015 = CFcpf032015.iloc[:, :-1]
CFcpf032015.dropna(subset=['Data'], inplace=True)
CFcpf032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CFcpf.csv', sep=',')
CFcpf122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CFcpf.csv', sep=';', skiprows=1)
CFcpf122014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122014 = CFcpf122014.iloc[:, :-1]
CFcpf122014.dropna(subset=['Data'], inplace=True)
CFcpf122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CFcpf.csv', sep=',')
CFcpf092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CFcpf.csv', sep=';', skiprows=1)
CFcpf092014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092014 = CFcpf092014.iloc[:, :-1]
CFcpf092014.dropna(subset=['Data'], inplace=True)
CFcpf092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CFcpf.csv', sep=',')
CFcpf062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CFcpf.csv', sep=';', skiprows=1)
CFcpf062014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062014 = CFcpf062014.iloc[:, :-1]
CFcpf062014.dropna(subset=['Data'], inplace=True)
CFcpf062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CFcpf.csv', sep=',')
CFcpf032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CFcpf.csv', sep=';', skiprows=1)
CFcpf032014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032014 = CFcpf032014.iloc[:, :-1]
CFcpf032014.dropna(subset=['Data'], inplace=True)
CFcpf032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CFcpf.csv', sep=',')
CFcpf122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CFcpf.csv', sep=';', skiprows=1)
CFcpf122013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122013 = CFcpf122013.iloc[:, :-1]
CFcpf122013.dropna(subset=['Data'], inplace=True)
CFcpf122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CFcpf.csv', sep=',')
CFcpf092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CFcpf.csv', sep=';', skiprows=1)
CFcpf092013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf092013 = CFcpf092013.iloc[:, :-1]
CFcpf092013.dropna(subset=['Data'], inplace=True)
CFcpf092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CFcpf.csv', sep=',')
CFcpf062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CFcpf.csv', sep=';', skiprows=1)
CFcpf062013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf062013 = CFcpf062013.iloc[:, :-1]
CFcpf062013.dropna(subset=['Data'], inplace=True)
CFcpf062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CFcpf.csv', sep=',')
CFcpf032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CFcpf.csv', sep=';', skiprows=1)
CFcpf032013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf032013 = CFcpf032013.iloc[:, :-1]
CFcpf032013.dropna(subset=['Data'], inplace=True)
CFcpf032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CFcpf.csv', sep=',')
CFcpf122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CFcpf.csv', sep=';', skiprows=1)
CFcpf122012.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Física)', 'Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo com Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo com Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo com Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo com Consignação em Folha - Total', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - A Vencer em até 90 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 91 a 360 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 361 a 1080 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1081 a 1800 Dias', 'Empréstimo sem Consignação em Folha - A Vencer Entre 1801 a 5400 Dias', 'Empréstimo sem Consignação em Folha - A vencer Acima de 5400 Dias', 'Empréstimo sem Consignação em Folha - Total', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - A Vencer em até 90 Dias', 'Financiamento de Veículos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Veículos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Veículos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Veículos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Veículos - A vencer Acima de 5400 Dias', 'Financiamento de Veículos - Total', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - A Vencer em até 90 Dias', 'Financiamento Habitacional - A Vencer Entre 91 a 360 Dias', 'Financiamento Habitacional - A Vencer Entre 361 a 1080 Dias', 'Financiamento Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Habitacional - A vencer Acima de 5400 Dias', 'Financiamento Habitacional - Total', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Cartão de Crédito - A Vencer em até 90 Dias', 'Cartão de Crédito - A Vencer Entre 91 a 360 Dias', 'Cartão de Crédito - A Vencer Entre 361 a 1080 Dias', 'Cartão de Crédito - A Vencer Entre 1081 a 1800 Dias', 'Cartão de Crédito - A Vencer Entre 1801 a 5400 Dias', 'Cartão de Crédito - A vencer Acima de 5400 Dias', 'Cartão de Crédito - Total', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - A Vencer em até 90 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Financiamento Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Financiamento Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Financiamento Rural e Agroindustrial - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Créditos no Exterior PF', 'N/A']
CFcpf122012 = CFcpf122012.iloc[:, :-1]
CFcpf122012.dropna(subset=['Data'], inplace=True)
CFcpf122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CFcpf.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CFcpf_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CFcpf_csv.to_csv('CFcpf.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CFcpf.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CFcpf = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', sep=';')
CFcpf1 = CFcpf[CFcpf['Carteira de Crédito Classificada (de Pessoa Física)'].str.contains('NI')==False]
CFcpf1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', index=False, encoding='utf-8-sig', sep=';')
CFcpf = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', sep=';')
CFcpf2 = CFcpf[CFcpf['Empréstimo com Consignação em Folha - Total'].str.contains('NI')==False]
CFcpf2.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', index=False, encoding='utf-8-sig', sep=';')
CFcpf = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', sep=';')
CFcpf3 = CFcpf[CFcpf['Financiamento Rural e Agroindustrial - Total'].str.contains('NI')==False]
CFcpf3.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', index=False, encoding='utf-8-sig', sep=';')
display(CFcpf3)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
# C:\Users\mvrgu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0                                        Instituição  \
# 0               0                            CAIXA ECONOMICA FEDERAL
# 1               1                                                 BB
# 2               2                                               ITAU
# 3               3                                           BRADESCO
# 4               4                                          SANTANDER
# ...           ...                                                ...
# 55329        1356                  BANCO CRÉDIT AGRICOLE BRASIL S.A.
# 55330        1359  COOPERATIVA CENTRAL DE CRÉDITO DE SANTA CATARI...
# 55331        1361  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# ...

# %%
# Conglomerados Financeiros e Instituições Independentes - Carteira de Crédito Classificada (de Pessoa Jurídica) por modalidade e prazo de vencimento
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CFcpj122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CFcpj.csv', sep=';', skiprows=1)
CFcpj122023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122023 = CFcpj122023.iloc[:, :-1]
CFcpj122023.dropna(subset=['Data'], inplace=True)
CFcpj122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CFcpj.csv', sep=',')
CFcpj092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CFcpj.csv', sep=';', skiprows=1)
CFcpj092023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092023 = CFcpj092023.iloc[:, :-1]
CFcpj092023.dropna(subset=['Data'], inplace=True)
CFcpj092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CFcpj.csv', sep=',')
CFcpj062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CFcpj.csv', sep=';', skiprows=1)
CFcpj062023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062023 = CFcpj062023.iloc[:, :-1]
CFcpj062023.dropna(subset=['Data'], inplace=True)
CFcpj062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CFcpj.csv', sep=',')
CFcpj032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CFcpj.csv', sep=';', skiprows=1)
CFcpj032023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032023 = CFcpj032023.iloc[:, :-1]
CFcpj032023.dropna(subset=['Data'], inplace=True)
CFcpj032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CFcpj.csv', sep=',')
CFcpj122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CFcpj.csv', sep=';', skiprows=1)
CFcpj122022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122022 = CFcpj122022.iloc[:, :-1]
CFcpj122022.dropna(subset=['Data'], inplace=True)
CFcpj122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CFcpj.csv', sep=',')
CFcpj092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CFcpj.csv', sep=';', skiprows=1)
CFcpj092022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092022 = CFcpj092022.iloc[:, :-1]
CFcpj092022.dropna(subset=['Data'], inplace=True)
CFcpj092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CFcpj.csv', sep=',')
CFcpj062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CFcpj.csv', sep=';', skiprows=1)
CFcpj062022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062022 = CFcpj062022.iloc[:, :-1]
CFcpj062022.dropna(subset=['Data'], inplace=True)
CFcpj062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CFcpj.csv', sep=',')
CFcpj032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CFcpj.csv', sep=';', skiprows=1)
CFcpj032022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032022 = CFcpj032022.iloc[:, :-1]
CFcpj032022.dropna(subset=['Data'], inplace=True)
CFcpj032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CFcpj.csv', sep=',')
CFcpj122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CFcpj.csv', sep=';', skiprows=1)
CFcpj122021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122021 = CFcpj122021.iloc[:, :-1]
CFcpj122021.dropna(subset=['Data'], inplace=True)
CFcpj122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CFcpj.csv', sep=',')
CFcpj092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CFcpj.csv', sep=';', skiprows=1)
CFcpj092021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092021 = CFcpj092021.iloc[:, :-1]
CFcpj092021.dropna(subset=['Data'], inplace=True)
CFcpj092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CFcpj.csv', sep=',')
CFcpj062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CFcpj.csv', sep=';', skiprows=1)
CFcpj062021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062021 = CFcpj062021.iloc[:, :-1]
CFcpj062021.dropna(subset=['Data'], inplace=True)
CFcpj062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CFcpj.csv', sep=',')
CFcpj032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CFcpj.csv', sep=';', skiprows=1)
CFcpj032021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032021 = CFcpj032021.iloc[:, :-1]
CFcpj032021.dropna(subset=['Data'], inplace=True)
CFcpj032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CFcpj.csv', sep=',')
CFcpj122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CFcpj.csv', sep=';', skiprows=1)
CFcpj122020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122020 = CFcpj122020.iloc[:, :-1]
CFcpj122020.dropna(subset=['Data'], inplace=True)
CFcpj122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CFcpj.csv', sep=',')
CFcpj092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CFcpj.csv', sep=';', skiprows=1)
CFcpj092020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092020 = CFcpj092020.iloc[:, :-1]
CFcpj092020.dropna(subset=['Data'], inplace=True)
CFcpj092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CFcpj.csv', sep=',')
CFcpj062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CFcpj.csv', sep=';', skiprows=1)
CFcpj062020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062020 = CFcpj062020.iloc[:, :-1]
CFcpj062020.dropna(subset=['Data'], inplace=True)
CFcpj062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CFcpj.csv', sep=',')
CFcpj032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CFcpj.csv', sep=';', skiprows=1)
CFcpj032020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032020 = CFcpj032020.iloc[:, :-1]
CFcpj032020.dropna(subset=['Data'], inplace=True)
CFcpj032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CFcpj.csv', sep=',')
CFcpj122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CFcpj.csv', sep=';', skiprows=1)
CFcpj122019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122019 = CFcpj122019.iloc[:, :-1]
CFcpj122019.dropna(subset=['Data'], inplace=True)
CFcpj122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CFcpj.csv', sep=',')
CFcpj092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CFcpj.csv', sep=';', skiprows=1)
CFcpj092019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092019 = CFcpj092019.iloc[:, :-1]
CFcpj092019.dropna(subset=['Data'], inplace=True)
CFcpj092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CFcpj.csv', sep=',')
CFcpj062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CFcpj.csv', sep=';', skiprows=1)
CFcpj062019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062019 = CFcpj062019.iloc[:, :-1]
CFcpj062019.dropna(subset=['Data'], inplace=True)
CFcpj062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CFcpj.csv', sep=',')
CFcpj032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CFcpj.csv', sep=';', skiprows=1)
CFcpj032019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032019 = CFcpj032019.iloc[:, :-1]
CFcpj032019.dropna(subset=['Data'], inplace=True)
CFcpj032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CFcpj.csv', sep=',')
CFcpj122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CFcpj.csv', sep=';', skiprows=1)
CFcpj122018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122018 = CFcpj122018.iloc[:, :-1]
CFcpj122018.dropna(subset=['Data'], inplace=True)
CFcpj122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CFcpj.csv', sep=',')
CFcpj092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CFcpj.csv', sep=';', skiprows=1)
CFcpj092018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092018 = CFcpj092018.iloc[:, :-1]
CFcpj092018.dropna(subset=['Data'], inplace=True)
CFcpj092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CFcpj.csv', sep=',')
CFcpj062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CFcpj.csv', sep=';', skiprows=1)
CFcpj062018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062018 = CFcpj062018.iloc[:, :-1]
CFcpj062018.dropna(subset=['Data'], inplace=True)
CFcpj062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CFcpj.csv', sep=',')
CFcpj032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CFcpj.csv', sep=';', skiprows=1)
CFcpj032018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032018 = CFcpj032018.iloc[:, :-1]
CFcpj032018.dropna(subset=['Data'], inplace=True)
CFcpj032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CFcpj.csv', sep=',')
CFcpj122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CFcpj.csv', sep=';', skiprows=1)
CFcpj122017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122017 = CFcpj122017.iloc[:, :-1]
CFcpj122017.dropna(subset=['Data'], inplace=True)
CFcpj122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CFcpj.csv', sep=',')
CFcpj092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CFcpj.csv', sep=';', skiprows=1)
CFcpj092017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092017 = CFcpj092017.iloc[:, :-1]
CFcpj092017.dropna(subset=['Data'], inplace=True)
CFcpj092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CFcpj.csv', sep=',')
CFcpj062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CFcpj.csv', sep=';', skiprows=1)
CFcpj062017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062017 = CFcpj062017.iloc[:, :-1]
CFcpj062017.dropna(subset=['Data'], inplace=True)
CFcpj062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CFcpj.csv', sep=',')
CFcpj032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CFcpj.csv', sep=';', skiprows=1)
CFcpj032017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032017 = CFcpj032017.iloc[:, :-1]
CFcpj032017.dropna(subset=['Data'], inplace=True)
CFcpj032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CFcpj.csv', sep=',')
CFcpj122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CFcpj.csv', sep=';', skiprows=1)
CFcpj122016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122016 = CFcpj122016.iloc[:, :-1]
CFcpj122016.dropna(subset=['Data'], inplace=True)
CFcpj122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CFcpj.csv', sep=',')
CFcpj092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CFcpj.csv', sep=';', skiprows=1)
CFcpj092016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092016 = CFcpj092016.iloc[:, :-1]
CFcpj092016.dropna(subset=['Data'], inplace=True)
CFcpj092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CFcpj.csv', sep=',')
CFcpj062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CFcpj.csv', sep=';', skiprows=1)
CFcpj062016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062016 = CFcpj062016.iloc[:, :-1]
CFcpj062016.dropna(subset=['Data'], inplace=True)
CFcpj062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CFcpj.csv', sep=',')
CFcpj032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CFcpj.csv', sep=';', skiprows=1)
CFcpj032016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032016 = CFcpj032016.iloc[:, :-1]
CFcpj032016.dropna(subset=['Data'], inplace=True)
CFcpj032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CFcpj.csv', sep=',')
CFcpj122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CFcpj.csv', sep=';', skiprows=1)
CFcpj122015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122015 = CFcpj122015.iloc[:, :-1]
CFcpj122015.dropna(subset=['Data'], inplace=True)
CFcpj122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CFcpj.csv', sep=',')
CFcpj092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CFcpj.csv', sep=';', skiprows=1)
CFcpj092015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092015 = CFcpj092015.iloc[:, :-1]
CFcpj092015.dropna(subset=['Data'], inplace=True)
CFcpj092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CFcpj.csv', sep=',')
CFcpj062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CFcpj.csv', sep=';', skiprows=1)
CFcpj062015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062015 = CFcpj062015.iloc[:, :-1]
CFcpj062015.dropna(subset=['Data'], inplace=True)
CFcpj062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CFcpj.csv', sep=',')
CFcpj032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CFcpj.csv', sep=';', skiprows=1)
CFcpj032015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032015 = CFcpj032015.iloc[:, :-1]
CFcpj032015.dropna(subset=['Data'], inplace=True)
CFcpj032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CFcpj.csv', sep=',')
CFcpj122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CFcpj.csv', sep=';', skiprows=1)
CFcpj122014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122014 = CFcpj122014.iloc[:, :-1]
CFcpj122014.dropna(subset=['Data'], inplace=True)
CFcpj122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CFcpj.csv', sep=',')
CFcpj092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CFcpj.csv', sep=';', skiprows=1)
CFcpj092014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092014 = CFcpj092014.iloc[:, :-1]
CFcpj092014.dropna(subset=['Data'], inplace=True)
CFcpj092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CFcpj.csv', sep=',')
CFcpj062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CFcpj.csv', sep=';', skiprows=1)
CFcpj062014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062014 = CFcpj062014.iloc[:, :-1]
CFcpj062014.dropna(subset=['Data'], inplace=True)
CFcpj062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CFcpj.csv', sep=',')
CFcpj032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CFcpj.csv', sep=';', skiprows=1)
CFcpj032014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032014 = CFcpj032014.iloc[:, :-1]
CFcpj032014.dropna(subset=['Data'], inplace=True)
CFcpj032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CFcpj.csv', sep=',')
CFcpj122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CFcpj.csv', sep=';', skiprows=1)
CFcpj122013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122013 = CFcpj122013.iloc[:, :-1]
CFcpj122013.dropna(subset=['Data'], inplace=True)
CFcpj122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CFcpj.csv', sep=',')
CFcpj092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CFcpj.csv', sep=';', skiprows=1)
CFcpj092013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj092013 = CFcpj092013.iloc[:, :-1]
CFcpj092013.dropna(subset=['Data'], inplace=True)
CFcpj092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CFcpj.csv', sep=',')
CFcpj062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CFcpj.csv', sep=';', skiprows=1)
CFcpj062013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj062013 = CFcpj062013.iloc[:, :-1]
CFcpj062013.dropna(subset=['Data'], inplace=True)
CFcpj062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CFcpj.csv', sep=',')
CFcpj032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CFcpj.csv', sep=';', skiprows=1)
CFcpj032013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj032013 = CFcpj032013.iloc[:, :-1]
CFcpj032013.dropna(subset=['Data'], inplace=True)
CFcpj032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CFcpj.csv', sep=',')
CFcpj122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CFcpj.csv', sep=';', skiprows=1)
CFcpj122012.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada (de Pessoa Jurídica)', 'Capital de Giro - Vencido a Partir de 15 Dias', 'Capital de Giro - A Vencer em até 90 Dias', 'Capital de Giro - A Vencer Entre 91 a 360 Dias', 'Capital de Giro - A Vencer Entre 361 a 1080 Dias', 'Capital de Giro - A Vencer Entre 1081 a 1800 Dias', 'Capital de Giro - A Vencer Entre 1801 a 5400 Dias', 'Capital de Giro - A vencer Acima de 5400 Dias', 'Capital de Giro - Total', 'Investimento - Vencido a Partir de 15 Dias', 'Investimento - A Vencer em até 90 Dias', 'Investimento - A Vencer Entre 91 a 360 Dias', 'Investimento - A Vencer Entre 361 a 1080 Dias', 'Investimento - A Vencer Entre 1081 a 1800 Dias', 'Investimento - A Vencer Entre 1801 a 5400 Dias', 'Investimento - A vencer Acima de 5400 Dias', 'Investimento - Total', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - A Vencer em até 90 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 91 a 360 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 361 a 1080 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1081 a 1800 Dias', 'Cheque Especial e Conta Garantida - A Vencer Entre 1801 a 5400 Dias', 'Cheque Especial e Conta Garantida - A vencer Acima de 5400 Dias', 'Cheque Especial e Conta Garantida - Total', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - A Vencer em até 90 Dias', 'Operações com Recebíveis - A Vencer Entre 91 a 360 Dias', 'Operações com Recebíveis - A Vencer Entre 361 a 1080 Dias', 'Operações com Recebíveis - A Vencer Entre 1081 a 1800 Dias', 'Operações com Recebíveis - A Vencer Entre 1801 a 5400 Dias', 'Operações com Recebíveis - A vencer Acima de 5400 Dias', 'Operações com Recebíveis - Total', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Comércio Exterior - A Vencer em até 90 Dias', 'Comércio Exterior - A Vencer Entre 91 a 360 Dias', 'Comércio Exterior - A Vencer Entre 361 a 1080 Dias', 'Comércio Exterior - A Vencer Entre 1081 a 1800 Dias', 'Comércio Exterior - A Vencer Entre 1801 a 5400 Dias', 'Comércio Exterior - A vencer Acima de 5400 Dias', 'Comércio Exterior - Total', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Outros Créditos - A Vencer em até 90 Dias', 'Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Outros Créditos - A vencer Acima de 5400 Dias', 'Outros Créditos - Total', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer em até 90 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 91 a 360 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 361 a 1080 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1081 a 1800 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A Vencer Entre 1801 a 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - A vencer Acima de 5400 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Total', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - A Vencer em até 90 Dias', 'Rural e Agroindustrial - A Vencer Entre 91 a 360 Dias', 'Rural e Agroindustrial - A Vencer Entre 361 a 1080 Dias', 'Rural e Agroindustrial - A Vencer Entre 1081 a 1800 Dias', 'Rural e Agroindustrial - A Vencer Entre 1801 a 5400 Dias', 'Rural e Agroindustrial - A vencer Acima de 5400 Dias', 'Rural e Agroindustrial - Total', 'Habitacional - Vencido a Partir de 15 Dias', 'Habitacional - A Vencer em até 90 Dias', 'Habitacional - A Vencer Entre 91 a 360 Dias', 'Habitacional - A Vencer Entre 361 a 1080 Dias', 'Habitacional - A Vencer Entre 1081 a 1800 Dias', 'Habitacional - A Vencer Entre 1801 a 5400 Dias', 'Habitacional - A vencer Acima de 5400 Dias', 'Habitacional - Total', 'Créditos no Exterior PJ', 'N/A']
CFcpj122012 = CFcpj122012.iloc[:, :-1]
CFcpj122012.dropna(subset=['Data'], inplace=True)
CFcpj122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CFcpj.csv', sep=',')    
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CFcpj_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CFcpj_csv.to_csv('CFcpj.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CFcpj.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CFcpj = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv', sep=';')
CFcpj1 = CFcpj[CFcpj['Carteira de Crédito Classificada (de Pessoa Jurídica)'].str.contains('NI')==False]
CFcpj1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv', index=False, encoding='utf-8-sig', sep=';')
CFcpj = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv', sep=';')
CFcpj2 = CFcpj[CFcpj['Capital de Giro - Total'].str.contains('NI')==False]
CFcpj2.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv', index=False, encoding='utf-8-sig', sep=';')
display(CFcpj2)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# 2               2                                               ITAU
# 3               3                                           BRADESCO
# 4               4                            CAIXA ECONOMICA FEDERAL
# ...           ...                                                ...
# 59509        1364  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS TR...
# 59510        1365  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS FU...
# 59511        1366  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS EM...
# 59515        1370  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS EM...
# 59517        1372  SOLIDEZ - CORRETORA DE CÂMBIO, TÍTULOS E VALOR...
#
#            Código  TCB TD       TC   SR   Segmento          Cidade  UF  \
# ...

# %%
# Conglomerados Financeiros e Instituições Independentes - Carteira de Crédito Classificada (por Nível de Risco)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CFris122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CFris.csv', sep=';')
CFris122023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122023 = CFris122023.iloc[:, :-1]
CFris122023.dropna(subset=['Data'], inplace=True)
CFris122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CFris.csv', sep=',')
CFris092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CFris.csv', sep=';')
CFris092023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092023 = CFris092023.iloc[:, :-1]
CFris092023.dropna(subset=['Data'], inplace=True)
CFris092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CFris.csv', sep=',')
CFris062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CFris.csv', sep=';')
CFris062023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062023 = CFris062023.iloc[:, :-1]
CFris062023.dropna(subset=['Data'], inplace=True)
CFris062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CFris.csv', sep=',')
CFris032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CFris.csv', sep=';')
CFris032023.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032023 = CFris032023.iloc[:, :-1]
CFris032023.dropna(subset=['Data'], inplace=True)
CFris032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CFris.csv', sep=',')
CFris122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CFris.csv', sep=';')
CFris122022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122022 = CFris122022.iloc[:, :-1]
CFris122022.dropna(subset=['Data'], inplace=True)
CFris122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CFris.csv', sep=',')
CFris092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CFris.csv', sep=';')
CFris092022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092022 = CFris092022.iloc[:, :-1]
CFris092022.dropna(subset=['Data'], inplace=True)
CFris092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CFris.csv', sep=',')
CFris062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CFris.csv', sep=';')
CFris062022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062022 = CFris062022.iloc[:, :-1]
CFris062022.dropna(subset=['Data'], inplace=True)
CFris062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CFris.csv', sep=',')
CFris032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CFris.csv', sep=';')
CFris032022.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032022 = CFris032022.iloc[:, :-1]
CFris032022.dropna(subset=['Data'], inplace=True)
CFris032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CFris.csv', sep=',')
CFris122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CFris.csv', sep=';')
CFris122021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122021 = CFris122021.iloc[:, :-1]
CFris122021.dropna(subset=['Data'], inplace=True)
CFris122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CFris.csv', sep=',')
CFris092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CFris.csv', sep=';')
CFris092021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092021 = CFris092021.iloc[:, :-1]
CFris092021.dropna(subset=['Data'], inplace=True)
CFris092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CFris.csv', sep=',')
CFris062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CFris.csv', sep=';')
CFris062021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062021 = CFris062021.iloc[:, :-1]
CFris062021.dropna(subset=['Data'], inplace=True)
CFris062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CFris.csv', sep=',')
CFris032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CFris.csv', sep=';')
CFris032021.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032021 = CFris032021.iloc[:, :-1]
CFris032021.dropna(subset=['Data'], inplace=True)
CFris032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CFris.csv', sep=',')
CFris122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CFris.csv', sep=';')
CFris122020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122020 = CFris122020.iloc[:, :-1]
CFris122020.dropna(subset=['Data'], inplace=True)
CFris122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CFris.csv', sep=',')
CFris092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CFris.csv', sep=';')
CFris092020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092020 = CFris092020.iloc[:, :-1]
CFris092020.dropna(subset=['Data'], inplace=True)
CFris092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CFris.csv', sep=',')
CFris062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CFris.csv', sep=';')
CFris062020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062020 = CFris062020.iloc[:, :-1]
CFris062020.dropna(subset=['Data'], inplace=True)
CFris062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CFris.csv', sep=',')
CFris032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CFris.csv', sep=';')
CFris032020.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032020 = CFris032020.iloc[:, :-1]
CFris032020.dropna(subset=['Data'], inplace=True)
CFris032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CFris.csv', sep=',')
CFris122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CFris.csv', sep=';')
CFris122019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122019 = CFris122019.iloc[:, :-1]
CFris122019.dropna(subset=['Data'], inplace=True)
CFris122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CFris.csv', sep=',')
CFris092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CFris.csv', sep=';')
CFris092019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092019 = CFris092019.iloc[:, :-1]
CFris092019.dropna(subset=['Data'], inplace=True)
CFris092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CFris.csv', sep=',')
CFris062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CFris.csv', sep=';')
CFris062019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062019 = CFris062019.iloc[:, :-1]
CFris062019.dropna(subset=['Data'], inplace=True)
CFris062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CFris.csv', sep=',')
CFris032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CFris.csv', sep=';')
CFris032019.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032019 = CFris032019.iloc[:, :-1]
CFris032019.dropna(subset=['Data'], inplace=True)
CFris032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CFris.csv', sep=',')
CFris122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CFris.csv', sep=';')
CFris122018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122018 = CFris122018.iloc[:, :-1]
CFris122018.dropna(subset=['Data'], inplace=True)
CFris122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CFris.csv', sep=',')
CFris092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CFris.csv', sep=';')
CFris092018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092018 = CFris092018.iloc[:, :-1]
CFris092018.dropna(subset=['Data'], inplace=True)
CFris092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CFris.csv', sep=',')
CFris062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CFris.csv', sep=';')
CFris062018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062018 = CFris062018.iloc[:, :-1]
CFris062018.dropna(subset=['Data'], inplace=True)
CFris062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CFris.csv', sep=',')
CFris032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CFris.csv', sep=';')
CFris032018.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032018 = CFris032018.iloc[:, :-1]
CFris032018.dropna(subset=['Data'], inplace=True)
CFris032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CFris.csv', sep=',')
CFris122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CFris.csv', sep=';')
CFris122017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122017 = CFris122017.iloc[:, :-1]
CFris122017.dropna(subset=['Data'], inplace=True)
CFris122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CFris.csv', sep=',')
CFris092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CFris.csv', sep=';')
CFris092017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092017 = CFris092017.iloc[:, :-1]
CFris092017.dropna(subset=['Data'], inplace=True)
CFris092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CFris.csv', sep=',')
CFris062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CFris.csv', sep=';')
CFris062017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062017 = CFris062017.iloc[:, :-1]
CFris062017.dropna(subset=['Data'], inplace=True)
CFris062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CFris.csv', sep=',')
CFris032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CFris.csv', sep=';')
CFris032017.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032017 = CFris032017.iloc[:, :-1]
CFris032017.dropna(subset=['Data'], inplace=True)
CFris032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CFris.csv', sep=',')
CFris122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CFris.csv', sep=';')
CFris122016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122016 = CFris122016.iloc[:, :-1]
CFris122016.dropna(subset=['Data'], inplace=True)
CFris122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CFris.csv', sep=',')
CFris092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CFris.csv', sep=';')
CFris092016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092016 = CFris092016.iloc[:, :-1]
CFris092016.dropna(subset=['Data'], inplace=True)
CFris092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CFris.csv', sep=',')
CFris062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CFris.csv', sep=';')
CFris062016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062016 = CFris062016.iloc[:, :-1]
CFris062016.dropna(subset=['Data'], inplace=True)
CFris062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CFris.csv', sep=',')
CFris032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CFris.csv', sep=';')
CFris032016.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032016 = CFris032016.iloc[:, :-1]
CFris032016.dropna(subset=['Data'], inplace=True)
CFris032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CFris.csv', sep=',')
CFris122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CFris.csv', sep=';')
CFris122015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122015 = CFris122015.iloc[:, :-1]
CFris122015.dropna(subset=['Data'], inplace=True)
CFris122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CFris.csv', sep=',')
CFris092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CFris.csv', sep=';')
CFris092015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092015 = CFris092015.iloc[:, :-1]
CFris092015.dropna(subset=['Data'], inplace=True)
CFris092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CFris.csv', sep=',')
CFris062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CFris.csv', sep=';')
CFris062015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062015 = CFris062015.iloc[:, :-1]
CFris062015.dropna(subset=['Data'], inplace=True)
CFris062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CFris.csv', sep=',')
CFris032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CFris.csv', sep=';')
CFris032015.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032015 = CFris032015.iloc[:, :-1]
CFris032015.dropna(subset=['Data'], inplace=True)
CFris032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CFris.csv', sep=',')
CFris122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CFris.csv', sep=';')
CFris122014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122014 = CFris122014.iloc[:, :-1]
CFris122014.dropna(subset=['Data'], inplace=True)
CFris122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CFris.csv', sep=',')
CFris092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CFris.csv', sep=';')
CFris092014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092014 = CFris092014.iloc[:, :-1]
CFris092014.dropna(subset=['Data'], inplace=True)
CFris092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CFris.csv', sep=',')
CFris062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CFris.csv', sep=';')
CFris062014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062014 = CFris062014.iloc[:, :-1]
CFris062014.dropna(subset=['Data'], inplace=True)
CFris062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CFris.csv', sep=',')
CFris032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CFris.csv', sep=';')
CFris032014.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032014 = CFris032014.iloc[:, :-1]
CFris032014.dropna(subset=['Data'], inplace=True)
CFris032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CFris.csv', sep=',')
CFris122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CFris.csv', sep=';')
CFris122013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122013 = CFris122013.iloc[:, :-1]
CFris122013.dropna(subset=['Data'], inplace=True)
CFris122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CFris.csv', sep=',')
CFris092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CFris.csv', sep=';')
CFris092013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris092013 = CFris092013.iloc[:, :-1]
CFris092013.dropna(subset=['Data'], inplace=True)
CFris092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CFris.csv', sep=',')
CFris062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CFris.csv', sep=';')
CFris062013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris062013 = CFris062013.iloc[:, :-1]
CFris062013.dropna(subset=['Data'], inplace=True)
CFris062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CFris.csv', sep=',')
CFris032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CFris.csv', sep=';')
CFris032013.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris032013 = CFris032013.iloc[:, :-1]
CFris032013.dropna(subset=['Data'], inplace=True)
CFris032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CFris.csv', sep=',')
CFris122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CFris.csv', sep=';')
CFris122012.columns =['Instituição', 'Código', 'TCB', 'TD', 'TC','SR', 'Segmento', 'Cidade', 'UF', 'Data', 'Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Nível D', 'Nível E', 'Nível F', 'Nível G', 'Nível H', 'Total Exterior', 'N/A']
CFris122012 = CFris122012.iloc[:, :-1]
CFris122012.dropna(subset=['Data'], inplace=True)
CFris122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CFris.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CFris_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CFris_csv.to_csv('CFris.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CFris.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris1 = CFris[CFris['Carteira de Crédito Classificada'].str.contains('NI')==False]
CFris1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris2 = CFris[CFris['Nível AA'].str.contains('NI')==False]
CFris2.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris3 = CFris[CFris['Nível A'].str.contains('NI')==False]
CFris3.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris4 = CFris[CFris['Nível B'].str.contains('NI')==False]
CFris4.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris5 = CFris[CFris['Nível C'].str.contains('NI')==False]
CFris5.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
CFris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', sep=';')
CFris6 = CFris[CFris['Total Exterior'].str.contains('NI')==False]
CFris6.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', index=False, encoding='utf-8-sig', sep=';')
display(CFris6)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1                                               ITAU
# 2               2                            CAIXA ECONOMICA FEDERAL
# 3               3                                           BRADESCO
# 4               4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# ...           ...                                                ...
# 55213        1239  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 55214        1240  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 55215        1263            NUMBRS SOCIEDADE DE CRÉDITO DIRETO S.A.
# 55216        1362  COOPERATIVA CENTRAL DE CRÉDITO, POUPANÇA E INV...
# 55217        1372  SOLIDEZ - CORRETORA DE CÂMBIO, TÍTULOS E VALOR...
#
#            Código  TCB TD       TC   SR   Segmento          Cidade  UF  \
# ...

# %%
# Conglomerados Prudenciais e Instituições Independentes - Passivos - a partir de 03/2014 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Passivos - até 12/2013 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir primeiras linhas / excluir totalizadores / criar arquivos .csv temporários
CPpas122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPpas.csv', sep=';', skiprows=2)
CPpas122023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122023 = CPpas122023.iloc[:, :-1]
CPpas122023.dropna(subset=['Data'], inplace=True)
CPpas122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPpas.csv', sep=',')
CPpas092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPpas.csv', sep=';', skiprows=2)
CPpas092023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092023 = CPpas092023.iloc[:, :-1]
CPpas092023.dropna(subset=['Data'], inplace=True)
CPpas092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPpas.csv', sep=',')
CPpas062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPpas.csv', sep=';', skiprows=2)
CPpas062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062023 = CPpas062023.iloc[:, :-1]
CPpas062023.dropna(subset=['Data'], inplace=True)
CPpas062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPpas.csv', sep=',')
CPpas032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPpas.csv', sep=';', skiprows=2)
CPpas032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032023 = CPpas032023.iloc[:, :-1]
CPpas032023.dropna(subset=['Data'], inplace=True)
CPpas032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPpas.csv', sep=',')
CPpas122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPpas.csv', sep=';', skiprows=2)
CPpas122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122022 = CPpas122022.iloc[:, :-1]
CPpas122022.dropna(subset=['Data'], inplace=True)
CPpas122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPpas.csv', sep=',')
CPpas092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPpas.csv', sep=';', skiprows=2)
CPpas092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092022 = CPpas092022.iloc[:, :-1]
CPpas092022.dropna(subset=['Data'], inplace=True)
CPpas092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPpas.csv', sep=',')
CPpas062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPpas.csv', sep=';', skiprows=2)
CPpas062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062022 = CPpas062022.iloc[:, :-1]
CPpas062022.dropna(subset=['Data'], inplace=True)
CPpas062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPpas.csv', sep=',')
CPpas032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPpas.csv', sep=';', skiprows=2)
CPpas032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032022 = CPpas032022.iloc[:, :-1]
CPpas032022.dropna(subset=['Data'], inplace=True)
CPpas032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPpas.csv', sep=',')
CPpas122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPpas.csv', sep=';', skiprows=2)
CPpas122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122021 = CPpas122021.iloc[:, :-1]
CPpas122021.dropna(subset=['Data'], inplace=True)
CPpas122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPpas.csv', sep=',')
CPpas092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPpas.csv', sep=';', skiprows=2)
CPpas092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092021 = CPpas092021.iloc[:, :-1]
CPpas092021.dropna(subset=['Data'], inplace=True)
CPpas092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPpas.csv', sep=',')
CPpas062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPpas.csv', sep=';', skiprows=2)
CPpas062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062021 = CPpas062021.iloc[:, :-1]
CPpas062021.dropna(subset=['Data'], inplace=True)
CPpas062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPpas.csv', sep=',')
CPpas032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPpas.csv', sep=';', skiprows=2)
CPpas032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032021 = CPpas032021.iloc[:, :-1]
CPpas032021.dropna(subset=['Data'], inplace=True)
CPpas032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPpas.csv', sep=',')
CPpas122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPpas.csv', sep=';', skiprows=2)
CPpas122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122020 = CPpas122020.iloc[:, :-1]
CPpas122020.dropna(subset=['Data'], inplace=True)
CPpas122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPpas.csv', sep=',')
CPpas092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPpas.csv', sep=';', skiprows=2)
CPpas092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092020 = CPpas092020.iloc[:, :-1]
CPpas092020.dropna(subset=['Data'], inplace=True)
CPpas092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPpas.csv', sep=',')
CPpas062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPpas.csv', sep=';', skiprows=2)
CPpas062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Conta de Pagamento Pré-Paga (a5)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062020 = CPpas062020.iloc[:, :-1]
CPpas062020.dropna(subset=['Data'], inplace=True)
CPpas062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPpas.csv', sep=',')
# Inclusão a partir de 06/2020 da coluna intermediária 'Conta de Pagamento Pré-Paga (a5)' a partir de 06/2020
CPpas032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPpas.csv', sep=';', skiprows=2)
CPpas032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032020 = CPpas032020.iloc[:, :-1]
CPpas032020.dropna(subset=['Data'], inplace=True)
CPpas032020.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPpas.csv', sep=',')
CPpas122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPpas.csv', sep=';', skiprows=2)
CPpas122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122019 = CPpas122019.iloc[:, :-1]
CPpas122019.dropna(subset=['Data'], inplace=True)
CPpas122019.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPpas.csv', sep=',')
CPpas092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPpas.csv', sep=';', skiprows=2)
CPpas092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092019 = CPpas092019.iloc[:, :-1]
CPpas092019.dropna(subset=['Data'], inplace=True)
CPpas092019.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPpas.csv', sep=',')
CPpas062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPpas.csv', sep=';', skiprows=2)
CPpas062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062019 = CPpas062019.iloc[:, :-1]
CPpas062019.dropna(subset=['Data'], inplace=True)
CPpas062019.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPpas.csv', sep=',')
CPpas032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPpas.csv', sep=';', skiprows=2)
CPpas032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032019 = CPpas032019.iloc[:, :-1]
CPpas032019.dropna(subset=['Data'], inplace=True)
CPpas032019.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPpas.csv', sep=',')
CPpas122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPpas.csv', sep=';', skiprows=2)
CPpas122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122018 = CPpas122018.iloc[:, :-1]
CPpas122018.dropna(subset=['Data'], inplace=True)
CPpas122018.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPpas.csv', sep=',')
CPpas092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPpas.csv', sep=';', skiprows=2)
CPpas092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092018 = CPpas092018.iloc[:, :-1]
CPpas092018.dropna(subset=['Data'], inplace=True)
CPpas092018.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPpas.csv', sep=',')
CPpas062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPpas.csv', sep=';', skiprows=2)
CPpas062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062018 = CPpas062018.iloc[:, :-1]
CPpas062018.dropna(subset=['Data'], inplace=True)
CPpas062018.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPpas.csv', sep=',')
CPpas032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPpas.csv', sep=';', skiprows=2)
CPpas032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032018 = CPpas032018.iloc[:, :-1]
CPpas032018.dropna(subset=['Data'], inplace=True)
CPpas032018.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPpas.csv', sep=',')
CPpas122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPpas.csv', sep=';', skiprows=2)
CPpas122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122017 = CPpas122017.iloc[:, :-1]
CPpas122017.dropna(subset=['Data'], inplace=True)
CPpas122017.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPpas.csv', sep=',')
CPpas092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPpas.csv', sep=';', skiprows=2)
CPpas092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092017 = CPpas092017.iloc[:, :-1]
CPpas092017.dropna(subset=['Data'], inplace=True)
CPpas092017.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPpas.csv', sep=',')
CPpas062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPpas.csv', sep=';', skiprows=2)
CPpas062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062017 = CPpas062017.iloc[:, :-1]
CPpas062017.dropna(subset=['Data'], inplace=True)
CPpas062017.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPpas.csv', sep=',')
CPpas032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPpas.csv', sep=';', skiprows=2)
CPpas032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032017 = CPpas032017.iloc[:, :-1]
CPpas032017.dropna(subset=['Data'], inplace=True)
CPpas032017.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPpas.csv', sep=',')
CPpas122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPpas.csv', sep=';', skiprows=2)
CPpas122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122016 = CPpas122016.iloc[:, :-1]
CPpas122016.dropna(subset=['Data'], inplace=True)
CPpas122016.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPpas.csv', sep=',')
CPpas092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPpas.csv', sep=';', skiprows=2)
CPpas092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092016 = CPpas092016.iloc[:, :-1]
CPpas092016.dropna(subset=['Data'], inplace=True)
CPpas092016.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPpas.csv', sep=',')
CPpas062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPpas.csv', sep=';', skiprows=2)
CPpas062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062016 = CPpas062016.iloc[:, :-1]
CPpas062016.dropna(subset=['Data'], inplace=True)
CPpas062016.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPpas.csv', sep=',')
CPpas032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPpas.csv', sep=';', skiprows=2)
CPpas032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032016 = CPpas032016.iloc[:, :-1]
CPpas032016.dropna(subset=['Data'], inplace=True)
CPpas032016.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPpas.csv', sep=',')
CPpas122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPpas.csv', sep=';', skiprows=2)
CPpas122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122015 = CPpas122015.iloc[:, :-1]
CPpas122015.dropna(subset=['Data'], inplace=True)
CPpas122015.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPpas.csv', sep=',')
CPpas092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPpas.csv', sep=';', skiprows=2)
CPpas092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092015 = CPpas092015.iloc[:, :-1]
CPpas092015.dropna(subset=['Data'], inplace=True)
CPpas092015.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPpas.csv', sep=',')
CPpas062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPpas.csv', sep=';', skiprows=2)
CPpas062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062015 = CPpas062015.iloc[:, :-1]
CPpas062015.dropna(subset=['Data'], inplace=True)
CPpas062015.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPpas.csv', sep=',')
CPpas032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPpas.csv', sep=';', skiprows=2)
CPpas032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032015 = CPpas032015.iloc[:, :-1]
CPpas032015.dropna(subset=['Data'], inplace=True)
CPpas032015.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPpas.csv', sep=',')
CPpas122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPpas.csv', sep=';', skiprows=2)
CPpas122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122014 = CPpas122014.iloc[:, :-1]
CPpas122014.dropna(subset=['Data'], inplace=True)
CPpas122014.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPpas.csv', sep=',')
CPpas092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPpas.csv', sep=';', skiprows=2)
CPpas092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092014 = CPpas092014.iloc[:, :-1]
CPpas092014.dropna(subset=['Data'], inplace=True)
CPpas092014.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPpas.csv', sep=',')
CPpas062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPpas.csv', sep=';', skiprows=2)
CPpas062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062014 = CPpas062014.iloc[:, :-1]
CPpas062014.dropna(subset=['Data'], inplace=True)
CPpas062014.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPpas.csv', sep=',')
CPpas032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPpas.csv', sep=';', skiprows=2)
CPpas032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032014 = CPpas032014.iloc[:, :-1]
CPpas032014.dropna(subset=['Data'], inplace=True)
CPpas032014.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPpas.csv', sep=',')
CPpas122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPpas.csv', sep=';', skiprows=2)
CPpas122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122013 = CPpas122013.iloc[:, :-1]
CPpas122013.dropna(subset=['Data'], inplace=True)
CPpas122013.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPpas.csv', sep=',')
CPpas092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPpas.csv', sep=';', skiprows=2)
CPpas092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas092013 = CPpas092013.iloc[:, :-1]
CPpas092013.dropna(subset=['Data'], inplace=True)
CPpas092013.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPpas.csv', sep=',')
CPpas062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPpas.csv', sep=';', skiprows=2)
CPpas062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas062013 = CPpas062013.iloc[:, :-1]
CPpas062013.dropna(subset=['Data'], inplace=True)
CPpas062013.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPpas.csv', sep=',')
CPpas032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPpas.csv', sep=';', skiprows=2)
CPpas032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas032013 = CPpas032013.iloc[:, :-1]
CPpas032013.dropna(subset=['Data'], inplace=True)
CPpas032013.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPpas.csv', sep=',')
CPpas122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPpas.csv', sep=';', skiprows=2)
CPpas122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Depósitos à Vista (a1)', 'Depósitos de Poupança (a2)', 'Depósitos Interfinanceiros (a3)', 'Depósitos a Prazo (a4)', 'Depósitos Outros (a6)', 'Depósito Total (a)', 'Obrigações por Operações Compromissadas (b)', 'Letras de Crédito Imobiliário (c1)', 'Letras de Crédito do Agronegócio (c2)', 'Letras Financeiras (c3)', 'Obrigações por Títulos e Valores Mobiliários no Exterior (c4)', 'Outros Recursos de Aceites e Emissão de Títulos (c5)', 'Recursos de Aceites e Emissão de Títulos (c)', 'Obrigações por Empréstimos e Repasses (d)', 'Captações (e) = (a) + (b) + (c) + (d)', 'Instrumentos Derivativos (f)', 'Outras Obrigações (g)', 'Passivo Circulante e Exigível a Longo Prazo (h) = (e) + (f) + (g)', 'Resultados de Exercícios Futuros (i)', 'Patrimônio Líquido (j)', 'Passivo Total (k) = (h) + (i) + (j)', 'N/A']
CPpas122012 = CPpas122012.iloc[:, :-1]
CPpas122012.dropna(subset=['Data'], inplace=True)
CPpas122012.insert(13, column = "Conta de Pagamento Pré-Paga (a5)", value = "")  
CPpas122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPpas.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPpas_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPpas_csv.to_csv('CPpas.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPpas.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPpas.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPpas = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPpas.csv', sep=';')
CPpas1 = CPpas[CPpas['Passivo Total (k) = (h) + (i) + (j)'].str.contains('NI')==False]
CPpas1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPpas.csv', index=False, encoding='utf-8-sig', sep=';')
display(CPpas1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
#        Unnamed: 0                                        Instituição  \
# 0               0                                                 BB
# 1               1                                               ITAU
# 2               2                                           BRADESCO
# 3               3                            CAIXA ECONOMICA FEDERAL
# 4               4  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# ...           ...                                                ...
# 64140        1338  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
# 64141        1339                                    AVIPAM CC LTDA.
# 64142        1340                                    HR SCMEPP LTDA.
# 64143        1341                                      MEGA CC LTDA.
# 64144        1342  COOPERATIVA DE ECONOMIA E CRÉDITO MÚTUO DOS BA...
#
#              Código  TCB   SR TD   TC          Cidade  UF     Data  ...  \
# ...

# %%
# Conglomerados Prudenciais e Instituições Independentes - Informações de Capital - a partir de 03/2015 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Informações de Capital - até 12/2014 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CPcap122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPcap.csv', sep=';')
CPcap122023.columns =['Instituição', 'Código', 'TCip', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWAcva (g5)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'RWAsp (i)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Adicional de Capital Principal', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122023 = CPcap122023.iloc[:, :-1]
CPcap122023.dropna(subset=['Data'], inplace=True)
CPcap122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPcap.csv', sep=',')
CPcap092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPcap.csv', sep=';')
CPcap092023.columns =['Instituição', 'Código', 'TCip', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWAcva (g5)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'RWAsp (i)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Adicional de Capital Principal', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092023 = CPcap092023.iloc[:, :-1]
CPcap092023.dropna(subset=['Data'], inplace=True)
CPcap092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPcap.csv', sep=',')
CPcap062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPcap.csv', sep=';')
CPcap062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Adicional de Capital Principal', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062023 = CPcap062023.iloc[:, :-1]
CPcap062023.dropna(subset=['Data'], inplace=True)
CPcap062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPcap.csv', sep=',')
CPcap032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPcap.csv', sep=';')
CPcap032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Adicional de Capital Principal', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032023 = CPcap032023.iloc[:, :-1]	
CPcap032023.dropna(subset=['Data'], inplace=True)
CPcap032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPcap.csv', sep=',')
CPcap122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPcap.csv', sep=';')
CPcap122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122022 = CPcap122022.iloc[:, :-1]
CPcap122022.dropna(subset=['Data'], inplace=True)
CPcap122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPcap.csv', sep=',')
CPcap092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPcap.csv', sep=';')
CPcap092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092022 = CPcap092022.iloc[:, :-1]
CPcap092022.dropna(subset=['Data'], inplace=True)
CPcap092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPcap.csv', sep=',')
CPcap062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPcap.csv', sep=';')
CPcap062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062022 = CPcap062022.iloc[:, :-1]
CPcap062022.dropna(subset=['Data'], inplace=True)
CPcap062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPcap.csv', sep=',')
CPcap032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPcap.csv', sep=';')
CPcap032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032022 = CPcap032022.iloc[:, :-1]
CPcap032022.dropna(subset=['Data'], inplace=True)
CPcap032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPcap.csv', sep=',')
CPcap122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPcap.csv', sep=';')
CPcap122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122021 = CPcap122021.iloc[:, :-1]
CPcap122021.dropna(subset=['Data'], inplace=True)
CPcap122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPcap.csv', sep=',')
CPcap092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPcap.csv', sep=';')
CPcap092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092021 = CPcap092021.iloc[:, :-1]
CPcap092021.dropna(subset=['Data'], inplace=True)
CPcap092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPcap.csv', sep=',')
CPcap062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPcap.csv', sep=';')
CPcap062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062021 = CPcap062021.iloc[:, :-1]
CPcap062021.dropna(subset=['Data'], inplace=True)
CPcap062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPcap.csv', sep=',')
CPcap032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPcap.csv', sep=';')
CPcap032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032021 = CPcap032021.iloc[:, :-1]
CPcap032021.dropna(subset=['Data'], inplace=True)
CPcap032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPcap.csv', sep=',')
CPcap122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPcap.csv', sep=';')
CPcap122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122020 = CPcap122020.iloc[:, :-1]
CPcap122020.dropna(subset=['Data'], inplace=True)
CPcap122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPcap.csv', sep=',')
CPcap092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPcap.csv', sep=';')
CPcap092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092020 = CPcap092020.iloc[:, :-1]
CPcap092020.dropna(subset=['Data'], inplace=True)
CPcap092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPcap.csv', sep=',')
CPcap062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPcap.csv', sep=';')
CPcap062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062020 = CPcap062020.iloc[:, :-1]
CPcap062020.dropna(subset=['Data'], inplace=True)
CPcap062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPcap.csv', sep=',')
CPcap032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPcap.csv', sep=';')
CPcap032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032020 = CPcap032020.iloc[:, :-1]
CPcap032020.dropna(subset=['Data'], inplace=True)
CPcap032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPcap.csv', sep=',')
CPcap122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPcap.csv', sep=';')
CPcap122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122019 = CPcap122019.iloc[:, :-1]
CPcap122019.dropna(subset=['Data'], inplace=True)
CPcap122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPcap.csv', sep=',')
CPcap092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPcap.csv', sep=';')
CPcap092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092019 = CPcap092019.iloc[:, :-1]
CPcap092019.dropna(subset=['Data'], inplace=True)
CPcap092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPcap.csv', sep=',')
CPcap062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPcap.csv', sep=';')
CPcap062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062019 = CPcap062019.iloc[:, :-1]
CPcap062019.dropna(subset=['Data'], inplace=True)
CPcap062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPcap.csv', sep=',')
CPcap032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPcap.csv', sep=';')
CPcap032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032019 = CPcap032019.iloc[:, :-1]
CPcap032019.dropna(subset=['Data'], inplace=True)
CPcap032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPcap.csv', sep=',')
CPcap122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPcap.csv', sep=';')
CPcap122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122018 = CPcap122018.iloc[:, :-1]
CPcap122018.dropna(subset=['Data'], inplace=True)
CPcap122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPcap.csv', sep=',')
CPcap092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPcap.csv', sep=';')
CPcap092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092018 = CPcap092018.iloc[:, :-1]
CPcap092018.dropna(subset=['Data'], inplace=True)
CPcap092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPcap.csv', sep=',')
CPcap062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPcap.csv', sep=';')
CPcap062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062018 = CPcap062018.iloc[:, :-1]
CPcap062018.dropna(subset=['Data'], inplace=True)
CPcap062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPcap.csv', sep=',')
CPcap032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPcap.csv', sep=';')
CPcap032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032018 = CPcap032018.iloc[:, :-1]
CPcap032018.dropna(subset=['Data'], inplace=True)
CPcap032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPcap.csv', sep=',')
CPcap122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPcap.csv', sep=';')
CPcap122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122017 = CPcap122017.iloc[:, :-1]
CPcap122017.dropna(subset=['Data'], inplace=True)
CPcap122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPcap.csv', sep=',')
CPcap092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPcap.csv', sep=';')
CPcap092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092017 = CPcap092017.iloc[:, :-1]
CPcap092017.dropna(subset=['Data'], inplace=True)
CPcap092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPcap.csv', sep=',')
CPcap062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPcap.csv', sep=';')
CPcap062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062017 = CPcap062017.iloc[:, :-1]
CPcap062017.dropna(subset=['Data'], inplace=True)
CPcap062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPcap.csv', sep=',')
CPcap032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPcap.csv', sep=';')
CPcap032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032017 = CPcap032017.iloc[:, :-1]
CPcap032017.dropna(subset=['Data'], inplace=True)
CPcap032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPcap.csv', sep=',')
CPcap122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPcap.csv', sep=';')
CPcap122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122016 = CPcap122016.iloc[:, :-1]
CPcap122016.dropna(subset=['Data'], inplace=True)
CPcap122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPcap.csv', sep=',')
CPcap092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPcap.csv', sep=';')
CPcap092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092016 = CPcap092016.iloc[:, :-1]
CPcap092016.dropna(subset=['Data'], inplace=True)
CPcap092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPcap.csv', sep=',')
CPcap062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPcap.csv', sep=';')
CPcap062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062016 = CPcap062016.iloc[:, :-1]
CPcap062016.dropna(subset=['Data'], inplace=True)
CPcap062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPcap.csv', sep=',')
CPcap032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPcap.csv', sep=';')
CPcap032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032016 = CPcap032016.iloc[:, :-1]
CPcap032016.dropna(subset=['Data'], inplace=True)
CPcap032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPcap.csv', sep=',')
CPcap122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPcap.csv', sep=';')
CPcap122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122015 = CPcap122015.iloc[:, :-1]
CPcap122015.dropna(subset=['Data'], inplace=True)
CPcap122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPcap.csv', sep=',')
CPcap092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPcap.csv', sep=';')
CPcap092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092015 = CPcap092015.iloc[:, :-1]
CPcap092015.dropna(subset=['Data'], inplace=True)
CPcap092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPcap.csv', sep=',')
CPcap062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPcap.csv', sep=';')
CPcap062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062015 = CPcap062015.iloc[:, :-1]
CPcap062015.dropna(subset=['Data'], inplace=True)
CPcap062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPcap.csv', sep=',')
CPcap032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPcap.csv', sep=';')
CPcap032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032015 = CPcap032015.iloc[:, :-1]
CPcap032015.dropna(subset=['Data'], inplace=True)
CPcap032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPcap.csv', sep=',')
CPcap122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPcap.csv', sep=';')
CPcap122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122014 = CPcap122014.iloc[:, :-1]
CPcap122014.dropna(subset=['Data'], inplace=True)
CPcap122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPcap.csv', sep=',')
CPcap092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPcap.csv', sep=';')
CPcap092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092014 = CPcap092014.iloc[:, :-1]
CPcap092014.dropna(subset=['Data'], inplace=True)
CPcap092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPcap.csv', sep=',')
CPcap062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPcap.csv', sep=';')
CPcap062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062014 = CPcap062014.iloc[:, :-1]
CPcap062014.dropna(subset=['Data'], inplace=True)
CPcap062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPcap.csv', sep=',')
CPcap032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPcap.csv', sep=';')
CPcap032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032014 = CPcap032014.iloc[:, :-1]
CPcap032014.dropna(subset=['Data'], inplace=True)
CPcap032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPcap.csv', sep=',')
CPcap122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPcap.csv', sep=';')
CPcap122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122013 = CPcap122013.iloc[:, :-1]
CPcap122013.dropna(subset=['Data'], inplace=True)
CPcap122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPcap.csv', sep=',')
CPcap092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPcap.csv', sep=';')
CPcap092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap092013 = CPcap092013.iloc[:, :-1]
CPcap092013.dropna(subset=['Data'], inplace=True)
CPcap092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPcap.csv', sep=',')
CPcap062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPcap.csv', sep=';')
CPcap062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap062013 = CPcap062013.iloc[:, :-1]
CPcap062013.dropna(subset=['Data'], inplace=True)
CPcap062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPcap.csv', sep=',')
CPcap032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPcap.csv', sep=';')
CPcap032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap032013 = CPcap032013.iloc[:, :-1]
CPcap032013.dropna(subset=['Data'], inplace=True)
CPcap032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPcap.csv', sep=',')
CPcap122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPcap.csv', sep=';')
CPcap122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Capital Principal para Comparação com RWA (a)', 'Capital Complementar (b)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)', 'Capital Nível II (d)', 'Patrimônio de Referência para Comparação com o RWA', 'RWA para Risco de Crédito (f)', 'RWAcam (g1)', 'RWAcom (g2)', 'RWAjur (g3)', 'RWAacs (g4)', 'RWA para Risco de Mercado (g) = (g1) + (g2) + (g3) + (g4) + (g5)', 'RWA para Risco Operacional (h)', 'Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)', 'Índice de Capital Principal (l) = (a) / (j)', 'Índice de Capital Nível I (m) = (c) / (j)', 'Índice de Basileia (n) = (e) / (j)', 'Razão de Alavancagem (o) = (c) / (k)', 'Índice de Imobilização (p)', 'N/A']
CPcap122012 = CPcap122012.iloc[:, :-1]
CPcap122012.dropna(subset=['Data'], inplace=True)
CPcap122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPcap.csv', sep=',')
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPcap_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPcap_csv.to_csv('CPcap.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPcap.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPcap.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPcap = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPcap.csv', sep=';')
CPcap1 = CPcap[CPcap['Índice de Basileia (n) = (e) / (j)'].str.contains('NI')==False]
CPcap1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPcap.csv', index=False, encoding='utf-8-sig', sep=';')
display(CPcap1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
# C:\Users\mvrgu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0                                        Instituição  \
# 0               2                                                 BB
# 1               3                                               ITAU
# 2               4                                           BRADESCO
# 3               5  BANCO NACIONAL DE DESENVOLVIMENTO ECONOMICO E ...
# 4               6                            CAIXA ECONOMICA FEDERAL
# ...           ...                                                ...
# 64107        1324                                           BELVO IP
# 64108        1325                                         QUADRA SCD
# 64109        1326                                          VERT DTVM
# ...

# %%
# Conglomerados Prudenciais e Instituições Independentes - Demonstração de Resultado - a partir de 03/2014 (inclusive)
# Conglomerados Financeiros e Instituições Independentes - Demonstração de Resultado - até 12/2013 (inclusive)
# Fonte: Banco Central do Brasil
# https://www3.bcb.gov.br/ifdata/
# Ler arquivos .csv / nomear colunas / excluir totalizadores / criar arquivos .csv temporários
CPluc122023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122023CPluc.csv', sep=';')
CPluc122023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc122023 = CPluc122023.iloc[:, :-1]
CPluc122023.dropna(subset=['Data'], inplace=True)
CPluc122023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122023CPluc.csv', sep=',')   
CPluc092023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092023CPluc.csv', sep=';')
CPluc092023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc092023 = CPluc092023.iloc[:, :-1]
CPluc092023.dropna(subset=['Data'], inplace=True)
CPluc092023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092023CPluc.csv', sep=',')    
CPluc062023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062023CPluc.csv', sep=';')
CPluc062023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc062023 = CPluc062023.iloc[:, :-1]
CPluc062023.dropna(subset=['Data'], inplace=True)
CPluc062023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062023CPluc.csv', sep=',')    
CPluc032023 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032023CPluc.csv', sep=';')
CPluc032023.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc032023 = CPluc032023.iloc[:, :-1]
CPluc032023.dropna(subset=['Data'], inplace=True)
CPluc032023.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032023CPluc.csv', sep=',')    
CPluc122022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122022CPluc.csv', sep=';')
CPluc122022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc122022 = CPluc122022.iloc[:, :-1]
CPluc122022.dropna(subset=['Data'], inplace=True)
CPluc122022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122022CPluc.csv', sep=',')    
CPluc092022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092022CPluc.csv', sep=';')
CPluc092022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc092022 = CPluc092022.iloc[:, :-1]
CPluc092022.dropna(subset=['Data'], inplace=True)
CPluc092022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092022CPluc.csv', sep=',')    
CPluc062022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062022CPluc.csv', sep=';')
CPluc062022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc062022 = CPluc062022.iloc[:, :-1]
CPluc062022.dropna(subset=['Data'], inplace=True)
CPluc062022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062022CPluc.csv', sep=',')    
CPluc032022 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032022CPluc.csv', sep=';')
CPluc032022.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc032022 = CPluc032022.iloc[:, :-1]
CPluc032022.dropna(subset=['Data'], inplace=True)
CPluc032022.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032022CPluc.csv', sep=',')    
CPluc122021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122021CPluc.csv', sep=';')
CPluc122021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc122021 = CPluc122021.iloc[:, :-1]
CPluc122021.dropna(subset=['Data'], inplace=True)
CPluc122021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122021CPluc.csv', sep=',')    
CPluc092021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092021CPluc.csv', sep=';')
CPluc092021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc092021 = CPluc092021.iloc[:, :-1]
CPluc092021.dropna(subset=['Data'], inplace=True)
CPluc092021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092021CPluc.csv', sep=',')    
CPluc062021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062021CPluc.csv', sep=';')
CPluc062021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc062021 = CPluc062021.iloc[:, :-1]
CPluc062021.dropna(subset=['Data'], inplace=True)
CPluc062021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062021CPluc.csv', sep=',')    
CPluc032021 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032021CPluc.csv', sep=';')
CPluc032021.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc032021 = CPluc032021.iloc[:, :-1]
CPluc032021.dropna(subset=['Data'], inplace=True)
CPluc032021.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032021CPluc.csv', sep=',')    
CPluc122020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122020CPluc.csv', sep=';')
CPluc122020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc122020 = CPluc122020.iloc[:, :-1]
CPluc122020.dropna(subset=['Data'], inplace=True)
CPluc122020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122020CPluc.csv', sep=',')    
CPluc092020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092020CPluc.csv', sep=';')
CPluc092020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc092020 = CPluc092020.iloc[:, :-1]
CPluc092020.dropna(subset=['Data'], inplace=True)
CPluc092020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092020CPluc.csv', sep=',')    
CPluc062020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062020CPluc.csv', sep=';')
CPluc062020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc062020 = CPluc062020.iloc[:, :-1]
CPluc062020.dropna(subset=['Data'], inplace=True)
CPluc062020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062020CPluc.csv', sep=',')    
CPluc032020 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032020CPluc.csv', sep=';')
CPluc032020.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc032020 = CPluc032020.iloc[:, :-1]
CPluc032020.dropna(subset=['Data'], inplace=True)
CPluc032020.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032020CPluc.csv', sep=',')    
CPluc122019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122019CPluc.csv', sep=';')
CPluc122019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc122019 = CPluc122019.iloc[:, :-1]
CPluc122019.dropna(subset=['Data'], inplace=True)
CPluc122019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122019CPluc.csv', sep=',')    
CPluc092019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092019CPluc.csv', sep=';')
CPluc092019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc092019 = CPluc092019.iloc[:, :-1]
CPluc092019.dropna(subset=['Data'], inplace=True)
CPluc092019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092019CPluc.csv', sep=',')    
CPluc062019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062019CPluc.csv', sep=';')
CPluc062019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc062019 = CPluc062019.iloc[:, :-1]
CPluc062019.dropna(subset=['Data'], inplace=True)
CPluc062019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062019CPluc.csv', sep=',')    
CPluc032019 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032019CPluc.csv', sep=';')
CPluc032019.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Social de Cooperativas (k)', 'N/A']
CPluc032019 = CPluc032019.iloc[:, :-1]
CPluc032019.dropna(subset=['Data'], inplace=True)
CPluc032019.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032019CPluc.csv', sep=',')    
CPluc122018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122018CPluc.csv', sep=';')
CPluc122018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122018 = CPluc122018.iloc[:, :-1]
CPluc122018.dropna(subset=['Data'], inplace=True)
CPluc122018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122018CPluc.csv', sep=',')                         
CPluc092018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092018CPluc.csv', sep=';')
CPluc092018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092018 = CPluc092018.iloc[:, :-1]
CPluc092018.dropna(subset=['Data'], inplace=True)
CPluc092018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092018CPluc.csv', sep=',')    
CPluc062018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062018CPluc.csv', sep=';')
CPluc062018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062018 = CPluc062018.iloc[:, :-1]
CPluc062018.dropna(subset=['Data'], inplace=True)
CPluc062018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062018CPluc.csv', sep=',')    
CPluc032018 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032018CPluc.csv', sep=';')
CPluc032018.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032018 = CPluc032018.iloc[:, :-1]
CPluc032018.dropna(subset=['Data'], inplace=True)
CPluc032018.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032018CPluc.csv', sep=',')    
CPluc122017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122017CPluc.csv', sep=';')
CPluc122017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122017 = CPluc122017.iloc[:, :-1]
CPluc122017.dropna(subset=['Data'], inplace=True)
CPluc122017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122017CPluc.csv', sep=',')    
CPluc092017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092017CPluc.csv', sep=';')
CPluc092017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092017 = CPluc092017.iloc[:, :-1]
CPluc092017.dropna(subset=['Data'], inplace=True)
CPluc092017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092017CPluc.csv', sep=',')    
CPluc062017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062017CPluc.csv', sep=';')
CPluc062017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062017 = CPluc062017.iloc[:, :-1]
CPluc062017.dropna(subset=['Data'], inplace=True)
CPluc062017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062017CPluc.csv', sep=',')    
CPluc032017 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032017CPluc.csv', sep=';')
CPluc032017.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032017 = CPluc032017.iloc[:, :-1]
CPluc032017.dropna(subset=['Data'], inplace=True)
CPluc032017.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032017CPluc.csv', sep=',')    
CPluc122016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122016CPluc.csv', sep=';')
CPluc122016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122016 = CPluc122016.iloc[:, :-1]
CPluc122016.dropna(subset=['Data'], inplace=True)
CPluc122016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122016CPluc.csv', sep=',')    
CPluc092016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092016CPluc.csv', sep=';')
CPluc092016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092016 = CPluc092016.iloc[:, :-1]
CPluc092016.dropna(subset=['Data'], inplace=True)
CPluc092016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092016CPluc.csv', sep=',')    
CPluc062016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062016CPluc.csv', sep=';')
CPluc062016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062016 = CPluc062016.iloc[:, :-1]
CPluc062016.dropna(subset=['Data'], inplace=True)
CPluc062016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062016CPluc.csv', sep=',')    
CPluc032016 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032016CPluc.csv', sep=';')
CPluc032016.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032016 = CPluc032016.iloc[:, :-1]
CPluc032016.dropna(subset=['Data'], inplace=True)
CPluc032016.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032016CPluc.csv', sep=',')    
CPluc122015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122015CPluc.csv', sep=';')
CPluc122015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122015 = CPluc122015.iloc[:, :-1]
CPluc122015.dropna(subset=['Data'], inplace=True)
CPluc122015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122015CPluc.csv', sep=',')    
CPluc092015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092015CPluc.csv', sep=';')
CPluc092015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092015 = CPluc092015.iloc[:, :-1]
CPluc092015.dropna(subset=['Data'], inplace=True)
CPluc092015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092015CPluc.csv', sep=',')    
CPluc062015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062015CPluc.csv', sep=';')
CPluc062015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062015 = CPluc062015.iloc[:, :-1]
CPluc062015.dropna(subset=['Data'], inplace=True)
CPluc062015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062015CPluc.csv', sep=',')    
CPluc032015 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032015CPluc.csv', sep=';')
CPluc032015.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032015 = CPluc032015.iloc[:, :-1]
CPluc032015.dropna(subset=['Data'], inplace=True)
CPluc032015.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032015CPluc.csv', sep=',')    
CPluc122014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122014CPluc.csv', sep=';')
CPluc122014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122014 = CPluc122014.iloc[:, :-1]
CPluc122014.dropna(subset=['Data'], inplace=True)
CPluc122014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122014CPluc.csv', sep=',')    
CPluc092014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092014CPluc.csv', sep=';')
CPluc092014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092014 = CPluc092014.iloc[:, :-1]
CPluc092014.dropna(subset=['Data'], inplace=True)
CPluc092014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092014CPluc.csv', sep=',')    
CPluc062014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062014CPluc.csv', sep=';')
CPluc062014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062014 = CPluc062014.iloc[:, :-1]
CPluc062014.dropna(subset=['Data'], inplace=True)
CPluc062014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062014CPluc.csv', sep=',')    
CPluc032014 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032014CPluc.csv', sep=';')
CPluc032014.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032014 = CPluc032014.iloc[:, :-1]
CPluc032014.dropna(subset=['Data'], inplace=True)
CPluc032014.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032014CPluc.csv', sep=',')    
CPluc122013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122013CPluc.csv', sep=';')
CPluc122013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122013 = CPluc122013.iloc[:, :-1]
CPluc122013.dropna(subset=['Data'], inplace=True)
CPluc122013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122013CPluc.csv', sep=',')    
CPluc092013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092013CPluc.csv', sep=';')
CPluc092013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092013 = CPluc092013.iloc[:, :-1]
CPluc092013.dropna(subset=['Data'], inplace=True)
CPluc092013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092013CPluc.csv', sep=',')    
CPluc062013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062013CPluc.csv', sep=';')
CPluc062013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062013 = CPluc062013.iloc[:, :-1]
CPluc062013.dropna(subset=['Data'], inplace=True)
CPluc062013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062013CPluc.csv', sep=',')    
CPluc032013 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032013CPluc.csv', sep=';')
CPluc032013.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032013 = CPluc032013.iloc[:, :-1]
CPluc032013.dropna(subset=['Data'], inplace=True)
CPluc032013.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032013CPluc.csv', sep=',')    
CPluc122012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/122012CPluc.csv', sep=';')
CPluc122012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc122012 = CPluc122012.iloc[:, :-1]
CPluc122012.dropna(subset=['Data'], inplace=True)
CPluc122012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/122012CPluc.csv', sep=',')   
CPluc092012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/092012CPluc.csv', sep=';')
CPluc092012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc092012 = CPluc092012.iloc[:, :-1]
CPluc092012.dropna(subset=['Data'], inplace=True)
CPluc092012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/092012CPluc.csv', sep=',')   
CPluc062012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/062012CPluc.csv', sep=';')
CPluc062012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc062012 = CPluc062012.iloc[:, :-1]
CPluc062012.dropna(subset=['Data'], inplace=True)
CPluc062012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/062012CPluc.csv', sep=',')    
CPluc032012 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Bases/032012CPluc.csv', sep=';')
CPluc032012.columns =['Instituição', 'Código', 'TCB', 'SR', 'TD', 'TC', 'Cidade', 'UF', 'Data', 'Rendas de Operações de Crédito (a1)', 'Rendas de Operações de Arrendamento Mercantil (a2)', 'Rendas de Operações com TVM (a3)', 'Rendas de Operações com Instrumentos Financeiros Derivativos (a4)', 'Resultado de Operações de Câmbio (a5)', 'Rendas de Aplicações Compulsórias (a6)', 'Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)', 'Despesas de Captação (b1)', 'Despesas de Obrigações por Empréstimos e Repasses (b2)', 'Despesas de Operações de Arrendamento Mercantil (b3)', 'Resultado de Operações de Câmbio (b4)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Intermediação Financeira (c) = (a) + (b)', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Resultado Operacional (e) = (c) + (d)', 'Resultado Não Operacional (f)', 'Resultado antes da Tributação, Lucro e Participação (g) = (e) + (f)', 'Imposto de Renda e Contribuição Social (h)', 'Participação nos Lucros (i)', 'Lucro Líquido (j) = (g) + (h) + (i)', 'Juros Sobre Capital Próprio (k)', 'N/A']
CPluc032012 = CPluc032012.iloc[:, :-1]
CPluc032012.dropna(subset=['Data'], inplace=True)
CPluc032012.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/032012CPluc.csv', sep=',')    
# Concatenar arquivos .csv temporários
os.chdir('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
CPluc_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
CPluc_csv.to_csv('CPluc.csv', index=False, encoding='utf-8-sig', sep=';')
# Excluir termo "Prudencial" dos nomes das instituições financeiras / Excluir instituições que não informaram o BACEN (termo "NI") / Criar arquivo .csv consolidado
text = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/CPluc.csv', 'r', encoding="utf-8")           
text = ''.join([i for i in text])
text = text.replace(" - PRUDENCIAL", "")
x = open('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPluc.csv',"w",encoding="utf-8") 
x.writelines(text) 
x.close()
CPluc = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPluc.csv', sep=';')
CPluc1 = CPluc[CPluc['Lucro Líquido (j) = (g) + (h) + (i)'].str.contains('NI')==False]
CPluc1.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPluc.csv', index=False, encoding='utf-8-sig', sep=';')
display(CPluc1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)
# Out:
# C:\Users\mvrgu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (39) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0              Instituição               Código TCB   SR TD  \
# 0               2                     ITAU        10,069.000000  b1  NaN  C
# 1               3                       BB        49,906.000000  b1  NaN  C
# 2               4                 BRADESCO        10,045.000000  b1  NaN  C
# 3               5                SANTANDER        30,379.000000  b1  NaN  C
# 4               6  CAIXA ECONOMICA FEDERAL       360,305.000000  b1  NaN  I
# ...           ...                      ...                  ...  ..  ... ..
# 69241        1340               BELLUNO IP 1,000,086,983.000000  n4  NaN  I
# 69242        1341              ACTUAL DTVM 1,000,087,243.000000  n2   S4  I
# ...

# %%
# Índice nacional de preços ao consumidor amplo (IPCA) geral: taxa de variação mensal (IBGE/SNIPC/PRECOS12_IPCAG12) - a partir de 01/1980 (inclusive)
# Fonte: Instituto de Pesquisa Econômica Aplicada (IPEA)
# http://www.ipeadata.gov.br/
IPCA = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IPEAData/Bases/ipca.csv', encoding='utf-8-sig', sep=';', thousands='.', decimal = ',')
IPCA.columns =['DataOriginal', 'IPCAOriginal', 'N/A']
IPCA = IPCA.iloc[:, :-1]
IPCA.dropna(subset=['DataOriginal'], inplace=True)
IPCA = IPCA.drop(IPCA[IPCA.DataOriginal < 201212].index)
IPCA['DataOriginal'] = IPCA['DataOriginal'].astype(str)
IPCA['Data'] = IPCA['DataOriginal'].str[-2:] + '/' + IPCA['DataOriginal'].str[:-2]
IPCA['IPCA Mensal'] = IPCA['IPCAOriginal']/100
IPCA['IPCA Acumulado'] = (1 + IPCA['IPCA Mensal']).cumprod() - 1  
IPCA['IPCA Fator'] = (IPCA['IPCA Acumulado']) + 1  
IPCA.loc[-1] = ['', '', '', '', '', 1]
IPCA.index = IPCA.index + 1
IPCA.sort_index(inplace=True) 
IPCA['IPCA Mensal'] = pd.to_numeric(IPCA['IPCA Mensal'], downcast="float")
IPCA = IPCA.drop(['DataOriginal', 'IPCAOriginal'], axis=1)
IPCA.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IPEAData/Tratados/ipca.csv', columns=['Data', 'IPCA Mensal', 'IPCA Fator'], index=False, encoding='utf-8-sig', sep=';', decimal = ',')
pd.options.display.float_format = '{:,.2f}'.format
display(IPCA)
# Out:
#         Data  IPCA Mensal IPCA Acumulado  IPCA Fator
# 0                     NaN                       1.00
# 396  12/2012         0.01           0.01        1.01
# 397  01/2013         0.01           0.02        1.02
# 398  02/2013         0.01           0.02        1.02
# 399  03/2013         0.00           0.03        1.03
# ..       ...          ...            ...         ...
# 529  01/2024         0.00           0.90        1.90
# 530  02/2024         0.01           0.92        1.92
# 531  03/2024         0.00           0.92        1.92
# 532  04/2024         0.00           0.93        1.93
# 533  05/2024         0.00           0.94        1.94
#
# [139 rows x 4 columns]

# %%
# BANRISUL - Dividendos e Juros sobre o Capital Próprio (Distribuídos)
# Fonte: Banrisul - Relações com Investidores
# https://ri.banrisul.com.br/informacoes-ao-mercado/dividendos-e-jscp/
DIV = pd.read_excel('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/BanrisulData/Bases/Histórico de Distribuição de Dividendos e JSCP.xlsx', usecols=[0, 3],skiprows=[1])
DIV.columns = ["Data", "Proventos"]
DIV = DIV.dropna(subset=['Data'])
DIV = DIV.dropna(subset=['Proventos'])
DIV['Data'] = '12/' + DIV['Data'].astype(str)
DIV['Data'] = pd.to_datetime(DIV['Data']) 
DIV['Data'] = DIV['Data'].dt.strftime('%m/%Y')
DIV = DIV[~(DIV['Data'] < '12/2012')]

#Exportação do arquivo DIV.csv
DIV.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/BanrisulData/Tratados/DIV.csv', index=False, encoding='utf-8-sig', sep=';', decimal=',')
pd.options.display.float_format = '{:,.6f}'.format
display(DIV)
# Out:
#        Data  Proventos
# 27  12/2012 326.500000
# 33  12/2013 314.300000
# 38  12/2014 280.800000
# 43  12/2015 356.444825
# 47  12/2016 264.757000
# 52  12/2017 420.200000
# 58  12/2018 419.900000
# 65  12/2019 536.600000
# 70  12/2020 218.200000
# 75  12/2021 382.150000
# 80  12/2022 360.200000
# 85  12/2023 434.900000
# 89  12/2024  50.000000

# %%
# Leitura e preparação do arquivo BaseMV.csv para utilização nos gráficos do Capítulo 3
pd.set_option('display.max_rows', 100)
BASEati = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPati.csv', encoding='utf-8-sig', sep=';', thousands='.')
BASEati['Data'] = pd.to_datetime(BASEati['Data']) 
BASEati.loc[BASEati['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEati = BASEati.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEreg = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFreg.csv', encoding='utf-8-sig', sep=';', thousands='.')
BASEreg['Data'] = pd.to_datetime(BASEreg['Data']) 
BASEreg.loc[BASEreg['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEreg = BASEreg.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEcpf = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpf.csv', encoding='utf-8-sig', sep=';', thousands='.', low_memory=False)
BASEcpf['Data'] = pd.to_datetime(BASEcpf['Data']) 
BASEcpf.loc[BASEcpf['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEcpf = BASEcpf.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEcpj = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFcpj.csv', encoding='utf-8-sig', sep=';', thousands='.', low_memory=False)
BASEcpj['Data'] = pd.to_datetime(BASEcpj['Data']) 
BASEcpj.loc[BASEcpj['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEcpj = BASEcpj.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEris = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CFris.csv', encoding='utf-8-sig', sep=';', thousands='.', low_memory=False)
BASEris['Data'] = pd.to_datetime(BASEris['Data']) 
BASEris.loc[BASEris['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEris = BASEris.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEpas = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPpas.csv', encoding='utf-8-sig', sep=';', thousands='.')
BASEpas['Data'] = pd.to_datetime(BASEpas['Data']) 
BASEpas.loc[BASEpas['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEpas = BASEpas.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEcap = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPcap.csv', encoding='utf-8-sig', sep=';', thousands='.')
BASEcap['Data'] = pd.to_datetime(BASEcap['Data']) 
BASEcap.loc[BASEcap['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEcap = BASEcap.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASEluc = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/CPluc.csv', encoding='utf-8-sig', sep=';', thousands='.')
BASEluc['Data'] = pd.to_datetime(BASEluc['Data']) 
BASEluc.loc[BASEluc['Instituição'] == 'CAIXA ECONOMICA FEDERAL', 'Instituição'] = 'CAIXA ECONÔMICA FEDERAL'
BASEluc = BASEluc.sort_values(['Instituição', 'Data'],ascending = [True, True])
IPCA = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IPEAData/Tratados/ipca.csv', encoding='utf-8-sig', sep=';', thousands='.')
IPCA['IPCA Fator'] = IPCA['IPCA Fator'].str.replace(',','.')
IPCA['IPCA Fator'] = pd.to_numeric(IPCA['IPCA Fator'])
IPCA['Data'] = pd.to_datetime(IPCA['Data']) 
IPCA = IPCA.sort_values(['Data'],ascending = [True])
DIV = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/BanrisulData/Tratados/DIV.csv', encoding='utf-8-sig', sep=';', thousands='.', decimal=',')

#1. Passivo Nominal
BASE = BASEpas
BASE['Passivo Total (k) = (h) + (i) + (j)'] = pd.to_numeric(BASE['Passivo Total (k) = (h) + (i) + (j)']) 
BASE=BASE.loc[(BASE['Instituição'] == 'BANRISUL') | (BASE['Instituição'] == 'BB') | (BASE['Instituição'] == 'BRADESCO') | (BASE['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE['Instituição'] == 'ITAU') | (BASE['Instituição'] == 'SANTANDER')]
BASE = BASE[['Instituição','Data','Passivo Total (k) = (h) + (i) + (j)']] 
BASE.columns = ['Instituição', 'Data','Passivo Nominal'] 
BASE['Passivo Nominal'] = BASE['Passivo Nominal'].div(1000000) 

#2. Passivo Real
BASE = BASE.merge(IPCA)
BASE = BASE.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE['Passivo Real'] = (BASE['Passivo Nominal'] / BASE['IPCA Fator']) * BASE['IPCA Fator'].iloc[-1]
BASE = BASE.drop(['IPCA Mensal', 'IPCA Fator'], axis=1)

#3. Participação de Mercado relativamente ao Total de Passivos
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Passivo Total (k) = (h) + (i) + (j)']] 
BASE1['Total'] = BASE1.groupby('Data')['Passivo Total (k) = (h) + (i) + (j)'].transform('sum')
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Passivo % Participação de Mercado'] = BASE1['Passivo Total (k) = (h) + (i) + (j)'] / BASE1['Total']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Passivo Total (k) = (h) + (i) + (j)', 'Total'], axis=1)

#4. Total de Depósitos relativamente ao Total de Passivos
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Passivo Total (k) = (h) + (i) + (j)', 'Depósito Total (a)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Depósito Total / Passivo'] = BASE1['Depósito Total (a)'] / BASE1['Passivo Total (k) = (h) + (i) + (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Passivo Total (k) = (h) + (i) + (j)', 'Depósito Total (a)'], axis=1)

#4. Participação de Mercado relativamente ao Total de Depósitos
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Depósito Total (a)']] 
BASE1['Total'] = BASE1.groupby('Data')['Depósito Total (a)'].transform('sum')
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Depósito Total % Participação de Mercado'] = BASE1['Depósito Total (a)'] / BASE1['Total']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Depósito Total (a)', 'Total'], axis=1)

#5. Total de Depósitos à Vista relativamente ao Total de Depósitos
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Depósitos à Vista (a1)', 'Depósito Total (a)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Depósito à Vista / Depósito Total'] = BASE1['Depósitos à Vista (a1)'] / BASE1['Depósito Total (a)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Depósitos à Vista (a1)', 'Depósito Total (a)'], axis=1)

#6. Total de Passivos Onerosos relativamente ao Total de Passivos
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Passivo Total (k) = (h) + (i) + (j)', 'Patrimônio Líquido (j)', 'Resultados de Exercícios Futuros (i)', 'Outras Obrigações (g)', 'Depósitos à Vista (a1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Passivo Oneroso'] = BASE1['Passivo Total (k) = (h) + (i) + (j)'] - BASE1['Patrimônio Líquido (j)'] - BASE1['Resultados de Exercícios Futuros (i)'] - BASE1['Outras Obrigações (g)'] - BASE1['Depósitos à Vista (a1)']
BASE1['% Passivo Oneroso / Passivo Total'] = BASE1['Passivo Oneroso'] / BASE1['Passivo Total (k) = (h) + (i) + (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Passivo Total (k) = (h) + (i) + (j)', 'Patrimônio Líquido (j)', 'Resultados de Exercícios Futuros (i)', 'Outras Obrigações (g)', 'Depósitos à Vista (a1)', 'Passivo Oneroso'], axis=1)

#7. Passivo Oneroso Médio
BASE1 = BASEpas
BASE1 = BASE1[['Instituição','Data','Passivo Total (k) = (h) + (i) + (j)', 'Patrimônio Líquido (j)', 'Resultados de Exercícios Futuros (i)', 'Outras Obrigações (g)', 'Depósitos à Vista (a1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Passivo Oneroso'] = BASE1['Passivo Total (k) = (h) + (i) + (j)'] - BASE1['Patrimônio Líquido (j)'] - BASE1['Resultados de Exercícios Futuros (i)'] - BASE1['Outras Obrigações (g)'] - BASE1['Depósitos à Vista (a1)']
BASE1['Passivo Oneroso'] = BASE1['Passivo Oneroso'].div(1000000) 
BASE1 = BASE1[['Instituição','Data','Passivo Oneroso']] 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
# Valores anteriores a 12/2012 incluídos manualmente
BASE1.loc[-24] = ['BB', '12/2011', 630.006045]
BASE1.loc[-23] = ['BB', '03/2012', 644.256766]
BASE1.loc[-22] = ['BB', '06/2012', 675.017702]
BASE1.loc[-21] = ['BB', '09/2012', 711.090569]
BASE1.loc[-20] = ['ITAU', '12/2011', 539.434375]
BASE1.loc[-19] = ['ITAU', '03/2012', 551.255739]
BASE1.loc[-18] = ['ITAU', '06/2012', 541.996618]
BASE1.loc[-17] = ['ITAU', '09/2012', 593.515335]
BASE1.loc[-16] = ['CAIXA ECONÔMICA FEDERAL', '12/2011', 405.895598]
BASE1.loc[-15] = ['CAIXA ECONÔMICA FEDERAL', '03/2012', 451.913414]
BASE1.loc[-14] = ['CAIXA ECONÔMICA FEDERAL', '06/2012', 483.056696]
BASE1.loc[-13] = ['CAIXA ECONÔMICA FEDERAL', '09/2012', 541.463364]
BASE1.loc[-12] = ['BRADESCO', '12/2011', 482.323632]
BASE1.loc[-11] = ['BRADESCO', '03/2012', 499.007726]
BASE1.loc[-10] = ['BRADESCO', '06/2012', 517.134936]
BASE1.loc[-9] = ['BRADESCO', '09/2012', 532.193705]
BASE1.loc[-8] = ['SANTANDER', '12/2011', 256.471811]
BASE1.loc[-7] = ['SANTANDER', '03/2012', 252.681922]
BASE1.loc[-6] = ['SANTANDER', '06/2012', 266.559135]
BASE1.loc[-5] = ['SANTANDER', '09/2012', 268.610976]
BASE1.loc[-4] = ['BANRISUL', '12/2011', 22.958702]
BASE1.loc[-3] = ['BANRISUL', '03/2012', 25.072137]
BASE1.loc[-2] = ['BANRISUL', '06/2012', 26.033931]
BASE1.loc[-1] = ['BANRISUL', '09/2012', 27.440181]
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['Passivo Oneroso Anterior'] = BASE1['Passivo Oneroso'].shift(4, fill_value=0)
BASE1['Passivo Oneroso Nominal Médio'] = (BASE1['Passivo Oneroso Anterior']+BASE1['Passivo Oneroso'])/2
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Passivo Oneroso', 'Passivo Oneroso Anterior'], axis=1)

#8. Despesas Financeiras Anualizadas
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data','Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Despesa Financeira'] = BASE1['Despesas de Intermediação Financeira (b) = (b1) + (b2) + (b3) + (b4) + (b5)'] - BASE1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)']
BASE1['Despesa Financeira'] = BASE1['Despesa Financeira'].div(1000000) 
BASE1 = BASE1[['Instituição','Data','Despesa Financeira']] 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['DF'] = Sem1['Despesa Financeira']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['DF'] = np.where(Sem1['Tri']==1, Sem1['DF'], Sem1['DF'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','DF']] 
Jun.columns = ['Instituição', 'Data','Despesa Financeira'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Despesa Financeira']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['DF'] = Sem2['Despesa Financeira']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['DF'] = np.where(Sem2['Tri']==1, Sem2['DF'], Sem2['DF'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','DF']] 
Dez.columns = ['Instituição', 'Data','Despesa Financeira'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Despesa Financeira']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['DF'] = BASE1['Despesa Financeira']
BASE1['Despesa Financeira Nominal Anualizada'] = BASE1.DF.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Despesa Financeira', 'Despesa Financeira Nominal Anualizada']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Despesa Financeira'], axis=1)

#9. Despesas Financeiras Anualizadas relativamente aos Passivos Onerosos Médios
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Passivo Oneroso Nominal Médio', 'Despesa Financeira Nominal Anualizada']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Despesa Financeira Nominal Anualizada / Passivo Oneroso Nominal Médio'] = -BASE1['Despesa Financeira Nominal Anualizada'] / BASE1['Passivo Oneroso Nominal Médio']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Passivo Oneroso Nominal Médio', 'Despesa Financeira Nominal Anualizada'], axis=1)

#10. Total de Operações de Crédito relativamente ao Total de Ativos
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data','Ativo Total (k) = (i) - (j)', 'Operações de Crédito (d1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Operações de Crédito Total / Ativo'] = BASE1['Operações de Crédito (d1)'] / BASE1['Ativo Total (k) = (i) - (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativo Total (k) = (i) - (j)', 'Operações de Crédito (d1)'], axis=1)

#11. Participação de Mercado relativamente ao Total de Operações de Crédito
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data','Operações de Crédito (d1)']] 
BASE1['Total'] = BASE1.groupby('Data')['Operações de Crédito (d1)'].transform('sum')
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Operações de Crédito Total % Participação de Mercado'] = BASE1['Operações de Crédito (d1)'] / BASE1['Total']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Operações de Crédito (d1)', 'Total'], axis=1)

#12. Carteira de Crédito Classificada na Região Sul relativamente à Carteira de Crédito Classificada Total
BASE1 = BASEreg
BASE1 = BASE1[['Instituição','Data','Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
# Na base do Banco Central do Brasil, os totais dos trimestres de 03/2015, 06/2015 e 12/2015 da Região Sul estão erroneamente considerados na Região Sudeste - o equívovo foi corrigido no código seguinte.
BASE1['Região Sudeste'] = BASE1['Região Sudeste'].str.replace('.', '').astype(int)
BASE1['Região Sul'] = np.where(BASE1['Data'] == '03/2015', BASE1['Região Sudeste'], BASE1['Região Sul'])
BASE1['Região Sul'] = np.where(BASE1['Data'] == '06/2015', BASE1['Região Sudeste'], BASE1['Região Sul'])
BASE1['Região Sul'] = np.where(BASE1['Data'] == '12/2015', BASE1['Região Sudeste'], BASE1['Região Sul'])
# Não foram identificados valores para 06/2014 na base do Banco Central do Brasil - os valores de 03/2014 foram repetidos para 06/2014 no código seguinte.
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE2 = BASE1.loc[BASE1['Data'] == '03/2014']
BASE2.Data[BASE2.Data=='03/2014'] = '06/2014'
BASE1 = pd.concat([BASE1, BASE2])
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['% Carteira de Crédito Classificada na Região Sul / Carteira de Crédito Classificada Total'] = BASE1['Região Sul'] / BASE1['Carteira de Crédito Classificada']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada'], axis=1)

#13. Carteira de Empréstimos Consignados e Financiamento Rural (Pessoa Física) relativamente à Carteira de Crédito Classificada (no Brasil)
BASE1 = BASEreg
BASE1 = BASE1[['Instituição','Data','Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Exterior']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
# Não foram identificados valores para 06/2014 na base do Banco Central do Brasil - os valores de 03/2014 foram repetidos para 06/2014 no código seguinte.
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE2 = BASE1.loc[BASE1['Data'] == '03/2014']
BASE2.Data[BASE2.Data=='03/2014'] = '06/2014'
BASE1 = pd.concat([BASE1, BASE2])
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE2 = BASEcpf
BASE2 = BASE2[['Instituição','Data','Empréstimo com Consignação em Folha - Total', 'Financiamento Rural e Agroindustrial - Total']]
BASE1 = BASE1.merge(BASE2)
BASE1['% Carteira de Empréstimos Consignados e Financiamento Rural (Pessoa Física) / Carteira de Crédito Classificada (no Brasil)'] = ((BASE1['Empréstimo com Consignação em Folha - Total']+BASE1['Financiamento Rural e Agroindustrial - Total'])/ (BASE1['Carteira de Crédito Classificada']-BASE1['Exterior']))
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Empréstimo com Consignação em Folha - Total', 'Financiamento Rural e Agroindustrial - Total', 'Exterior'], axis=1)

#14. Carteira de Empréstimos Consignados Pessoa Física relativamente à Carteira de Crédito Classificada (no Brasil)
BASE1 = BASEreg
BASE1 = BASE1[['Instituição','Data','Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Exterior']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
# Não foram identificados valores para 06/2014 na base do Banco Central do Brasil - os valores de 03/2014 foram repetidos para 06/2014 no código seguinte.
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE2 = BASE1.loc[BASE1['Data'] == '03/2014']
BASE2.Data[BASE2.Data=='03/2014'] = '06/2014'
BASE1 = pd.concat([BASE1, BASE2])
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE2 = BASEcpf
BASE2 = BASE2[['Instituição','Data','Empréstimo com Consignação em Folha - Total']]
BASE1 = BASE1.merge(BASE2)
BASE1['% Carteira de Empréstimos Consignados Pessoa Física / Carteira de Crédito Classificada (no Brasil)'] = ((BASE1['Empréstimo com Consignação em Folha - Total'])/ (BASE1['Carteira de Crédito Classificada']-BASE1['Exterior']))
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Empréstimo com Consignação em Folha - Total','Exterior'], axis=1)

#15. Carteira de Financiamento Rural Pessoa Física relativamente à Carteira de Crédito Classificada (no Brasil)
BASE1 = BASEreg
BASE1 = BASE1[['Instituição','Data','Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Exterior']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
# Não foram identificados valores para 06/2014 na base do Banco Central do Brasil - os valores de 03/2014 foram repetidos para 06/2014 no código seguinte.
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE2 = BASE1.loc[BASE1['Data'] == '03/2014']
BASE2.Data[BASE2.Data=='03/2014'] = '06/2014'
BASE1 = pd.concat([BASE1, BASE2])
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE2 = BASEcpf
BASE2 = BASE2[['Instituição','Data','Financiamento Rural e Agroindustrial - Total']]
BASE1 = BASE1.merge(BASE2)
BASE1['% Carteira de Financiamento Rural Pessoa Física / Carteira de Crédito Classificada (no Brasil)'] = ((BASE1['Financiamento Rural e Agroindustrial - Total'])/ (BASE1['Carteira de Crédito Classificada']-BASE1['Exterior']))
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Região Sul', 'Região Sudeste', 'Carteira de Crédito Classificada', 'Financiamento Rural e Agroindustrial - Total', 'Exterior'], axis=1)

#16. Provisão para Créditos de Difícil Liquidação relativamente ao Total de Operações de Crédito
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data','Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito (d1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Provisão para Créditos de Difícil Liquidação / Operações de Crédito'] = -BASE1['Provisão sobre Operações de Crédito (d2)'] / BASE1['Operações de Crédito (d1)']
BASE = BASE.merge(BASE1)

#17. Carteira de Operações de Crédito "D ou pior" relativamente à Carteira de Crédito Classificada (no Brasil)
BASE1 = BASEris
BASE1 = BASE1[['Instituição','Data','Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Total Exterior']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Carteira de Operações de Crédito "D ou pior" / Carteira de Crédito Classificada (no Brasil)'] = (BASE1['Carteira de Crédito Classificada'] - BASE1['Nível AA'] - BASE1['Nível A'] - BASE1['Nível B'] - BASE1['Nível C'] - BASE1['Total Exterior']) / (BASE1['Carteira de Crédito Classificada'] - BASE1['Total Exterior'])
BASE = BASE.merge(BASE1)

#18. Provisão para Créditos de Difícil Liquidação relativamente à Carteira de Operações de Crédito "D ou pior"
BASE['% Provisão para Créditos de Difícil Liquidação / Carteira de Operações de Crédito "D ou pior"'] = -BASE['Provisão sobre Operações de Crédito (d2)'] / (BASE['Carteira de Crédito Classificada'] - BASE['Nível AA'] - BASE['Nível A'] - BASE['Nível B'] - BASE['Nível C'] - BASE['Total Exterior'])
BASE = BASE.drop(['Carteira de Crédito Classificada', 'Nível AA', 'Nível A', 'Nível B', 'Nível C', 'Total Exterior'], axis=1)

#19. Valores de Operações de Crédito vencidos há mais de 14 dias relativamente à Carteira de Crédito Classificada (no Brasil)
BASE0 = BASEcpj
BASE0 = BASE0[BASE0['Investimento - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Operações com Recebíveis - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Comércio Exterior - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Outros Créditos - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Rural e Agroindustrial - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0 = BASE0[BASE0['Habitacional - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE0.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/BaseCPJ.csv', index=False, encoding='utf-8-sig', sep=';')
BASE1 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/BaseCPJ.csv', encoding='utf-8-sig', sep=';', thousands='.', low_memory=False)
BASE1 = BASE1[['Instituição','Data','Capital de Giro - Vencido a Partir de 15 Dias', 'Investimento - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Habitacional - Vencido a Partir de 15 Dias']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Parcelas de Operações de Crédito vencidas há mais de 14 dias (PJ)'] = BASE1['Capital de Giro - Vencido a Partir de 15 Dias'] + BASE1['Investimento - Vencido a Partir de 15 Dias'] + BASE1['Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias'] + BASE1['Operações com Recebíveis - Vencido a Partir de 15 Dias'] + BASE1['Comércio Exterior - Vencido a Partir de 15 Dias'] + BASE1['Outros Créditos - Vencido a Partir de 15 Dias'] + BASE1['Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias'] + BASE1['Rural e Agroindustrial - Vencido a Partir de 15 Dias'] + BASE1['Habitacional - Vencido a Partir de 15 Dias']
BASE1= BASE1.drop(['Capital de Giro - Vencido a Partir de 15 Dias', 'Investimento - Vencido a Partir de 15 Dias', 'Cheque Especial e Conta Garantida - Vencido a Partir de 15 Dias', 'Operações com Recebíveis - Vencido a Partir de 15 Dias', 'Comércio Exterior - Vencido a Partir de 15 Dias', 'Outros Créditos - Vencido a Partir de 15 Dias', 'Financiamento de Infraestrutura/Desenvolvimento/Projeto e Outros Créditos - Vencido a Partir de 15 Dias', 'Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Habitacional - Vencido a Partir de 15 Dias'], axis=1)
BASE2 = BASEcpf
BASE2 = BASE2[BASE2['Financiamento de Veículos - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE2 = BASE2[BASE2['Financiamento Habitacional - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE2 = BASE2[BASE2['Cartão de Crédito - Vencido a Partir de 15 Dias'].str.contains('NI')==False]
BASE2.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/BaseCPF.csv', index=False, encoding='utf-8-sig', sep=';')
BASE3 = pd.read_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp/BaseCPF.csv', encoding='utf-8-sig', sep=';', thousands='.', low_memory=False)
BASE3 = BASE3[['Instituição','Data','Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Outros Créditos - Vencido a Partir de 15 Dias']]
BASE3=BASE3.loc[(BASE3['Instituição'] == 'BANRISUL') | (BASE3['Instituição'] == 'BB') | (BASE3['Instituição'] == 'BRADESCO') | (BASE3['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE3['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE3['Instituição'] == 'ITAU') | (BASE3['Instituição'] == 'SANTANDER')]
BASE3['Parcelas de Operações de Crédito vencidas há mais de 14 dias (PF)'] = BASE3['Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias'] + BASE3['Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias'] + BASE3['Financiamento de Veículos - Vencido a Partir de 15 Dias'] + BASE3['Financiamento Habitacional - Vencido a Partir de 15 Dias'] + BASE3['Cartão de Crédito - Vencido a Partir de 15 Dias'] + BASE3['Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias'] + BASE3['Outros Créditos - Vencido a Partir de 15 Dias']
BASE3= BASE3.drop(['Empréstimo com Consignação em Folha - Vencido a Partir de 15 Dias', 'Empréstimo sem Consignação em Folha - Vencido a Partir de 15 Dias', 'Financiamento de Veículos - Vencido a Partir de 15 Dias', 'Financiamento Habitacional - Vencido a Partir de 15 Dias', 'Cartão de Crédito - Vencido a Partir de 15 Dias', 'Financiamento Rural e Agroindustrial - Vencido a Partir de 15 Dias', 'Outros Créditos - Vencido a Partir de 15 Dias'], axis=1)
BASE4 = BASE3.merge(BASE1)
BASE4['Parcelas de Operações de Crédito vencidas há mais de 14 dias'] = BASE4['Parcelas de Operações de Crédito vencidas há mais de 14 dias (PF)'] + BASE4['Parcelas de Operações de Crédito vencidas há mais de 14 dias (PJ)']
BASE4= BASE4.drop(['Parcelas de Operações de Crédito vencidas há mais de 14 dias (PF)', 'Parcelas de Operações de Crédito vencidas há mais de 14 dias (PJ)'], axis=1)
BASE4['Data'] = pd.to_datetime(BASE4['Data']) 
BASE4 = BASE4.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1 = BASEreg
BASE1 = BASE1[['Instituição','Data','Carteira de Crédito Classificada', 'Exterior']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
# Não foram identificados valores para 06/2014 na base do Banco Central do Brasil - os valores de 03/2014 foram repetidos para 06/2014 no código seguinte.
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE2 = BASE1.loc[BASE1['Data'] == '03/2014']
BASE2.Data[BASE2.Data=='03/2014'] = '06/2014'
BASE1 = pd.concat([BASE1, BASE2])
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1 = BASE1.merge(BASE4)
BASE1['% Valores de Operações de Crédito vencidos há mais de 14 dias / Carteira de Crédito Classificada (no Brasil)'] = BASE1['Parcelas de Operações de Crédito vencidas há mais de 14 dias'] / (BASE1['Carteira de Crédito Classificada'] - BASE1['Exterior'])
BASE = BASE.merge(BASE1)
# Deletar arquivos .csv temporários
directory='C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Temp'
os.chdir(directory)
files=glob.glob('*.csv')
for filename in files:
    os.unlink(filename)

#20. Provisão para Créditos de Difícil Liquidação relativamente aos Valores de Operações de Crédito vencidos há mais de 14 dias    
BASE['% Provisão para Créditos de Difícil Liquidação / Valores de Operações de Crédito vencidos há mais de 14 dias'] = -BASE['Provisão sobre Operações de Crédito (d2)'] / BASE['Parcelas de Operações de Crédito vencidas há mais de 14 dias']
BASE = BASE.drop(['Provisão sobre Operações de Crédito (d2)', 'Operações de Crédito (d1)'], axis=1)    
BASE = BASE.drop(['Exterior', 'Parcelas de Operações de Crédito vencidas há mais de 14 dias'], axis=1)    
BASE['Carteira de Crédito Classificada'] = BASE['Carteira de Crédito Classificada'].div(1000000) 

#21. Saldo Médio de Operações de Crédito
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data','Operações de Crédito (d1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Operações de Crédito (d1)'] = BASE1['Operações de Crédito (d1)'].div(1000000) 
BASE1 = BASE1[['Instituição','Data','Operações de Crédito (d1)']] 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
# Valores anteriores a 12/2012 incluídos manualmente
BASE1.loc[-24] = ['BB', '12/2011', 369.963440]
BASE1.loc[-23] = ['BB', '03/2012', 376.141408]
BASE1.loc[-22] = ['BB', '06/2012', 401.316324]
BASE1.loc[-21] = ['BB', '09/2012', 420.267809]
BASE1.loc[-20] = ['ITAU', '12/2011', 287.306055]
BASE1.loc[-19] = ['ITAU', '03/2012', 292.988916]
BASE1.loc[-18] = ['ITAU', '06/2012', 303.074556]
BASE1.loc[-17] = ['ITAU', '09/2012', 307.047983]
BASE1.loc[-16] = ['CAIXA ECONÔMICA FEDERAL', '12/2011', 249.548776]
BASE1.loc[-15] = ['CAIXA ECONÔMICA FEDERAL', '03/2012', 268.830701]
BASE1.loc[-14] = ['CAIXA ECONÔMICA FEDERAL', '06/2012', 297.600834]
BASE1.loc[-13] = ['CAIXA ECONÔMICA FEDERAL', '09/2012', 324.498805]
BASE1.loc[-12] = ['BRADESCO', '12/2011', 237.008549]
BASE1.loc[-11] = ['BRADESCO', '03/2012', 239.515979]
BASE1.loc[-10] = ['BRADESCO', '06/2012', 248.458758]
BASE1.loc[-9] = ['BRADESCO', '09/2012', 253.793386]
BASE1.loc[-8] = ['SANTANDER', '12/2011', 172.713683]
BASE1.loc[-7] = ['SANTANDER', '03/2012', 175.522638]
BASE1.loc[-6] = ['SANTANDER', '06/2012', 180.987322]
BASE1.loc[-5] = ['SANTANDER', '09/2012', 182.358153]
BASE1.loc[-4] = ['BANRISUL', '12/2011', 19.751542]
BASE1.loc[-3] = ['BANRISUL', '03/2012', 20.654095]
BASE1.loc[-2] = ['BANRISUL', '06/2012', 21.833600]
BASE1.loc[-1] = ['BANRISUL', '09/2012', 22.666375]
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['Total de Operações de Crédito Anterior'] = BASE1['Operações de Crédito (d1)'].shift(4, fill_value=0)
BASE1['Saldo Médio de Operações de Crédito'] = (BASE1['Total de Operações de Crédito Anterior']+BASE1['Operações de Crédito (d1)'])/2
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Operações de Crédito (d1)', 'Total de Operações de Crédito Anterior'], axis=1)

#22. Receitas Financeiras Anualizadas (de Operações de Crédito) 
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data','Rendas de Operações de Crédito (a1)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Rendas de Operações de Crédito (a1)'] = BASE1['Rendas de Operações de Crédito (a1)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['ROC'] = Sem1['Rendas de Operações de Crédito (a1)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['ROC'] = np.where(Sem1['Tri']==1, Sem1['ROC'], Sem1['ROC'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','ROC']] 
Jun.columns = ['Instituição', 'Data','Rendas de Operações de Crédito (a1)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Rendas de Operações de Crédito (a1)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['ROC'] = Sem2['Rendas de Operações de Crédito (a1)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['ROC'] = np.where(Sem2['Tri']==1, Sem2['ROC'], Sem2['ROC'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','ROC']] 
Dez.columns = ['Instituição', 'Data','Rendas de Operações de Crédito (a1)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Rendas de Operações de Crédito (a1)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['ROC'] = BASE1['Rendas de Operações de Crédito (a1)']
BASE1['Receita Financeira (de clientes) Nominal Anualizada'] = BASE1.ROC.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Rendas de Operações de Crédito (a1)', 'Receita Financeira (de clientes) Nominal Anualizada']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Rendas de Operações de Crédito (a1)'], axis=1)

#23. Receitas Financeiras Anualizadas (de Operações de Crédito) relativamente ao Saldo Médio de Operações de Crédito
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Saldo Médio de Operações de Crédito', 'Receita Financeira (de clientes) Nominal Anualizada']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Receita Financeira (de clientes) Nominal Anualizada / Saldo Médio de Operações de Crédito'] = BASE1['Receita Financeira (de clientes) Nominal Anualizada'] / BASE1['Saldo Médio de Operações de Crédito']
BASE = BASE.merge(BASE1)

#24. Total de Ativos Rentáveis relativamente ao Total de Ativos
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data','Ativo Total (k) = (i) - (j)', 'Provisão sobre Operações de Crédito (d2)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Ativo Rentável'] = BASE1['Ativo Total (k) = (i) - (j)'] - BASE1['Provisão sobre Operações de Crédito (d2)'] - BASE1['Outros Ativos Realizáveis (g)'] - BASE1['Permanente Ajustado (h)'] 
BASE1['% Ativo Rentável / Ativo Total'] = BASE1['Ativo Rentável'] / BASE1['Ativo Total (k) = (i) - (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativo Total (k) = (i) - (j)', 'Provisão sobre Operações de Crédito (d2)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)', 'Ativo Rentável'], axis=1)

#25. Ativo Rentável Médio
BASE1 = BASEati
BASE1 = BASE1[['Instituição','Data', 'Ativo Total (k) = (i) - (j)', 'Provisão sobre Operações de Crédito (d2)', 'Outros Ativos Realizáveis (g)', 'Permanente Ajustado (h)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Ativos Rentáveis'] = BASE1['Ativo Total (k) = (i) - (j)'] - BASE1['Provisão sobre Operações de Crédito (d2)'] - BASE1['Outros Ativos Realizáveis (g)'] - BASE1['Permanente Ajustado (h)']
BASE1['Ativos Rentáveis'] = BASE1['Ativos Rentáveis'].div(1000000) 
BASE1 = BASE1[['Instituição','Data','Ativos Rentáveis']] 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
# Valores anteriores a 12/2012 incluídos manualmente
BASE1.loc[-24] = ['BB', '12/2011', 752.214309]
BASE1.loc[-23] = ['BB', '03/2012', 765.09353]
BASE1.loc[-22] = ['BB', '06/2012', 814.44648]
BASE1.loc[-21] = ['BB', '09/2012', 867.326398]
BASE1.loc[-20] = ['ITAU', '12/2011', 667.439967]
BASE1.loc[-19] = ['ITAU', '03/2012', 731.615632]
BASE1.loc[-18] = ['ITAU', '06/2012', 715.709238]
BASE1.loc[-17] = ['ITAU', '09/2012', 778.888748]
BASE1.loc[-16] = ['CAIXA ECONÔMICA FEDERAL', '12/2011', 421.439741]
BASE1.loc[-15] = ['CAIXA ECONÔMICA FEDERAL', '03/2012', 464.985877]
BASE1.loc[-14] = ['CAIXA ECONÔMICA FEDERAL', '06/2012', 498.855151]
BASE1.loc[-13] = ['CAIXA ECONÔMICA FEDERAL', '09/2012', 573.153079]
BASE1.loc[-12] = ['BRADESCO', '12/2011', 555.167455]
BASE1.loc[-11] = ['BRADESCO', '03/2012', 589.317567]
BASE1.loc[-10] = ['BRADESCO', '06/2012', 616.409699]
BASE1.loc[-9] = ['BRADESCO', '09/2012', 638.893141]
BASE1.loc[-8] = ['SANTANDER', '12/2011', 359.357094]
BASE1.loc[-7] = ['SANTANDER', '03/2012', 352.223215]
BASE1.loc[-6] = ['SANTANDER', '06/2012', 379.90184]
BASE1.loc[-5] = ['SANTANDER', '09/2012', 385.887229]
BASE1.loc[-4] = ['BANRISUL', '12/2011', 33.646781]
BASE1.loc[-3] = ['BANRISUL', '03/2012', 35.853114]
BASE1.loc[-2] = ['BANRISUL', '06/2012', 38.342987]
BASE1.loc[-1] = ['BANRISUL', '09/2012', 39.964974]
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['Ativos Rentáveis Anterior'] = BASE1['Ativos Rentáveis'].shift(4, fill_value=0)
BASE1['Ativos Rentáveis Médios'] = (BASE1['Ativos Rentáveis Anterior']+BASE1['Ativos Rentáveis'])/2
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Rentáveis', 'Ativos Rentáveis Anterior'], axis=1)

#26. Receitas Financeiras Anualizadas
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data','Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Receitas Financeiras'] = BASE1['Receitas de Intermediação Financeira (a) = (a1) + (a2) + (a3) + (a4) + (a5) + (a6)']
BASE1['Receitas Financeiras'] = BASE1['Receitas Financeiras'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['RF'] = Sem1['Receitas Financeiras']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['RF'] = np.where(Sem1['Tri']==1, Sem1['RF'], Sem1['RF'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','RF']] 
Jun.columns = ['Instituição', 'Data','Receitas Financeiras'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Receitas Financeiras']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['RF'] = Sem2['Receitas Financeiras']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['RF'] = np.where(Sem2['Tri']==1, Sem2['RF'], Sem2['RF'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','RF']] 
Dez.columns = ['Instituição', 'Data','Receitas Financeiras'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Receitas Financeiras']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['RF'] = BASE1['Receitas Financeiras']
BASE1['Receita Financeira Nominal Anualizada'] = BASE1.RF.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Receitas Financeiras', 'Receita Financeira Nominal Anualizada']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Receitas Financeiras'], axis=1)

#27. Receitas Financeiras Anualizadas relativamente aos Ativos Rentáveis Médios
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Ativos Rentáveis Médios', 'Receita Financeira Nominal Anualizada']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Receita Financeira Nominal Anualizada / Ativo Rentável Médio'] = BASE1['Receita Financeira Nominal Anualizada'] / BASE1['Ativos Rentáveis Médios']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Receita Financeira Nominal Anualizada'], axis=1)

#28. Lucro Líquido Nominal Anualizado
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data','Lucro Líquido (j) = (g) + (h) + (i)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Lucro Líquido (j) = (g) + (h) + (i)'] = BASE1['Lucro Líquido (j) = (g) + (h) + (i)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['LL'] = Sem1['Lucro Líquido (j) = (g) + (h) + (i)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['LL'] = np.where(Sem1['Tri']==1, Sem1['LL'], Sem1['LL'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','LL']] 
Jun.columns = ['Instituição', 'Data','Lucro Líquido (j) = (g) + (h) + (i)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Lucro Líquido (j) = (g) + (h) + (i)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['LL'] = Sem2['Lucro Líquido (j) = (g) + (h) + (i)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['LL'] = np.where(Sem2['Tri']==1, Sem2['LL'], Sem2['LL'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','LL']] 
Dez.columns = ['Instituição', 'Data','Lucro Líquido (j) = (g) + (h) + (i)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Lucro Líquido (j) = (g) + (h) + (i)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['LL'] = BASE1['Lucro Líquido (j) = (g) + (h) + (i)']
BASE1['Lucro Líquido Nominal Anualizado'] = BASE1.LL.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Lucro Líquido (j) = (g) + (h) + (i)', 'Lucro Líquido Nominal Anualizado']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Lucro Líquido (j) = (g) + (h) + (i)'], axis=1)

#29. Lucro Líquido Real Anualizado
BASE = BASE.merge(IPCA)
BASE = BASE.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE['Lucro Líquido Real Anualizado'] = (BASE['Lucro Líquido Nominal Anualizado'] / BASE['IPCA Fator']) * BASE['IPCA Fator'].iloc[-1]
BASE = BASE.drop(['IPCA Mensal', 'IPCA Fator'], axis=1)

#30. BANRISUL - Proventos Distribuídos relativamente ao Lucro Líquido do Exercício (Payout)
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Lucro Líquido Nominal Anualizado']]
BASE1 = BASE1.loc[BASE1['Instituição'] == ('BANRISUL')] 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
BASE1 = BASE1[BASE1['Data'].str.startswith('12/')]
BASE2 = DIV
BASE2['Proventos Distribuídos'] = BASE2['Proventos'].div(1000) 
BASE1 = BASE1.merge(BASE2)
BASE1['%Proventos Distribuídos'] = BASE1['Proventos Distribuídos'] / BASE1['Lucro Líquido Nominal Anualizado']
BASE1 = BASE1.drop(['Lucro Líquido Nominal Anualizado', 'Proventos'], axis=1)
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1, how='left')

#31. Patrimônio Líquido Médio
BASE1 = BASEpas
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido (j)']] 
BASE1.columns = ['Instituição', 'Data','Patrimônio Líquido Nominal'] 
BASE1['Patrimônio Líquido Nominal'] = BASE1['Patrimônio Líquido Nominal'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
# Valores anteriores a 12/2012 incluídos manualmente
BASE1.loc[-24] = ['BB', '12/2011', 58.592587]
BASE1.loc[-23] = ['BB', '03/2012', 60.276651]
BASE1.loc[-22] = ['BB', '06/2012', 62.528364]
BASE1.loc[-21] = ['BB', '09/2012', 64.400900]
BASE1.loc[-20] = ['ITAU', '12/2011', 72.528414]
BASE1.loc[-19] = ['ITAU', '03/2012', 73.640578]
BASE1.loc[-18] = ['ITAU', '06/2012', 76.886624]
BASE1.loc[-17] = ['ITAU', '09/2012', 80.244916]
BASE1.loc[-16] = ['CAIXA ECONÔMICA FEDERAL', '12/2011', 19.561381]
BASE1.loc[-15] = ['CAIXA ECONÔMICA FEDERAL', '03/2012', 20.522978]
BASE1.loc[-14] = ['CAIXA ECONÔMICA FEDERAL', '06/2012', 21.397946]
BASE1.loc[-13] = ['CAIXA ECONÔMICA FEDERAL', '09/2012', 22.460366]
BASE1.loc[-12] = ['BRADESCO', '12/2011', 55.767699]
BASE1.loc[-11] = ['BRADESCO', '03/2012', 58.246679]
BASE1.loc[-10] = ['BRADESCO', '06/2012', 64.107300]
BASE1.loc[-9] = ['BRADESCO', '09/2012', 66.233425]
BASE1.loc[-8] = ['SANTANDER', '12/2011', 66.122836]
BASE1.loc[-7] = ['SANTANDER', '03/2012', 66.659056]
BASE1.loc[-6] = ['SANTANDER', '06/2012', 66.386234]
BASE1.loc[-5] = ['SANTANDER', '09/2012', 66.379761]
BASE1.loc[-4] = ['BANRISUL', '12/2011', 4.400290]
BASE1.loc[-3] = ['BANRISUL', '03/2012', 4.551251]
BASE1.loc[-2] = ['BANRISUL', '06/2012', 4.653001]
BASE1.loc[-1] = ['BANRISUL', '09/2012', 4.800151]
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['Patrimônio Líquido Nominal Anterior'] = BASE1['Patrimônio Líquido Nominal'].shift(4, fill_value=0)
BASE1['Patrimônio Líquido Nominal Médio'] = (BASE1['Patrimônio Líquido Nominal Anterior']+BASE1['Patrimônio Líquido Nominal'])/2
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Patrimônio Líquido Nominal', 'Patrimônio Líquido Nominal Anterior'], axis=1)

#32. Retorno Anualizado sobre o Patrimônio Líquido Médio (ROAE)
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Lucro Líquido Nominal Anualizado']]
BASE1['%Retorno Anualizado sobre o Patrimônio Líquido Médio'] = BASE1['Lucro Líquido Nominal Anualizado'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1 = BASE1.drop(['Lucro Líquido Nominal Anualizado', 'Patrimônio Líquido Nominal Médio'], axis=1)
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)

#33. Margem Financeira Anualizada
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data','Resultado de Intermediação Financeira (c) = (a) + (b)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Margem Financeira'] = BASE1['Resultado de Intermediação Financeira (c) = (a) + (b)'] - BASE1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)']
BASE1['Margem Financeira'] = BASE1['Margem Financeira'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['MF'] = Sem1['Margem Financeira']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['MF'] = np.where(Sem1['Tri']==1, Sem1['MF'], Sem1['MF'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','MF']] 
Jun.columns = ['Instituição', 'Data','Margem Financeira'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Margem Financeira']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['MF'] = Sem2['Margem Financeira']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['MF'] = np.where(Sem2['Tri']==1, Sem2['MF'], Sem2['MF'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','MF']] 
Dez.columns = ['Instituição', 'Data','Margem Financeira'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Margem Financeira']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['MF'] = BASE1['Margem Financeira']
BASE1['Margem Financeira Nominal Anualizada'] = BASE1.MF.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Margem Financeira', 'Margem Financeira Nominal Anualizada']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Margem Financeira'], axis=1)

#34. Margem Financeira Anualizada relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Margem Financeira Nominal Anualizada']]
BASE1['%Margem Financeira Anualizada relativamente ao Patrimônio Líquido Médio'] = BASE1['Margem Financeira Nominal Anualizada'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1 = BASE1.drop(['Margem Financeira Nominal Anualizada'], axis=1)
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)

#35. Margem Financeira Anualizada relativamente aos Ativos Rentáveis Médios
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Margem Financeira Nominal Anualizada', 'Ativos Rentáveis Médios']]
BASE1['%Margem Financeira Anualizada relativamente aos Ativos Rentáveis Médios'] = BASE1['Margem Financeira Nominal Anualizada'] / BASE1['Ativos Rentáveis Médios']
BASE1 = BASE1.drop(['Margem Financeira Nominal Anualizada'], axis=1)
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)

#36. Margem Financeira Anualizada (de Operações de Crédito) relativamente ao Saldo Médio de Operações de Crédito
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Saldo Médio de Operações de Crédito', 'Receita Financeira (de clientes) Nominal Anualizada', '% Despesa Financeira Nominal Anualizada / Passivo Oneroso Nominal Médio', 'Ativos Rentáveis Médios']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['%Margem Financeira (de Operações de Crédito) Anualizada relativamente ao Saldo Médio de Operações de Crédito'] = (BASE1['Receita Financeira (de clientes) Nominal Anualizada']-(BASE1['% Despesa Financeira Nominal Anualizada / Passivo Oneroso Nominal Médio']*BASE1['Saldo Médio de Operações de Crédito']))/BASE1['Saldo Médio de Operações de Crédito']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Saldo Médio de Operações de Crédito', 'Receita Financeira (de clientes) Nominal Anualizada', 'Ativos Rentáveis Médios'], axis=1)

#37. Despesas Anualizadas com Provisão para Créditos de Difícil Liquidação
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)'] = BASE1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['PCDL'] = Sem1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['PCDL'] = np.where(Sem1['Tri']==1, Sem1['PCDL'], Sem1['PCDL'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','PCDL']] 
Jun.columns = ['Instituição', 'Data','Resultado de Provisão para Créditos de Difícil Liquidação (b5)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Resultado de Provisão para Créditos de Difícil Liquidação (b5)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['PCDL'] = Sem2['Resultado de Provisão para Créditos de Difícil Liquidação (b5)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['PCDL'] = np.where(Sem2['Tri']==1, Sem2['PCDL'], Sem2['PCDL'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','PCDL']] 
Dez.columns = ['Instituição', 'Data','Resultado de Provisão para Créditos de Difícil Liquidação (b5)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Resultado de Provisão para Créditos de Difícil Liquidação (b5)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['PCDL'] = BASE1['Resultado de Provisão para Créditos de Difícil Liquidação (b5)']
BASE1['Resultado de Provisão para Créditos de Difícil Liquidação Nominal Anualizada'] = BASE1.PCDL.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Resultado de Provisão para Créditos de Difícil Liquidação Nominal Anualizada']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Resultado de Provisão para Créditos de Difícil Liquidação (b5)'], axis=1)

#38. Despesas Anualizadas com Provisão para Créditos de Difícil Liquidação relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Resultado de Provisão para Créditos de Difícil Liquidação Nominal Anualizada']]
BASE1['%Provisão para Créditos de Difícil Liquidação Anualizada relativamente ao Patrimônio Líquido Médio'] = BASE1['Resultado de Provisão para Créditos de Difícil Liquidação Nominal Anualizada'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Resultado de Provisão para Créditos de Difícil Liquidação Nominal Anualizada'], axis=1)

#39. Receitas Anualizadas com Tarifas e Serviços
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Rendas de Prestação de Serviços (d1)', 'Rendas de Tarifas Bancárias (d2)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Resultado com Tarifas e Serviços'] = BASE1['Rendas de Prestação de Serviços (d1)'] + BASE1['Rendas de Tarifas Bancárias (d2)']
BASE1['Resultado com Tarifas e Serviços'] = BASE1['Resultado com Tarifas e Serviços'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['SER'] = Sem1['Resultado com Tarifas e Serviços']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['SER'] = np.where(Sem1['Tri']==1, Sem1['SER'], Sem1['SER'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','SER']] 
Jun.columns = ['Instituição', 'Data','Resultado com Tarifas e Serviços'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Resultado com Tarifas e Serviços']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['SER'] = Sem2['Resultado com Tarifas e Serviços']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['SER'] = np.where(Sem2['Tri']==1, Sem2['SER'], Sem2['SER'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','SER']] 
Dez.columns = ['Instituição', 'Data','Resultado com Tarifas e Serviços'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Resultado com Tarifas e Serviços']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['SER'] = BASE1['Resultado com Tarifas e Serviços']
BASE1['Receitas Anualizadas com Tarifas e Serviços'] = BASE1.SER.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Resultado com Tarifas e Serviços', 'Receitas Anualizadas com Tarifas e Serviços']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Resultado com Tarifas e Serviços'], axis=1)

#40. Receitas Anualizadas com Tarifas e Serviços relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Receitas Anualizadas com Tarifas e Serviços']]
BASE1['%Receitas Anualizadas com Tarifas e Serviços relativamente ao Patrimônio Líquido Médio'] = BASE1['Receitas Anualizadas com Tarifas e Serviços'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Receitas Anualizadas com Tarifas e Serviços'], axis=1)

#41. Despesas Anualizadas de Pessoal
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Despesas de Pessoal (d3)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Despesas de Pessoal (d3)'] = BASE1['Despesas de Pessoal (d3)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['PES'] = Sem1['Despesas de Pessoal (d3)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['PES'] = np.where(Sem1['Tri']==1, Sem1['PES'], Sem1['PES'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','PES']] 
Jun.columns = ['Instituição', 'Data','Despesas de Pessoal (d3)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Despesas de Pessoal (d3)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['PES'] = Sem2['Despesas de Pessoal (d3)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['PES'] = np.where(Sem2['Tri']==1, Sem2['PES'], Sem2['PES'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','PES']] 
Dez.columns = ['Instituição', 'Data','Despesas de Pessoal (d3)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Despesas de Pessoal (d3)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['PES'] = BASE1['Despesas de Pessoal (d3)']
BASE1['Despesas Anualizadas de Pessoal'] = BASE1.PES.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Despesas de Pessoal (d3)', 'Despesas Anualizadas de Pessoal']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Despesas de Pessoal (d3)'], axis=1)

#42. Despesas Anualizadas de Pessoal relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Despesas Anualizadas de Pessoal']]
BASE1['%Despesas Anualizadas de Pessoal relativamente ao Patrimônio Líquido Médio'] = BASE1['Despesas Anualizadas de Pessoal'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Despesas Anualizadas de Pessoal'], axis=1)

#43. Despesas Administrativas Anualizadas
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Despesas Administrativas (d4)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Despesas Administrativas (d4)'] = BASE1['Despesas Administrativas (d4)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['ADM'] = Sem1['Despesas Administrativas (d4)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['ADM'] = np.where(Sem1['Tri']==1, Sem1['ADM'], Sem1['ADM'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','ADM']] 
Jun.columns = ['Instituição', 'Data','Despesas Administrativas (d4)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Despesas Administrativas (d4)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['ADM'] = Sem2['Despesas Administrativas (d4)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['ADM'] = np.where(Sem2['Tri']==1, Sem2['ADM'], Sem2['ADM'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','ADM']] 
Dez.columns = ['Instituição', 'Data','Despesas Administrativas (d4)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Despesas Administrativas (d4)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['ADM'] = BASE1['Despesas Administrativas (d4)']
BASE1['Despesas Administrativas Anualizadas'] = BASE1.ADM.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Despesas Administrativas (d4)', 'Despesas Administrativas Anualizadas']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Despesas Administrativas (d4)'], axis=1)

#44. Despesas Administrativas Anualizadas relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Despesas Administrativas Anualizadas']]
BASE1['%Despesas Administrativas Anualizadas relativamente ao Patrimônio Líquido Médio'] = BASE1['Despesas Administrativas Anualizadas'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Despesas Administrativas Anualizadas'], axis=1)

#45. Outras Receitas e Despesas Anualizadas
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Despesas Tributárias (d5)', 'Resultado de Participações (d6)', 'Outras Receitas Operacionais (d7)', 'Outras Despesas Operacionais (d8)', 'Resultado Não Operacional (f)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Outras Receitas e Despesas'] = BASE1['Despesas Tributárias (d5)'] + BASE1['Resultado de Participações (d6)'] + BASE1['Outras Receitas Operacionais (d7)'] + BASE1['Outras Despesas Operacionais (d8)'] + BASE1['Resultado Não Operacional (f)']
BASE1['Outras Receitas e Despesas'] = BASE1['Outras Receitas e Despesas'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['OUT'] = Sem1['Outras Receitas e Despesas']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['OUT'] = np.where(Sem1['Tri']==1, Sem1['OUT'], Sem1['OUT'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','OUT']] 
Jun.columns = ['Instituição', 'Data','Outras Receitas e Despesas'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Outras Receitas e Despesas']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['OUT'] = Sem2['Outras Receitas e Despesas']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['OUT'] = np.where(Sem2['Tri']==1, Sem2['OUT'], Sem2['OUT'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','OUT']] 
Dez.columns = ['Instituição', 'Data','Outras Receitas e Despesas'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Outras Receitas e Despesas']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['OUT'] = BASE1['Outras Receitas e Despesas']
BASE1['Outras Receitas e Despesas Anualizadas'] = BASE1.OUT.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Outras Receitas e Despesas', 'Outras Receitas e Despesas Anualizadas']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Outras Receitas e Despesas'], axis=1)

#46. Outras Receitas e Despesas Anualizadas relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Outras Receitas e Despesas Anualizadas']]
BASE1['%Outras Receitas e Despesas Anualizadas relativamente ao Patrimônio Líquido Médio'] = BASE1['Outras Receitas e Despesas Anualizadas'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Outras Receitas e Despesas Anualizadas'], axis=1)

#47. Índice de Eficiência
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Numerador'] = - BASE1['Despesas de Pessoal (d3)'] - BASE1['Despesas Administrativas (d4)']
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['NUM'] = Sem1['Numerador']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['NUM'] = np.where(Sem1['Tri']==1, Sem1['NUM'], Sem1['NUM'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','NUM']] 
Jun.columns = ['Instituição', 'Data','Numerador'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Numerador']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['NUM'] = Sem2['Numerador']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['NUM'] = np.where(Sem2['Tri']==1, Sem2['NUM'], Sem2['NUM'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','NUM']] 
Dez.columns = ['Instituição', 'Data','Numerador'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Numerador']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['NUM'] = BASE1['Numerador']
BASE1['Numerador Anualizado'] = BASE1.NUM.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Numerador', 'Numerador Anualizado']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE1 = BASE1.drop(['Numerador'], axis=1)
BASE2 = BASEluc
BASE2 = BASE2[['Instituição','Data','Resultado de Intermediação Financeira (c) = (a) + (b)', 'Resultado de Provisão para Créditos de Difícil Liquidação (b5)', 'Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)', 'Despesas de Pessoal (d3)', 'Despesas Administrativas (d4)', 'Resultado Não Operacional (f)']]
BASE2=BASE2.loc[(BASE2['Instituição'] == 'BANRISUL') | (BASE2['Instituição'] == 'BB') | (BASE2['Instituição'] == 'BRADESCO') | (BASE2['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE2['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE2['Instituição'] == 'ITAU') | (BASE2['Instituição'] == 'SANTANDER')]
BASE2['Denominador'] = BASE2['Resultado de Intermediação Financeira (c) = (a) + (b)'] - BASE2['Resultado de Provisão para Créditos de Difícil Liquidação (b5)'] + BASE2['Outras Receitas/Despesas  Operacionais (d) = (d1) + (d2) + (d3) + (d4) + (d5) + (d6) + (d7) + (d8)'] - BASE2['Despesas de Pessoal (d3)'] - BASE2['Despesas Administrativas (d4)'] + BASE2['Resultado Não Operacional (f)']
BASE2['Data'] = BASE2['Data'].dt.strftime('%m/%Y')
Mar = BASE2[BASE2['Data'].str.startswith('03/')]
Jun = BASE2[BASE2['Data'].str.startswith('06/')]
Set = BASE2[BASE2['Data'].str.startswith('09/')]
Dez = BASE2[BASE2['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['DEN'] = Sem1['Denominador']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['DEN'] = np.where(Sem1['Tri']==1, Sem1['DEN'], Sem1['DEN'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','DEN']] 
Jun.columns = ['Instituição', 'Data','Denominador'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Denominador']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['DEN'] = Sem2['Denominador']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['DEN'] = np.where(Sem2['Tri']==1, Sem2['DEN'], Sem2['DEN'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','DEN']] 
Dez.columns = ['Instituição', 'Data','Denominador'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Denominador']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE2 = pd.merge(merge2, Dez, how = 'outer')
BASE2['Data'] = pd.to_datetime(BASE2['Data']) 
BASE2 = BASE2.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE2['DEN'] = BASE2['Denominador']
BASE2['Denominador Anualizado'] = BASE2.DEN.rolling(4, min_periods=1).sum()
BASE2 = BASE2[['Instituição','Data','Denominador', 'Denominador Anualizado']] 
BASE2 = BASE2[~(BASE2['Data'] < '2012-12-01')]
BASE2 = BASE2.drop(['Denominador'], axis=1)
BASE1 = BASE1.merge(BASE2)
BASE1['%Índice de Eficiência'] = BASE1['Numerador Anualizado'] / BASE1['Denominador Anualizado']
BASE1 = BASE1.drop(['Numerador Anualizado', 'Denominador Anualizado'], axis=1)
BASE = BASE.merge(BASE1)

#48. Tributos sobre os Lucros Anualizados
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Imposto de Renda e Contribuição Social (h)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Imposto de Renda e Contribuição Social (h)'] = BASE1['Imposto de Renda e Contribuição Social (h)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['TRI'] = Sem1['Imposto de Renda e Contribuição Social (h)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['TRI'] = np.where(Sem1['Tri']==1, Sem1['TRI'], Sem1['TRI'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','TRI']] 
Jun.columns = ['Instituição', 'Data','Imposto de Renda e Contribuição Social (h)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Imposto de Renda e Contribuição Social (h)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['TRI'] = Sem2['Imposto de Renda e Contribuição Social (h)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['TRI'] = np.where(Sem2['Tri']==1, Sem2['TRI'], Sem2['TRI'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','TRI']] 
Dez.columns = ['Instituição', 'Data','Imposto de Renda e Contribuição Social (h)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Imposto de Renda e Contribuição Social (h)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['TRI'] = BASE1['Imposto de Renda e Contribuição Social (h)']
BASE1['Tributos sobre os Lucros Anualizados'] = BASE1.TRI.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Imposto de Renda e Contribuição Social (h)', 'Tributos sobre os Lucros Anualizados']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Imposto de Renda e Contribuição Social (h)'], axis=1)

#49. Tributos sobre os Lucros Anualizados relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Tributos sobre os Lucros Anualizados']]
BASE1['%Tributos sobre os Lucros Anualizados relativamente ao Patrimônio Líquido Nominal Médio'] = BASE1['Tributos sobre os Lucros Anualizados'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Tributos sobre os Lucros Anualizados'], axis=1)

#50. Participações nos Lucros Anualizados
BASE1 = BASEluc
BASE1 = BASE1[['Instituição','Data', 'Participação nos Lucros (i)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['Participação nos Lucros (i)'] = BASE1['Participação nos Lucros (i)'].div(1000000) 
BASE1['Data'] = BASE1['Data'].dt.strftime('%m/%Y')
Mar = BASE1[BASE1['Data'].str.startswith('03/')]
Jun = BASE1[BASE1['Data'].str.startswith('06/')]
Set = BASE1[BASE1['Data'].str.startswith('09/')]
Dez = BASE1[BASE1['Data'].str.startswith('12/')]
Sem1 = pd.merge(Mar, Jun, how = 'outer')
Sem1['PAR'] = Sem1['Participação nos Lucros (i)']
Sem1['Tri'] = Sem1['Data'].astype(str).str[1]
Sem1['Tri'] = Sem1['Tri'].str.replace('6','2')
Sem1['Tri'] = Sem1['Tri'].str.replace('3','1')
Sem1['Data'] = pd.to_datetime(Sem1['Data']) 
Sem1 = Sem1.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem1['PAR'] = np.where(Sem1['Tri']==1, Sem1['PAR'], Sem1['PAR'].diff(1))
Jun = Sem1.loc[Sem1['Tri'] == ('2')] 
Jun = Jun[['Instituição','Data','PAR']] 
Jun.columns = ['Instituição', 'Data','Participação nos Lucros (i)'] 
Mar = Sem1.loc[Sem1['Tri'] == ('1')] 
Mar = Mar[['Instituição','Data','Participação nos Lucros (i)']]
Sem2 = pd.merge(Set, Dez, how = 'outer')
Sem2['PAR'] = Sem2['Participação nos Lucros (i)']
Sem2['Tri'] = Sem2['Data'].astype(str).str[1]
Sem2['Tri'] = Sem2['Tri'].str.replace('9','3')
Sem2['Tri'] = Sem2['Tri'].str.replace('2','4')
Sem2['Data'] = pd.to_datetime(Sem2['Data']) 
Sem2 = Sem2.sort_values(['Instituição', 'Data'],ascending = [True, True])
Sem2['PAR'] = np.where(Sem2['Tri']==1, Sem2['PAR'], Sem2['PAR'].diff(1))
Dez = Sem2.loc[Sem2['Tri'] == ('4')] 
Dez = Dez[['Instituição','Data','PAR']] 
Dez.columns = ['Instituição', 'Data','Participação nos Lucros (i)'] 
Set = Sem2.loc[Sem2['Tri'] == ('3')] 
Set = Set[['Instituição','Data','Participação nos Lucros (i)']] 
merge1 = pd.merge(Mar, Jun, how = 'outer')
merge2 = pd.merge(merge1, Set, how = 'outer')
BASE1 = pd.merge(merge2, Dez, how = 'outer')
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['PAR'] = BASE1['Participação nos Lucros (i)']
BASE1['Participações nos Lucros Anualizados'] = BASE1.PAR.rolling(4, min_periods=1).sum()
BASE1 = BASE1[['Instituição','Data','Participação nos Lucros (i)', 'Participações nos Lucros Anualizados']] 
BASE1 = BASE1[~(BASE1['Data'] < '2012-12-01')]
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Participação nos Lucros (i)'], axis=1)

#51. Participações nos Lucros Anualizados relativamente ao Patrimônio Líquido Médio
BASE1 = BASE
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido Nominal Médio', 'Participações nos Lucros Anualizados']]
BASE1['%Participações nos Lucros Anualizados relativamente ao Patrimônio Líquido Nominal Médio'] = BASE1['Participações nos Lucros Anualizados'] / BASE1['Patrimônio Líquido Nominal Médio']
BASE1['Data'] = pd.to_datetime(BASE1['Data']) 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Participações nos Lucros Anualizados'], axis=1)

#52. Patrimônio Líquido Nominal
BASE1 = BASEpas
BASE1['Patrimônio Líquido (j)'] = pd.to_numeric(BASE1['Patrimônio Líquido (j)']) 
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1 = BASE1[['Instituição','Data','Patrimônio Líquido (j)']] 
BASE1.columns = ['Instituição', 'Data','Patrimônio Líquido Nominal'] 
BASE1['Patrimônio Líquido Nominal'] = BASE1['Patrimônio Líquido Nominal'].div(1000000) 
BASE = BASE.merge(BASE1)

#53. Patrimônio Líquido Real
BASE1 = BASE1.merge(IPCA)
BASE1 = BASE1.sort_values(['Instituição', 'Data'],ascending = [True, True])
BASE1['Patrimônio Líquido Real'] = (BASE1['Patrimônio Líquido Nominal'] / BASE1['IPCA Fator']) * BASE1['IPCA Fator'].iloc[-1]
BASE1 = BASE1.drop(['IPCA Mensal', 'IPCA Fator'], axis=1)
BASE = BASE.merge(BASE1)

#54. Ativos Ponderados pelo Risco relativamente aos Ativos Totais
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE2 = BASEati
BASE2 = BASE2[['Instituição','Data','Ativo Total (k) = (i) - (j)']]
BASE2=BASE2.loc[(BASE2['Instituição'] == 'BANRISUL') | (BASE2['Instituição'] == 'BB') | (BASE2['Instituição'] == 'BRADESCO') | (BASE2['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE2['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE2['Instituição'] == 'ITAU') | (BASE2['Instituição'] == 'SANTANDER')]
BASE1 = BASE1.merge(BASE2)
BASE1['% Ativos Ponderados pelo Risco / Ativos Totais'] = BASE1['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)'] / BASE1['Ativo Total (k) = (i) - (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Ativo Total (k) = (i) - (j)'], axis=1)

#55. Exposição Total relativamente aos Ativos Ponderados pelo Risco
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Exposição Total / Ativos Ponderados pelo Risco'] = BASE1['Exposição Total (k)'] / BASE1['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Exposição Total (k)'], axis=1)

#56. Capital Principal relativamente ao Patrimônio Líquido
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Capital Principal para Comparação com RWA (a)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE2 = BASEpas
BASE2 = BASE2[['Instituição','Data','Patrimônio Líquido (j)']]
BASE2=BASE2.loc[(BASE2['Instituição'] == 'BANRISUL') | (BASE2['Instituição'] == 'BB') | (BASE2['Instituição'] == 'BRADESCO') | (BASE2['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE2['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE2['Instituição'] == 'ITAU') | (BASE2['Instituição'] == 'SANTANDER')]
BASE1 = BASE1.merge(BASE2)
BASE1['% Capital Principal / Patrimônio Líquido'] = BASE1['Capital Principal para Comparação com RWA (a)'] / BASE1['Patrimônio Líquido (j)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Capital Principal para Comparação com RWA (a)', 'Patrimônio Líquido (j)'], axis=1)

#57. Patrimônio de Referência Nível I relativamente ao Capital Principal
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Capital Principal para Comparação com RWA (a)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Patrimônio de Referência Nível I / Capital Principal'] = BASE1['Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'] / BASE1['Capital Principal para Comparação com RWA (a)']
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Capital Principal para Comparação com RWA (a)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'], axis=1)

#58. Patrimônio de Referência relativamente ao Patrimônio de Referência Nível I
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Patrimônio de Referência para Comparação com o RWA', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Patrimônio de Referência / Patrimônio de Referência Nível I'] = BASE1['Patrimônio de Referência para Comparação com o RWA'] / BASE1['Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'] 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Patrimônio de Referência para Comparação com o RWA', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'], axis=1)

#59. Índice de Capital Principal
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Capital Principal para Comparação com RWA (a)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Índice de Capital Principal'] = BASE1['Capital Principal para Comparação com RWA (a)'] / BASE1['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)'] 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Capital Principal para Comparação com RWA (a)'], axis=1)

#60. Índice de Capital Nível I
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Índice de Capital Nível I'] = BASE1['Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'] / BASE1['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)'] 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'], axis=1)

#61. Índice de Basileia
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Patrimônio de Referência para Comparação com o RWA']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Índice de Basileia'] = BASE1['Patrimônio de Referência para Comparação com o RWA'] / BASE1['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)'] 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Ativos Ponderados pelo Risco (RWA) (j) = (f) + (g) + (h) + (i)', 'Patrimônio de Referência para Comparação com o RWA'], axis=1)

#62. Razão de Alavancagem
BASE1 = BASEcap
BASE1 = BASE1[['Instituição','Data','Exposição Total (k)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)']]
BASE1=BASE1.loc[(BASE1['Instituição'] == 'BANRISUL') | (BASE1['Instituição'] == 'BB') | (BASE1['Instituição'] == 'BRADESCO') | (BASE1['Instituição'] == 'CAIXA ECONOMICA FEDERAL') | (BASE1['Instituição'] == 'CAIXA ECONÔMICA FEDERAL') | (BASE1['Instituição'] == 'ITAU') | (BASE1['Instituição'] == 'SANTANDER')]
BASE1['% Razão de Alavancagem'] = BASE1['Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'] / BASE1['Exposição Total (k)'] 
BASE = BASE.merge(BASE1)
BASE = BASE.drop(['Exposição Total (k)', 'Patrimônio de Referência Nível I para Comparação com RWA (c) = (a) + (b)'], axis=1)

# Ajuste dos nomes das instituições e formatação das datas
BASE.loc[BASE['Instituição'] == 'BB', 'Instituição'] = 'BANCO DO BRASIL'
BASE.loc[BASE['Instituição'] == 'CAIXA ECONÔMICA FEDERAL', 'Instituição'] = 'CAIXA'
BASE.loc[BASE['Instituição'] == 'ITAU', 'Instituição'] = 'ITAÚ'
BASE['Data'] = BASE['Data'].dt.strftime('%m/%Y')

#Exportação do arquivo BaseMV.csv
BASE.to_csv('C:/Users/mvrgu/OneDrive/Documentos/Scanned Documents/Mestrado/Trabalho Final/IFData/Tratados/BaseMV.csv', index=False, encoding='utf-8-sig', sep=';', decimal=',')
pd.options.display.float_format = '{:,.6f}'.format
display(BASE)
# Out:
# C:\Users\mvrgu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\mvrgu\AppData\Local\Temp/ipykernel_6080/3963272508.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BASE1['Total'] = BASE1.groupby('Data')['Passivo Total (k) = (h) + (i) + (j)'].transform('sum')
# C:\Users\mvrgu\AppData\Local\Temp/ipykernel_6080/3963272508.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
